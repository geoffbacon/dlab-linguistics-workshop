# %% [markdown]
# # Pirahã syntax
#
# In this notebook we are going to explore Pirahã syntax. As you know, Pirahã is (in)famous in the field of linguistics for many reasons. One of the most prominent claims made about the language is a lack of syntactic recursion. Futrell et al. (2016) analyze a corpus of Pirahã for evidence of syntactic embedding. They report that they do not find any such evidence, and that the corpus is consistent with an analysis of Pirahã as a regular language. If you want to know more about Pirahã and the controversy surrounding it, read the following:
#
# - Everett, Daniel L. "Pirahã culture and grammar: a response to some criticisms." Language 85.2 (2009): 405-442.
# - Everett, Daniel, et al. "Cultural constraints on grammar and cognition in Piraha: Another look at the design features of human language." Current anthropology 46.4 (2005): 621-646.
# - Frank, Michael C., et al. "Number as a cognitive technology: Evidence from Pirahã language and cognition." Cognition 108.3 (2008): 819-824.
# - Futrell, Richard, et al. "A corpus investigation of syntactic embedding in Pirahã." PloS one 11.3 (2016): e0145289.
# - Nevins, Andrew, David Pesetsky, and Cilene Rodrigues. "Pirahã exceptionality: A reassessment." Language 85.2 (2009): 355-404.
#
# Futrell et al. (2016) make their corpus data freely available, which is why I chose this article. In particular, the corpus comes in a nice messy format. Throughout all the notebooks of this workshop, we're not going to be concerned with whether the arguments are right or wrong. Rather, we care about practising our Python skills so that we can do similar linguistic analyses.

# %% [markdown]
# ## Data
#
# The corpus used in the paper consists of Pirahã stories that were originally collected and translated by Steve Sheldon and Dan Everett over the period of several decades. It also includes aligned translation between Pirahã
# and English, including shallow syntactic parses and approximate English glosses.
#
# Here's how the authors describe the way they created the corpus:
# > We obtained glossed transcriptions of 17 stories in Pirahã, consisting of a total of 1149 sentences
# and 6830 words in our analysis. 13 of the stories were collected by Steve Sheldon in the
# 1970s, and the remaining 4 stories were collected by Dan Everett over the period 1980–2009.
# Each story was told by a single speaker with no recorded interruptions. The stories were transcribed
# by Everett or Sheldon; audio recordings are only available for stories 2 and 3. According
# to Everett, the texts are fairly representative of how the Pirahã tell stories to one another.
#
# If you're interested, you can see all the original texts in pdf format [here](https://github.com/languageMIT/piraha/tree/master/sources).

# %% [markdown]
# ### Downloading the data
#
# I've already downloaded the data for you. In the `data` folder there's a file called `piraha.txt`.

# %% [markdown]
# ### Structure of the data
#
# Although it's great that the data is made freely available, it's in a really messy format. It's going to take some preprocessing for us to reformat the data into a more usable form. Here's the description from the [README](https://github.com/languageMIT/piraha/blob/master/README.md) of how the corpus is structured:
#
# > Each text in the corpus is preceded by three lines of hashes and information about the source of the text. The corpus is divided into stories; stories are divided into "utterances"; and utterances are divided into sentences. Utterances correspond to the sentence breaks in Steve Sheldon's original glosses. Each utterance is preceded by two English glosses (free translations). The first is labeled with a hash and a code of two numbers, and reflects the English translation given by Steve Sheldon or Daniel L. Everett in their original translation. The second is labeled with a hash and a code of three numbers, and reflects the current best translation, as judged by Daniel L. Everett, Steve Sheldon, and the other authors. Clarifications are provided in square brackets in these glosses. The glosses allow simple text searching to find rough equivalents of English words and phrases (e.g. what does Pirahã use to convey meanings glossed as "and"?).
#
# > Each Pirahã sentence is labeled with a unique code of three numbers, appearing on the preceding line along with its current best English translation. The first number indicates the text in which the utterance appears. The second number indicates the utterance's sequential placement within the text. This second number reflects the utterance boundaries present in the original transcriptions (e.g. by Dan Everett and Steve Sheldon). In many cases, text which was originally translated into a single utterance actually includes a group of Pirahã sentences according to our current best translations. When this occurs, the third number indicates the order of the Pirahã sentences within this grouping. Otherwise, the third number is simply 1.
#
# Here's my simplification of it:
#
# - The corpus is all in one file, `piraha.txt`.
# - There are 17 stories in the corpus. They are separated from one another by three lines of hashtags.
# - Each story starts with three pieces of metadata: the source, the informant and the comment.
# - The source holds the names of the original pdf files of the story and the story number.
# - The informant is the speaker (for most stories there's only one speaker).
# - The comment holds various other things, like background, summary of the story, etc.
# - After the metadata, each story has a series of utterances. Utterances are the original sentence boundaries given by either Everett or Sheldon. Each utterance has a number within the story (e.g. 4.16 for utterance number 16 in story number 4). Immediately after the numeric identifier comes the original English translation of the utterance.
# - However, Sheldon and Everett have re-analyzed many utterances to in fact consist of more than one sentence. So each utterance actually consists of one or more sentences. Each sentence is identified by the story number, utterance number and sentence number (so 4.16.2 is the 2nd sentence of the 16th utterance of the 4th text). Immediately after each numeric identifier of a sentence is a shallow parse tree.

# %% [markdown]
# ### Reading in the data

# %%
fname = 'data/piraha.txt'
with open(fname, 'r') as f:
    raw_text = f.read()

# %% [markdown]
# ### Working with a single story

# %%
def split_stories(text):
    """Return all the stories in `text`.
    
    Parameters
    ----------
    text : str
        The raw text of the corpus
    
    Returns
    -------
    stories: list(str)
    """
    text_boundary = '''############################################################################################################################################ 
############################################################################################################################################ 
############################################################################################################################################'''
    stories = text.split(text_boundary)[1:]
    return [story.strip() for story in stories]

stories = split_stories(raw_text)
story = stories[3]

# %% [markdown]
# ### Extracting metadata

# %%
import os
import re

# %%
def story_number(story):
    """Extract the number of `story`.
    
    Parameters
    ----------
    story : str
    
    Returns
    -------
    number: int
        The position of the story in the corpus
    """
    match = re.search(r'# SOURCE: (\d+)', story)
    if match:
        number = match.group(1)
        number = int(number)
        return number
    else:
        return -1

story_number(story)
# Out:
# 17

# %%
def story_filename(story):
    """Extract the original pdf filename of `story`.
    
    Parameters
    ----------
    story : str
    
    Returns
    -------
    filename: str
        The filename of the original pdf
    """
    match = re.search(r'# SOURCE: .*, (.*.*\.pdf)', story)
    if match:
        filename = match.group(1)
        return filename
    return None

story_filename(story)
# Out:
# '17 PORTO VELHO IS BIG.pdf'

# %%
def story_informant(story):
    """Extract the name of the speaker of `story`.
    
    Parameters
    ----------
    story : str
    
    Returns
    -------
    name: str
    """
    speaker_pattern = re.compile(r'# INFORMANT: (.*)\n')
    match = re.search(speaker_pattern, story)
    if match:
        return match.group(1)
    return None

story_informant(story)
# Out:
# 'Tisahai'

# %%
def story_comment(story):
    """Extract the comment of `story`.
    
    Parameters
    ----------
    story : str
    
    Returns
    -------
    comment: str
    """
    comment_pattern = re.compile(r'# COMMENT: (.*)\n')
    match = re.search(comment_pattern, story)
    if match:
        return match.group(1)
    return None

story_comment(story)
# Out:
# 'Tisahai and her husband Apibai were in Porto Velho attending a workshop when this story was told.  She was sending it as a letter to others back in the village to tell them some of her impressions.'

# %% [markdown]
# ### Working with a single utterance

# %%
def split_utterances(story):
    """Return all the utterances in `story`.
    
    Parameters
    ----------
    story : str
        The raw text of a story
    
    Returns
    -------
    utterances: list(str)
    """
    utterance_boundary = '\n\n'
    utterances = story.split(utterance_boundary)[2:]
    return utterances

utterances = split_utterances(story)
utterance = utterances[0]

# %% [markdown]
# ### Extracting utterance data

# %%
def utterance_number(utt):
    """Extract the number of `utt`.
    
    Parameters
    ----------
    utt : str
        An utterance

    Returns
    -------
    number: int
        The position of the utterance in the story
    """
    match = re.search(r'(\d+\.\d+):', utt)
    if match:
        whole_number = match.group(1)
        number = whole_number.split('.')[1]
        number = int(number)
        return number
    return -1

utterance_number(utterances[-2])
# Out:
# 19

# %%
def utterance_translation(utt):
    """Extract the (original) translation of `utt`.
    
    Parameters
    ----------
    utt : str
        An utterance

    Returns
    -------
    translation: str
        The translation of the utterance
    """
    match = re.search(r'(\d+\.\d+): (.*)', utt)
    if match:
        translation = match.group(2)
        return translation
    return None

utterance_translation(utterances[0])
# Out:
# 'Itaibigai he (Steve) bought a lot of fish.'

# %% [markdown]
# ### Working with a single sentence

# %%
def split_sentences(utt):
    """Return all the sentences in `utterance`.
    
    Parameters
    ----------
    utt : str
        The raw text of an utterance
    
    Returns
    -------
    sentences: list(str)
    """
    all_sentences = re.sub(r'(# \d+\.\d+): (.*)', '', utt).strip()
    sentences = re.split(r'(?: ^|\n)# ', all_sentences)
    return sentences

# %% [markdown]
# ### Extracting sentence data

# %%
def sentence_number(sent):
    """Extract the number of `sent`.
    
    Parameters
    ----------
    sent : str
        A sentence

    Returns
    -------
    number: int
        The position of the sentence in the utterance
    """
    match = re.search(r'(\d+\.\d+\.\d+):', sent)
    if match:
        whole_number = match.group(1)
        number = whole_number.split('.')[2]
        number = int(number)
        return number
    return -1

sentence_number(sentence)
# Out:
# 1

# %%
def sentence_translation(sent):
    """Extract the translation of `sent`.
    
    Parameters
    ----------
    sent : str
        An utterance

    Returns
    -------
    translation: str
        The translation of the sent
    """
    match = re.search(r'(\d+\.\d+\.\d+): (.*)', sent)
    if match:
        translation = match.group(2)
        return translation
    return None

sentence_translation(sentence)
# Out:
# '[You] have not seen the foreigners.'

# %%
from nltk.tree import ParentedTree
from nltk.tgrep import tgrep_nodes, tgrep_positions

# %%
def sentence_tree(sent):
    """Extract the tree of `sent`.
    
    Parameters
    ----------
    sent : str

    Returns
    -------
    tree: str
    """
    non_tree_pattern = re.compile(r'# \d+\.\d+(\.\d+)?: .*')
    tree = re.sub(non_tree_pattern, '', sent).strip()
    return ParentedTree.fromstring(tree)

t = sentence_tree(sentence)
type(t)
# Out:
# nltk.tree.ParentedTree

# %%
for story in split_stories(raw_text):
    print(story_number(story), story_filename(story), story_informant(story))
    print()
    print(story_comment(story))
    print()
    for utterance in split_utterances(story):
        print(utterance_number(utterance), utterance_translation(utterance))
        print()
        for sentence in split_sentences(utterance):
            print(sentence_number(sentence), sentence_translation(sentence))
            print()
# Out:
# 1 01_KATO'S BABY FALLS NEAR THE FIRE.pdf Aogioso
#
# Steve Sheldon early 1970s; Translations and glosses completed by Dan Everett 2009. This is a story about a small baby (Tixohóí) who during the night falls off the bed and near the fire. His mother (Kato) and father (Hoagaixoóxai) are sound sleepers and do not waken to his crying. The grandmother (Xaogoíso) who is telling the story is very angry as is her sister (Xigaoxixaihoái) and husband (Xopísi). The father’s brother (Xoii) is also angry at their sleepiness and threatens that because the mother is such a sound sleeper he will have sexual contact with her some night and she would never know it. The baby is not really burned nor hurt, and finally grandmother takes baby back to his mommy to be nursed and put back to sleep. When the baby is sleeping again, the grandmother also returns to sleep.
#
# 2 He (TixohOI) fell by the fire.
#
# 1 He [TixohOI, KatO's baby] almost fell in the fire.
#
# 3 I spoke (carried sound). TixohOI is crying on the ground
#
# 1 I spoke!
#
# 2 "He [TixohOI] is on the ground."
#
# 3 "TixohOI is crying."
#
# 4 He fell by the fire right now.
#
# 1 [He] certainly fell by the fire just now.
#
# 5 I spoke to Opisi. 'Did TixohOI burn himself just now?'
#
# 1 I thus spoke [to] Xopisi [speaker's husband]!
#
# 2 "Did TixohOI fall down [and burn himself] just now?"
#
# 6 He is by the fire crying.
#
# 1 "[TixohOI] is by the fire crying."
#
# 7 Did he burn himself right now?
#
# 1 "Did he fall down [and burn himself] just now?"
#
# 8 I spoke. Well I will go pick him up.
#
# 1 I thus spoke!
#
# 2 "Well thus I will seek him out in that place."
#
# 9 He is really putting dirt up in his mouth on the ground
#
# 1 He was putting dirt up in [his] mouth!
#
# 10 Thus I spoke.  Xopisi, don't be so sleepy (lazy)!
#
# 1 I thus spoke!
#
# 2 "Xopisi, don't be so sleepy!"  ###Or possibly: Xopisi mustn't be sleepy.
#
# 11 He just fell by the fire.
#
# 1 [TixohOI] certainly fell by the fire just now.
#
# 12 Did he burn himself?  (lit: Did he fall directly down (on the fire)?)
#
# 1 Did he fall directly down [on the fire]?
#
# 13 XigaOxixaihoai then spoke.  Kato are you sleeping?
#
# 1 XigaOxixaihoai thus certainly spoke.
#
# 2 "Kato, you certainly are sleepy.  ###Or possibly, "Kato certainly is sleepy.
#
# 14 Your young first born son is by the fire now.
#
# 1 " Your young first born child is by the fire right now." # favorite?
#
# 15 She said (my sister is angry) she said, "Did he fall in the fire?  Did he fall in the fire just now?"
#
# 1 She [speaker's sister] thus spoke.
#
# 2 [My] sister is certainly angry.
#
# 3 She spoke!
#
# 4 "[TixohOI] fell in the fire?"
#
# 5 "[He] fell in the fire just now?"
#
# 16 Did TixohOi burn himself? (lit: fall directly on (the fire))
#
# 1 "Did Tixohoi fall down [in the fire]?"
#
# 17 He is crying by the fire.
#
# 1 "[He] is crying by the fire."
#
# 18 I then spoke.  Well Opisi, did he burn himself now?
#
# 1 I thus spoke!
#
# 2 "Well, Xopisi, did he fall down [in the fire] just now?"
#
# 19 Well XoI the relative is very angry.
#
# 1 Well XoI the relative certainly was angry.
#
# 20 XoI spoke.  Hoagaixoxai are you sleepy (lit: are your eyes fluttering)? (Are) you a man?
#
# 1 XoI certainly spoke.
#
# 2 "Hoagaixoxai, are you sleepy?"
#
# 3 "[Are] you a man?"
#
# 21 He will not go get his son.  (lit: He will not move in the environment to pick up and bring back his son)
#
# 1 He [Hoagaixoxai] will not go grab and pick up [his] son.
#
# 22 He is on the ground, under the ground (digging himself in)
#
# 1 He [TixohOI] [is] on the ground.
#
# 2 He [is] under the ground [digging himself in].
#
# 23 'Where is he?  I do not know.' (one speaker to the other) 'His hips are near the head of the bed. (answer to first speaker)
#
# 1 "Where [is] he?"
#
# 2 "I do not know." ###Lit: "I am unaware/ignorant." "I am no-eyes."
#
# 3 "[He] is certainly near the upper part [the head] of the bed."
#
# 24 His face is there on the ground.  It is there on the ground.
#
# 1 [His] face is there on the ground.
#
# 2 [His] face is there on the ground.
#
# 25 Well I nearly went to see Kato.
#
# 1 Well then I almost went to Kato.  ###Lit: Then I almost sought her out at the jungle/place.
#
# 26 Then I nearly cried out so she'd pick him up.  (lit:  I almost cried (to) her (such that) (she) picked (him) up.)
#
# 1 I nearly shouted to her.
#
# 27 But I spoke.  Kato is sleepy. (lit:Kato's eyes are fluttering)
#
# 1 Okay, [I] spoke.
#
# 2 "Kato certainly is sleepy."
#
# 28 Well I almost started to go and beat KatO.
#
# 1 I thus almost started beating up Kato. ###Lit: Kato -- I thus nearly hit [her] repeatedly.
#
# 29 Is he sleeping?
#
# 1 Is he sleeping?
#
# 30 Well then I went and picked him up.
#
# 1 I thus picked him up!
#
# 31 XopIsi spoke.  Is KatO intensely sleepy?
#
# 1 XopIsi thus spoke?
#
# 2 "KatO is very sleepy."
#
# 32 She will not go and pick him up.
#
# 1 She will not pick him up.
#
# 34 Well then I went to pull him up again.
#
# 1 I thus went to pull him up again.
#
# 35 I went up to him.  (3 person can be used for 1 person in texts, as the speaker takes a 'narrative perspective')
#
# 1 [I] sought him out in that place.
#
# 36 Is he all wrapped up in the cloth? (lit: He is turned down/tied.  Is it being the cloth?)
#
# 1 He is tied.
#
# 2 Is it cloth?
#
# 37 He is in (the cloth).  He is.  He is in.  He is being in.
#
# 1 He is tied. # Tied?!?!? Turn!??!!
#
# 2 She/he is.
#
# 3 He is tied.
#
# 4 He has been tied.
#
# 38 Well then my sister, BAIgipOhoasi, took XigaOxixaihoAi.
#
# 1 Well thus my sister, BAIgipOhoasi, certainly took XigaOxixaihoAi.
#
# 39 I then spoke.  Sister is angry.
#
# 1 I spoke.
#
# 2 "[She is] angry."
#
# 3 "(As has been mentioned,) [my] sister certainly [is] angry."
#
# 40 She spoke.  Well is Hoagaixoxai really sleepy?
#
# 1 She spoke.
#
# 2 "Well is Hoagaixoxai very sleepy?"
#
# 41 He doesn't go get his son.
#
# 1 He doesn't go get [his] son.
#
# 42 He sings/chants/whines (repetitive sounds).
#
# 1 She/he certainly whines.
#
# 43 I went to pick her up.
#
# 1 I thus picked [him] up.
#
# 44 I really spoke.  TixohOi is on the ground crying.
#
# 1 I spoke!
#
# 2 "TixohOi is on the ground crying."
#
# 45 (Continuing our main discussion), are the ants biting him?
#
# 1 Are ants biting him (as has been mentioned)?
#
# 46 His hips are over there.  Over there.
#
# 1 His hips are over there.
#
# 2 He [is] over there.
#
# 47 Yes, and over there on the ground is his head, over by the head of the bed.
#
# -1 None
#
# 1 He thus [is] here.
#
# 2 He spoke.
#
# 3 (As has been mentioned,) [his] head [is] on the ground, over by the head of his bed.
#
# 48 He is throwing up a lot of dirt for sure.
#
# 1 He certainly is really throwing dirt at you.
#
# 49 Well I called Hoagaixoxai.  He (then) almost shook his wife.
#
# 1 Well Hoagaixoxai heard me calling.
#
# 2 He, the ignorant one, certainly then almost shook his wife. # where is ignorant one?
#
# 50 Might he not hit wife not hit his hand.
#
# 1 Don't hit your wife!
#
# 51 He is angry at you for me.
#
# 1 (As has ben mentioned,) he certainly [is] angry at you [because of] me.
#
# 52 I alone will go get him!
#
# 1 [I] alone will go get her!
#
# 53 Well I got Kato.
#
# 1 I thus certainly went and got Kato.
#
# 54 He is in the dirt crying.
#
# 1 He [TixohOI] is in the dirt.
#
# 2 [He] is crying. # Why is this a second sentence?
#
# 55 As has been said, the ants could be biting his flesh.
#
# 1 (As has been mentioned,) the ants could be biting [his] flesh.
#
# 56 Well I went to him.  I spoke.  ToIao why are you getting up? (lit: what is associated with your rising?)
#
# 1 I thus went to him in the jungle.
#
# 2 [I] spoke.
#
# 3 Why is ToIao getting up?
#
# 57 ToIao, did he burn himself just now? (lit: might he have fallen down directly (onto the fire))
#
# 1 Might ToIao have fallen down directly [in the fire] just now?
#
# 58 Well then Opisi woke up.
#
# 1 Well then Xopisi certainly woke up.
#
# 59 Then he was talking.  I was angry.  I spoke.  I was angry.  I was quite angry.  I'll go get him!
#
# 1 Then he spoke to me.
#
# 2 "[I] was angry."
#
# 3 "I spoke."
#
# 4 "[I] was angry."
#
# 5 "[I] was certainly angry."
#
# 6 "[I] went to get [her]!"
#
# 60 Xoii was thus really mad at his brothers wife it seems.
#
# -1 None
#
# 1 Xoii was thus really mad at his brother's wife (it seems).
#
# 61 Xoii thus spoke (as we have been discussing), so it was heard. "(I) will eat you right now ('eat'=have sex.)  (I) will hit inside you in the daylight." (implying that she is too sleepy to know better.)
#
# 1 (I heard that as has been mentioned,) Xoii thus spoke.
#
# 2 "I [could be] eating her/you right now." ['eat'=have sex.]
#
# 3 "[I could] hit [your] insides!"
#
# 4 "[While the] sun was [up, even]!"
#
# 62 Xoii thus spoke.  He thus spoke.  I will eat you right now.  I will hit inside you.  With my pointy thing I will hit for a while.  In the sun even.
#
# 1 Xoii thus spoke.
#
# 2 (As has been mentioned,) he thus spoke.
#
# 3 "[I] will eat you right now!"
#
# 4 "[I] will hit your insides."
#
# 5 "With [it]"
#
# 6 "[With my] pointy thing [I could be] hitting."
#
# 7 "[While the] sun was certainly [up, even]!"
#
# 63 I picked up the child.  I spoke.  Why are you so lazy/sleep so much (lit: why do your eyes flutter?)
#
# 1 I thus picked up the child.
#
# 2 I certainly spoke!
#
# 3 "Why are you so sleepy?"
#
# 64 (Your) father (lit: 'thick one') hunts quickly.  If there are animals.
#
# 1 Your father [lit: 'thick/strong one'] certainly hunts quickly!
#
# 2 When there are animals.
#
# 65 He is sleeping/It seems. He (nevertheless) almost shoots an animal.  From inside the canoe (as is known).
#
# -1 None
#
# 1 He is sleeping.
#
# 2 [It] seems.
#
# 3 From inside he almost shoots an animal.
#
# 4 From inside the canoe, (as has been mentioned).
#
# 66 He is ignorant. He is not. (He is ignorant - not.)
#
# -1 None
#
# 1 He is ignorant.
#
# 2 Certainly not.
#
# 67 Xoii thus, Xoii thus was very angry with his wife.
#
# 1 (As has been mentioned,) thus Xoii certainly was angry with [his brother's] wife!
#
# 68 (He) yelled.  Don't (let) your son flop on the ground.
#
# 1 [He] yelled.
#
# 2 "Don't let your son flop on the ground."
#
# 69 I spoke loudly/clearly.  Did he fall down (into the fire) right now?
#
# 1 I spoke.
#
# 2 "Did he fall down [into the fire] just now?"
#
# 70 He fell so long ago.  (So I ask) are his clothes really messed up?
#
# 1 [Because] he certainly fell so long ago.
#
# 2 He thus certainly is ugly.
#
# 3 [Are his] clothes [twisted] around?
#
# 71 I thus spoke to him on the ground. I picked him up.  XitaIoi thus said Kato you are very sleepy (lit: your eyes flutter).
#
# 1 I thus almost talked to him on the ground.
#
# 2 [I] picked him up.
#
# 3 XitaIoi thus certainly spoke.
#
# 4 "Kato, you are very sleepy."
#
# 72 You are ignorant.  You don't get up.
#
# 1 " Well, you are ignorant."
#
# 2 "[ You] don't get up!"
#
# 73 Hoagaixoxai's wife nearly pierced his hand.  To his wife (he said) don't arrow me.  He tied her.  Thus his wife did not arrow him.
#
# 1 Hoagaixoxai's wife nearly pierced his hand.
#
# 2 [He spoke to his wife:] "Don't you, her/my wife, arrow me."
#
# 3 [He] certainly tied her.
#
# 4 Thus [his] wife did not pierce his hand.
#
# 74 Well then I picked him up.
#
# 1 I thus picked him up!
#
# 75 I thus spoke.  Has XopIsi just fallen into the fire?
#
# 1 I thus spoke.
#
# 2 "Did XopIsi fall [into the fire] just now?"
#
# 76 Did he fall into the fire now?
#
# 1 Did [he] fall into the fire just now?
#
# 77 I picked him up there.  I picked him up.  Then I put him down there.
#
# 1 [I] picked [him] up there.
#
# 2 [I] picked him up.
#
# 3 [I] was putting him down there.
#
# 78 He stopped crying. I went to sleep again.
#
# 1 He didn't cry.
#
# 2 [I] began to leave again to continue to sleep.
#
# 79 Milked, he stopped crying. (i.e. when he got milk he stopped crying.)
#
# -1 None
#
# 1 [He got] milk.
#
# 2 [He] didn't cry.
#
# 80 You stop crying. I'm picking you up now (as we have seen in this discourse).
#
# 1 [You] don't cry.
#
# 2 (As has been mentioned,) I picked you up.
#
# 81 Xopisi thus pulled his daughter up angry.  He (then) went to sleep again.
#
# 1 Xopisi thus pulled his daughter [Kato] up angrily.
#
# 2 [He] certainly went to sleep again.
#
# 82 Hoagaixoxai woke up.  I spoke up.  Hoagaixoxai did (he) fall (in the fire)?
#
# 1 Hoagaixoxai woke up.
#
# 2 I spoke up.
#
# 3 "Hoagaixoxai, did [he] fall in the fire?"
#
# 83 Will you stop being so sleepy?
#
# 1 Was he [Hoagaixoxai] so sleepy?
#
# 84 Do not be so sleepy!
#
# 1 He mustn't be so sleepy!
#
# 85 Did (he) fall in the fire?  You might (have) been ignorant of it.
#
# 1 Did [Tixohoi] fall in the fire?
#
# 2 He/you might have been unaware.  ###Possibly: He might not have been unaware.  Double negatives with ignorant/unaware.
#
# 86 You were completely ignorant.  (You) were on the ground by the ashes weren't you?
#
# 1 She/you were completely ignorant.
#
# 2 [You] might have been on the ground by the ashes?
#
# 87 I strong one (will) get him.
#
# 1 I, the thick/strong one, will pick him up.
#
# 88 I thus spoke strongly.  Is TixohOi eating dirt right now?
#
# 1 I thus spoke!
#
# 2 Is TixohOi eating dirt right now?
#
# 89 Did he get burned? (lit: did he fall into (the fire))
#
# 1 Did he fall [into the fire]?
#
# 90 It almost fell down (as we have been saying) into (the fire)?  Did the cloth fall into (the fire)?
#
# 1 (As has been mentioned,) he almost fell down.
#
# 2 Did the cloth fall [into the fire]?
#
# 91 Thus I moved towards him.  By the side (of the fire) I turned around to go again.
#
# 1 Thus I certainly moved towards him.
#
# 2 By the side [of the fire] [I] turned around.
#
# 3 [I] went again.
#
# 92 I thus spoke.  I almost called (sent my voice up and down the river bank) ToIao.
#
# 1 I thus spoke.
#
# 2 I almost continued to shout about ToIao.
#
# 93 Thus I spoke right there.  He almost sat in the fire.  He's crying.
#
# 1 (As has been mentioned,) thus I spoke right there.
#
# 2 He almost was sitting in the fire.
#
# 3 Certainly he cried.
#
# 94 Hoagaixoxoai is unaware.  He's not there.
#
# 1 Hoagaixoxoai is unaware.
#
# 2 He's not [there].
#
# 95 Well XopIsi finished pulling his child (Kato) up angrily.  Then he went down to sleep again.
#
# 1 Well XopIsi finished pulling his daughter [Kato] up angrily.
#
# 2 [He] certainly went down to continue to sleep again.
#
# 96 He (XopIsi) spoke.  I was not ignorant of it.  I intended to sleep.
#
# 1 He [XopIsi] spoke.
#
# 2 "[I] was not ignorant of it."
#
# 3 "[I] intended to sleep."
#
# 97 He thus is sleepy.
#
# -1 None
#
# 1 He thus is sleepy.
#
# 98 Hoagaixoxai he thus spoke.  (My) wife was finished being angry.  My wife's angry thus (I) put (the child) up again.
#
# 1 Hoagaixoxai thus spoke.
#
# 2 "[My] wife was finished being angry."
#
# 3 "[My] wife [is] angry."
#
# 4 "Thus [I] put the child up again."
#
# 99 I thus spoke.  I will put (it) with its mother (that we are talking about).
#
# 1 (As has been mentioned,) I thus spoke.
#
# 2 "[I] was putting [the child]."
#
# 3 "With his big [one][his mother] (as has been mentioned)."
#
# 100 (I) will put him up there (on the platform) again.
#
# 1 [I] will put him up there again.
#
# 101 He does not cry up there.
#
# 1 He does not cry there.
#
# 2 02 XigAbaI almost bitten by snake.pdf XahoApati
#
# Told by XahoApati to Dan Everett ca.2000
#
# 2 Certainly the snake nearly bit [him].
#
# 1 Certainly the snake nearly bit [him].
#
# 3 Thus ToItoI with (him) it bit at (also). Thus it was a real snake, a bushmaster, they saw.
#
# 1 Well certainly [the snake] also nearly bit Toitoi. ###Lit: Thus, Toitoi -- the snake certainly nearly bit with/at him.
#
# 2 It thus [was a] thick/strong 'real snake' [a bushmaster].
#
# 4 It is a bushmaster. Shoot it!
#
# 1 A 'real snake!'
#
# 2 Shoot the animal!
#
# 5 Thus the bulk of the people wanted to search carefully down on the ground. Thus (for that) snake.
#
# 1 They, the bulk [of them], were [there].
#
# 2 [They] certainly wanted to find that animal down on the ground!
#
# 6 (When I was) with the animal, (it) struck up (at me).
#
# 1 Because I [was] with the animal.
#
# 2 It struck up [at me].
#
# 7 I spoke (as I have been doing).  It almost bit him, almost wanted to.
#
# 1 (As has been mentioned,) I spoke.
#
# 2 The animal certainly almost bit [him], almost wanted to.
#
# 8 Thus, it (the bushmaster) didn't bite the human being (upwards and viciously).
#
# 1 Thus, it didn't bite the human being upwards and viciously.
#
# 9 He was there (almost) bitten?  (It was there that he was almost bitten)
#
# 1 The animal certainly [almost] bit [him] [some]where.
#
# 10 He was there (almost) bitten. It was there in the jungle. (The snake) almost bit XigAbaI, as we have been saying.
#
# 1 The animal [almost] bit [him] [some]where.
#
# 2 (As has been mentioned,) he/it was [there] in the jungle.
#
# 3 (As has been mentioned,) [the snake] almost bit XigAbaI!
#
# 11 (The snake) barely didn't bite XigAbaI. Quase Medo. (Port) Almost afraid.
#
# 1 [The snake] barely didn't bite XigAbaI.
#
# 3 03 Sept23AMFX3.pdf KaioA
#
# None
#
# 2 (taping) goes slowly
#
# -1 None
#
# 1 [Dan speaking:] [The taping is going] slowly.
#
# 3 Yeah. Slowly.
#
# 1 Yeah, slowly.
#
# 4 That's right.
#
# 1 Right.
#
# 5 Sarah {documentary producer} writes a lot
#
# 1 Sarah [documentary producer] writes [a lot].
#
# 6 Yeah, is it OK for you to speak to the recorder?
#
# -1 None
#
# 1 [Dan speaking:] Yeah, [is this] okay? [Asking permission for following command.]
#
# 2 [Dan speaking:] You speak to the recorder.
#
# 7 There are many foreigners in other jungles who want to see the Pirahãs. Is that OK?
#
# -1 None
#
# 1 [Dan speaking:] Many foreigners in other jungles want to see the Piraha.
#
# 2 [Dan speaking:] [Is that] OK?
#
# 8 OK
#
# 1 Okay.
#
# 9 OK I will talk to the paper/image
#
# 1 Okay, he/I will talk to the paper/image.
#
# 10 Dan, what did you say?
#
# 1 Dan, what did he [you] say?
#
# 11 There are foreigners (who want to see) the Pirahãs?
#
# 1 Thus [there are] many foreigners [who want to see the] Piraha?
#
# 12 Many?
#
# 1 Many?
#
# 13 There are foreigners in another jungle.
#
# -1 None
#
# 1 [Dan speaking:] Foreigners are in another jungle.
#
# 14 They say we want to see the Pirahãs.
#
# -1 None
#
# 1 [Dan speaking:] They say (as has been mentioned).
#
# 2 [Dan speaking:] "[We] want to see the Piraha."
#
# 15 Thus into the camera they look.
#
# -1 None
#
# 1 [Dan speaking:] Thus (as has been mentioned) [they] look [into] the camera.
#
# 16 Thus when you finish speaking, I will take it to another jungle (for them to see).
# -1 None
#
# 1 [Dan speaking:] Thus you finish talking.
#
# 2 [Dan speaking:] [I will take it] with [me] to another jungle [for them to see.]
#
# 17 OK?
#
# -1 None
#
# 1 [Dan speaking:] Okay?
#
# 18 OK
#
# 1 Okay.
#
# 19 Well, OK then. I speak. OK then.
#
# 1 Well [it] is okay.
#
# 2 Thus I speak (as has been mentioned).
#
# 3 [It] is okay.
#
# 20 Foreigners in the (other) jungle?
#
# 1 Foreigners are in [another] jungle?
#
# 21 I a whole lot want to see.
#
# 1 Very many of them want to see me.  ###OR: [They] want to see very many of them [like] me. Meaning: They want to see many Piraha, many people like me.
#
# 22 There is a small (amount here).  There is a small amount here.
#
# 1 A few [are here.] ###Or:  A few of them [the Piraha] [are here].
#
# 23 Paóxai wants to see.  A whole lot (of people).
#
# 1 Paoxai [Dan] wants to see very many of them [Piraha].
#
# 24 Thus a whole lot he wants to see.
#
# 1 Thus he [Dan] wants to see very many of them [Piraha].
#
# 25 A really whole lot. He wants to see. Here.
#
# 1 He wants to see very many of them there.
#
# 26 Xooopai he wants to see. A whole lot (of foreingers).
#
# 1 Xooopai [Dan] almost wants to see very many of them.
#
# 27 Yes. The water is shallow.
#
# 1 Thus the water [is] really shallow.
#
# 28 The boat cannot go up there.
#
# 1 The boat cannot [go] up [there] with her/it!
#
# 29 Thus the boat will not go.
#
# 1 Thus the boat certainly will not go.
#
# 30 The foreigners want to see a lot. A lot.
#
# 1 The foreigners want to see very many of them, very many of them.
#
# 31 There are only a few here.
#
# 1 A few of them are here.
#
# 2 Well, a few are here at Passar Bem.
#
# 32 Foreigners he calls this place Passar Bem.
#
# 1 Foreigners call this place Passar Bem.
#
# 33 Thus at Hoagahíai (Passar Bem) there are many Pirahãs. Thus a lot.
#
# 1 Thus at Hoagahiai [Passar Bem] the Piraha are numerous.
#
# 2 Thus [they] are numerous.
#
# 34 At Hoagahíai. Thus at Hoagahíai there are many.
#
# 1 [The Piraha] are at Hoagahiai.
#
# 2 Thus at Hoagahiai [Passar Bem] [the Piraha] are numerous.
#
# 35 You already know Hoagahíai.
#
# 1 You [Dan] already [know] HoagahIai.
#
# 36 Thus I alone speak to the recorder. Thus here. Me.
#
# 1 Thus I alone talk to the recorder here.
#
# 37 There is nothing. Not many here.
#
# 1 [There is] certainly nothing.
#
# 2 Certainly not many here.
#
# 38 I stay.
#
# 1 Only I stay.
#
# 39 Xioitabíi (his wife) here.
#
# 1 Xioitabii [speaker's wife] [lives] here.
#
# 40 Bahaio (his child) also.
#
# 1 Bahaio [his child] now.
#
# 41 Thus Hoaowii (shotgun: name of another of his children).
#
# 1 Thus Hoaowii [another one of his children].
#
# 42 Thus Shit (the name of another of his children) went to live there (goo is also used as a question word.)
#
# 1 Thus now Tiiowi [another one of his children] went to live there.
#
# 43 Alone. At Kaahai there is not a lot. One. Just one.
#
# 1 Alone.
#
# 2 At Kaahai [there are] certainly not many.
#
# 3 One. Just one.
#
# 44 Thus (at the place called) Palhal there are few. Now, here. I also. Few. Few. None. Not many.
#
# 1 Thus at Palhal [there are] few.
#
# 2 Now here I now...
#
# 3 Just one. Just one.
#
# 4 Certainly aren't not many.
#
# 45 Now at Hoagahíai (there are) many Pirahã.
#
# 1 Now at Hoagaiai the Piraha are numerous/many.
#
# 46 Thus Pirahã are many Pirahã. Hoagahiai at. Thus here.
#
# 1 Thus the Piraha are numerous/many here at Hoagahiai.
#
# 47 Hoigiigiai (lit: at the place of arrows or arrow shaft material) here. Hoihiigíai here.
#
# 1 Hoigiigiai hoihiigiai.
#
# 48 Foreigners call this Flechal (at the place of arrows or arrow shaft material).
#
# 1 Foreigners call [this place] Flechal.
#
# 2 Thus now the Piraha are numerous [at Flechal].
#
# 49 Hoigiigiai. Hoigiigiai also. Many.
#
# 1 At Hoigiigiai now they are numerous.
#
# 50 Thus Pirahã, jungle ('place') calls Hoihiigíai.
#
# 1 Thus the Piraha call [this] place Hoihiigiai.
#
# 51 Thus, Flechal. Thus foreigners foreigner (prefix) he calls it.
#
# 1 Thus foreigners call [it] Flechal.
#
# 52 Thus the Pirahãs call it Hoihiigíai. Hoihiigiai.
#
# 1 Thus the Piraha call [it] HoihiigIai.
#
# 53 Here. At Hoagaihiaii (there are Pirahã). More towards here. Hoagaihiaihi.
#
# 1 Here at Hoagaihiaii [there are] Piraha, more towards here.
#
# 54 There are many Pirahãs at Hoagaihiaihi. (At) Hoagaihiaihi.
#
# 1 Well the Piraha are numerous at Hoagaihiai.
#
# 55 Thus you (already) know Hoagaihiai.
#
# 1 Thus you [Dan] [already] know Hoagaihiai.
#
# 56 Thus I say. I speak to the recorder now.
#
# 1 (As has been mentioned,) thus I say.
#
# 2 I talk to the recorder now.
#
# 57 Here Kabagai (Pirahã woman) lives alone (not really - her husband lives with her). Thus alone Kabagai.
#
# 1 Here Kabagai [Piraha woman] [lives] alone.
#
# 2 Thus alone Kabagai.
#
# 58 There are no Pirahãs. No others.
#
# 1 The others [are] not Piraha.
#
# 59 Thus almost here. Here at Passar Bem, at the side of.
#
# 1 Thus almost here here Passar Bem strong.
#
# 60 Many there are few. Almost there are a lot.
#
# 1 Many [of] them certainly are a few.
#
# 2 Well, [there] are almost very [many].
#
# 61 Thus many at this jungle thus there. Many. Many are here. Many.
#
# 1 Thus many of them at this jungle/place they are thus here-- many.
#
# 2 Many are here.
#
# 62 Thus I also am at one.
#
# 1 Thus [with respect to] me [there are] now few.
#
# 63 Thus Bernardo also here. One. Not many.
#
# 1 Well, Bernardo [is] also here.
#
# 2 One. Not many.
#
# 64 Thus Bernardo (where he lives) there aren't many. Here. No one/nothing.
#
# 1 Well, [where] Bernardo [lives] [there are] not many.
#
# 2 Here aren't [many].
#
# 65 At Hoagaihiai. There are many Pirahã. Thus at Hoagaihiai there are many.
#
# 1 Thus at Hagaihiai many Piraha [are] numerous at Hoagaihiai.
#
# 66 Here at Flechal also. There are many. Pirahãs.
#
# -1 None
#
# 67 At Coatá also. There are many Pirahãs. Many children. Thus there. (There are) many (at) Coata.
#
# 1 At Coata now many Piraha, many children, thus really [are] numerous at Coata.
#
# 68 Thus. Paagagisai (what we call the foreign name, Coatá) You already know it.
#
# 1 Thus Paagagisai name foreigner, you already know [it] thus.
#
# 69 Thus Coatá, more towards here. Coatá. Thus at Coatá many.
#
# 1 Thus Coata, more towards here, Coata.
#
# 2 Well, [there are] many at CoatA.
#
# 70 Ok. I am going to talk to the foreigner (Randall).
#
# -1 None
#
# 1 [Dan speaking:] Well, I [will now] talk to the foreigner [Randall].
#
# 71 Okay.
#
# 1 Okay.
#
# 4 04 panther.pdf XahoApati (Simão)
#
# July 28, 1980; Maici River; Posto Novo; Collected, translated, analyzed, and transcribed by Daniel L. Everett
#
# 2 There the jaguar pounced on my dog and the dog died, it happened with respect to me.
#
# 1 The jaguar pounced on my companion [dog].
#
# 2 [The jaguar] killed it.
#
# 3 Yes, [this] certainly did [happen to] me.
#
# 3 There the jaguar killed the dog by pouncing on it.
#
# 1 There [the jaguar] certainly hit/killed the animal [dog] by pouncing.
#
# 4 With respect to it, the jaguar pounced on the dog, I thought I saw it.
#
# 1 The animal [jaguar] pounced on the companion [dog] there.
#
# 2 The animal [jaguar] jumped down.
#
# 3 [I] saw [it].
#
# 5 Then I recognized that the panther pounced on my dog.
#
# 1 Then I did [see] here.
#
# 2 The panther pounced on the companion [dog].
#
# 6 Then the panther pounced on my dog.
#
# 1 Then the panther pounced on the companion [dog].
#
# 7 Then I said that this (is the work of) a panther.
#
# 1 Then I spoke.
#
# 2 "A panther certainly was [what did this]."
#
# 8 Then I said with respect to the panter, "Here is where it went. I think I see (where it went)".
#
# 1 Then I spoke about the panther.
#
# 2 "Here (this place that as been mentioned) [is where] the animal went."
#
# 3 "[I] intend to go seeing/watching it." ###Or possibly: [I] am seeing it go.
#
# 9 Uh, I said "The jaguar then jumped up on the log".
#
# 1 Uh, I spoke.
#
# 2 "The animal [the jaguar] jumped up here onto a [log]".
#
# 10 As for the dog, the panther pounced on the partner.
#
# 1 [As for the] dog, the panther certainly pounced on the companion [dog].
#
# 11 The panther hit the dog and it had died.
#
# 1 The panther hit [the dog].
#
# 2 It died.
#
# 3 The animal was [dying].
#
# 12 Then when I had gunshot the jaguar, it began to fall.
#
# 1 Then [I] gunshot it [the jaguar].
#
# 2 The animal still began to die/fall.
#
# 13 "KaapAsi", I said, "Throw a basket (to me)".
#
# -1 None
#
# 1 "Kaapasi"
#
# 2 Well, I spoke.
#
# 3 "Kaapasi, throw a basket [to me]".
#
# 14 Throw me a basket to put the dog into.
#
# 1 She/you throw a basket [to put the dog into].
#
# 2 [I?/you?/she?] catch a basket.
#
# 15 The same cat pounced on the dog.
#
# 1 [This] same [jaguar] was.
#
# 2 Well, [this] cat was pouncing on the animal [dog].
#
# 16 The panther pounced on the dog, thus it caused him to be not.
#
# 1 Because the panther certainly was pouncing on the animal [dog].
#
# 2 Because then [it] certainly was causing [it to] not [exist].
#
# 17 Put the jaguar into the same basket with the dog.
#
# -1 None
#
# 1 It [the jaguar] is in there [the basket] with the dog.
#
# 2 You/he put [it] into the same basket there.
#
# 18 Put it in with the dog, he caused the dog to be not. He has therefore already (died).
#
# 1 Put it down.
#
# 2 Therefore [you] were setting [it] with the animal [dog].
#
# 3 Because he [the dog] [is] finished.
#
# 19 When you have the jaguar parts in the basket, then put the basket on your head [with a tumpline -DLE].
#
# 1 Because/after the animal has been put with the animal.
#
# 2 Then put the basket [on your head].
#
# 20 The dog then at night smelled him for sure then.
#
# 1 The dog then at night [when the fires are lit] certainly smelled [the jaguar] then.
#
# 21 It is right on top of the dog. It pounced on the dog and killed him.
#
# 1 [It is right on top of] the companion [dog], [certainly/directly] touching [it].
#
# 2 [It] pounced on the companion [dog].
#
# 3 He [the dog] certainly does not [live].
#
# 22 It is right on top of the dog. It pounced on the dog and killed him.
#
# 1 [It] pounced on the companion [dog] [and killed him].
#
# 23 Then I was talking, then Kaapasi he, animal, he ...
#
# 1 Then I spoke.
#
# 24 Don't shoot from far away. Be shooting down on it.
#
# 1 [You] mustn't want to be shooting far.
#
# 2 Continue to shoot down on it.
#
# 25 I moved quickly down towards the action onto the trunk, (I) killed it, thus it changed (died).
#
# 1 I moved quickly down towards the animal.
#
# 2 Certainly [I] finished/accomplished killing the animal.
#
# 3 Thus the animal certainly changed [died].
#
# 26 It was dying and it wasn't able to leave therefore.
#
# 1 Certainly the animal continued dying.
#
# 2 Therefore the animal certainly wasn't able to leave therefore.
#
# 27 OK, then, it thus came to die. Then it was coming to die.
#
# 1 OK, then, certainly the animal was dying therefore.
#
# 2 Then it continued dying.
#
# 28 Then Kaapasi, OK, he shot it.
#
# 1 Then Kaapasi, okay, [he] shot [it].
#
# 29 Then the animal thus changed and was dying. When the animal stood up it went away again.
#
# 1 Then the animal it therefore was dying.
#
# 2 The animal therefore stood up. ###Or possibly: Because/after the animal stood up.
#
# 3 It went away again.
#
# 30 Its dying was lingering.
#
# 1 It was dying.
#
# 31 I therefore shot it again, breaking its elbow.
#
# 1 Because I shot it again. ###Or possibly: I therefore shot it again.
#
# 2 The animal's elbow bone -- it [was] hurt [broken]. ###Or: The animal's elbow, at it [at that part], the animal's bone it [was] hurt/broken.
#
# 32 Then I shot it again, I therefore shot it again then.
#
# 1 I shot it again then.
#
# 2 I therefore shot it then. ###Or possibly: Because I shot it then.
#
# 33 It came to die, it came to die; it had thick fur.
#
# 1 It was dying.
#
# 2 It was certainly dying then.
#
# 3 The animal's fur/essence [was] strong/thick.
#
# 34 It intended thus to die. He did not move, therefore. His fur/essence is strong.
#
# 1 The animal it intended to die.
#
# 2 Therefore he did not move [from] there.
#
# 3 The animal's fur/essence [is] strong/thick.
#
# 35 He had not died. (I said) "That foreigner, you (Dan) the foreigner, have not seen (a jaguar) dead."
#
# 1 He had not yet died there. ###Or possibly: He had not yet died. [I] spoke.
#
# 2 "Foreigner, foreigner, you have not seen it [a jaguar]."
#
# 36 Then right away, (I) moved it, right then.
#
# -1 None
#
# 1 Then now [right then], [I] moved it, now [right then].
#
# 37 Then cats, Xisaitaógi (not DLE) has already seen.
#
# 1 Well, just cats -- Steve has already seen it/that.
#
# 38 Here jaguars [marked-he-is] (he has seen), only panthers the foreigner (not DLE) has not yet seen.
#
# 1 Here jaguars [he has seen].
#
# 2 Only a panther -- Steve still has not yet seen it/that animal.
#
# 39 Now, the Pirahãs have just now shot (a jaguar).
#
# 1 Now, already the Piraha shot it [the panther] just now.
#
# 40 Then the Pirahãs are intensely afraid of panthers. The end.
#
# 1 Thus, the Piraha [have] an intense fear [of] panthers.
#
# 2 The end.
#
# 5 05 VISIT OF THE ANTHROPOLOGISTS.pdf Itaibigai
#
# Two anthropologists from the Masen Goeldi have made three trips into the Piraha to study the culture.  Their names are Adelia (iAbi) and Ivelise (itaIai).  During their first visit they lived on the beach at the mouth of the Maici.  During their time there two children became very sick.  Kaogiai the son of Kaxai, and a new-born of Ahoogi's.  Kaogiai got better with medicine, but Ahoogi did not take the new-born to get medicine.  This upset the other Indians a great deal. The antropologists talk of Steve's return to the tribe and wonder if he will be angry.  The Indians are hoping that the girls will leave their goods behind when they go away.
#
# 2 I'll stay with them, I won't leave.
#
# 1 "[I'll stay] with the foreign women."
#
# 2 "[I] won't leave."
#
# 3 Ahoogi almost went away from the anthropologists, and his younger brother also.
#
# 1 Ahoogi also almost went away from the foreign women.
#
# 4 Kohoibiisai (the younger brother) then said, don't go away from the girls.
#
# 1 (As has been mentioned,) Kohoibiisai [the younger brother] thus spoke.
#
# 2 "Don't go away from the foreign women. ###Lit: Also do not the foreign women."
#
# 5 You will be sick.
#
# 1 "(As has been mentioned,) you will be sick."
#
# 6 Stay with the girls.
#
# 1 "[Stay] with the foreign women."
#
# 7 Well the children were stealing from the girls.
#
# 1 Well they [the children] were stealing the foreign women's things!
#
# 8 They were doing bad things.
#
# 1 (I heard that as has been mentioned) they [were doing] bad [things] [to] the foreign women's things.
#
# 9 Ahoogi then said, don't do that to the girls!
#
# 1 (I heard that as has been mentioned,) Xahoogi spoke.
#
# 2 "Don't you do [that] to the foreign women!"
#
# 10 The girls said, Steve is nearly to return isn't he?
#
# 1 (I heard that as has been mentioned,) the foreign women thus spoke.
#
# 2 "(I heard that as has been mentioned,) Steve comes [soon]?"
#
# 11 The moon is nearly gone.
#
# 1 "The moon [is] nearly gone."
#
# 12 Iabi then said, Steve, don't return just now!
#
# 1 (I heard that as has been mentioned,) Xiabi [the foreign woman] thus spoke.
#
# 2 "Steve shouldn't come just now!" ###Or: Steve, don't come right now!
#
# 13 The moon is nearly gone, the anthropologist said.
#
# 1 "(I heard that as has been mentioned) the moon [is] nearly gone."
#
# 2 The foreign women did [spoke].
#
# 14 Oi said, yes Steve will be coming.
#
# 1 Xoi thus spoke.
#
# 2 "Steve the foreigner will [come]."
#
# 3 "He will come."
#
# 15 Itaiai then said, by the next morning this time I will have gone.
#
# 1 The foreign woman spoke.
#
# 2 (I heard that as has been mentioned) Itaiai [the foreign woman] thus spoke.
#
# 3 The foreigner did [speak].
#
# 4 "(As has been mentioned,) I will go."
#
# 16 Steve is going to return.
#
# 1 Steve he does [come].
#
# 2 He will come.
#
# 17 Oi then said, I'm not going away from the girls.
#
# 1 Xoi thus spoke.
#
# 2 "[I] also will not [leave] the foreign women."
#
# 18 Steve is nearly here, yes he is.
#
# 1 "Steve the foreinger is [nearly here.]"
#
# 2 "He with."
#
# 3 "(I heard that as has been mentioned,) he will be."
#
# 19 Yes, I will not go away from the girls.
#
# 1 "I thus also will not [leave] the foreign women."
#
# 20 Well, the girls will leave the mosquito nets and everything here.
#
# 1 Well, the foreign women will leave the mosquito nets!
#
# 21 The child is sick.
#
# 1 The child [is] sick.
#
# 22 Don't be sick!
#
# 1 Child, don't be sick!
#
# 23 They have almost gone away from the girls.
#
# 1 They have almost [gone away] from the foreign women.
#
# 24 Oi said, don't go away from the girls.
#
# 1 He [Xoi] spoke.
#
# 2 "Do not also [leave] the foreign women."
#
# 25 You will be sick.
#
# 1 "You will be sick."
#
# 26 Iabi then yes then she (a stutter).
#
# 1 _A FRAGMENT/STUTTER_ Xiabi she then the foreign woman she then
#
# 27 Ahoogi's child died!
#
# 1 Xahoogi's child died!
#
# 28 Iabi said, Ahoogi's child died!
#
# 1 Certainly Xiabi thus spoke.
#
# 2 Xahoogi's son died just now!
#
# 29 Iabi said, Ahoogi's child died just now.
#
# 1 Xiabi, the foreign woman, thus [spoke].
#
# 2 "His child certainly died [this] afternoon."
#
# 30 Ahoogi said, he died, he is dead.
#
# 1 (As has been mentioned,) he/she spoke.
#
# 2 "He is dead."
#
# 31 Ahoogi said, I did not go see the anthropologist.
#
# 1 Xahoogi thus spoke.
#
# 2 He did not go see the foreign women.
#
# 32 Right near the girls, at the same place he died.
#
# 1 Right near the foreign women, at [that] same [place], he died.
#
# 33 Isabi said, Since Ahoogi did not go to see the girls he died, didn't he?
#
# 1 (As has been mentioned,) certainly Xisaabi thus spoke.
#
# 2 "Xahoogi did not go to see the foreign women."
#
# 3 "He died?"
#
# 34 Why is it that he died?
#
# 1 "Why did he die?"
#
# 35 He lives near the girls.
#
# 1 "(I heard that as has been mentioned,) he certainly lives [near] the foreign women." ###Or: He lives [by] the foreign women at [the place] they [are]. _Or: Him-- the foreign women live at [the place where] he [is].
#
# 36 Oi nearly went very early to see his relatives son.
#
# -1 None
#
# 1 Thus Xoi at dawn certainly nearly went to see [his] sibling's son.
#
# 37 The girls nearly brought medicine in the morning.
#
# 1 Another day, the foreign women nearly brought medicine.
#
# 38 Did Iabi really go see him early in the morning?
#
# 1 Did Xiabi,the foreign woman, go see him at [the place where] he [was] at dawn?
#
# 39 The child is dead.
#
# 1 The child is dead.
#
# 40 Steve don't be angry!
#
# 1 Steve mustn't be angry.
#
# 41 He died, yes he did.
#
# 1 (I heard that as has been mentioned,) he died.
#
# 42 Because of (the illness) Oi went early to see the anthropologist.
#
# 1 Because [of the illness] he [Xoi] went and saw the foreign women at [the place where] he [was] at dawn.
#
# 2 [He] went to the foreign women.
#
# 43 Iabi said (ahoogi) did not come to see me.
#
# 1 (I heard that as has been mentioned,) Xiabi the foreign woman thus spoke.
#
# 2 "He [Xahoogi] did not come to see me."
#
# 44 (If he had) I would have given him medicine.
#
# 1 "[With respect to] him [if he had come] then [I] would have certainly given him medicine."
#
# 45 Didn't kaogiai almost die?
#
# 1 Didn't Kaogiai almost die?
#
# 46 Well iabi put medicine onto the mouth of kaogiai who was almost dead.
#
# 1 Certainly Xiabi, the foreign woman, put her medicine into his [Kaogiai's] the [almost] dead one's mouth.
#
# 47 Kaxai said The girl is putting lots of medicine in, and when she did, well then he became alive again.
#
# 1 The foreign woman she did [put] lots of medicine [in] his mouth.
#
# 2 Certainly she went to put the medicine [in his mouth].
#
# 3 Kaogiai [because of the] medicine therefore certainly lives.
#
# 48 Kaxai, the younger one was almost angry with the anthropologist.
#
# 1 Kaxai [was] almost angry with the foreign woman.
#
# 2 The younger brother [Kaxai] was at [the place where] he [was].
#
# 49 Oi, the older one, put the medicine into the mouth of the younger relative, yes he did.
#
# 1 Xoi, he, [with respect to the] younger brother, the older one [Xoi] certainly did put her medicine [into] that sibling's [Kaxai's] mouth.
#
# 6 I STAY.pdf Tisahai
#
# This is a story about a trip that Steve, Apibai and the Maku informant were going to take in Porto Velho.  The speaker is Apibai's wife who does not plan to go on the trip even though her husband wants her to, because he never helps with the little child.
#
# 2 Linda said, "She intends to stay."
#
# 1 (As has been mentioned,) Linda spoke.
#
# 2 "She intends to remain."
#
# 3 Don't delay, I will remain.
#
# 1 He/you don't/shouldn't be delaying.
#
# 2 I intend to remain.
#
# 4 Only you go.
#
# 1 Only [you] come/go.
#
# 5 Don't delay!
#
# 1 (As has been mentioned) he/you want to be delaying.
#
# 6 Return quickly.
#
# 1 Return quickly.
#
# 7 I will remain here.
#
# 1 (As has been mentioned,) I intend to remain.
#
# 8 I intend to remain.
#
# 1 [I] intend to remain.
#
# 9 I will not go there.
#
# 1 [I will] not [go to that] place.
#
# 10 I intend to remain.
#
# 1 [I] intend to remain.
#
# 11 The child is very heavy.
#
# 1 The child he will be very heavy.
#
# 12 You don't carry the child.
#
# 1 You [do] not move with him [the child]!  ###Meaning: You don't carry him!
#
# 13 Yes, I intend to remain.
#
# 1 Thus, [I] intend to remain.
#
# 14 He (The other Indian) said, "O.K. let's go."
#
# 1 (As has been mentioned,) he [someone else] spoke.
#
# 2 "[Let's] go already!"
#
# 15 Don't delay long.
#
# 1 (As has been mentioned,) he is delaying.
#
# 16 I will not go there.
#
# 1 [I will] not go there.
#
# 17 I will remain.
#
# 1 Certainly [I will] still remain [here].
#
# 18 The Maku (Indian) sail also be going.
#
# 1 The Maku Indian must also come now.
#
# 19 I will not go there.
#
# 1 [I will] not [go to that] place there.
#
# 20 I intend to remain.
#
# 1 [I] intend to remain.
#
# 21 Well, when Steve goes, you go with his.
#
# 1 Well, Steve goes.
#
# 2 [You] also go [with Steve].
#
# 22 Yes, I will not go there.
#
# 1 Well, [I will] not [go to that] place there.
#
# 23 I intend to remain.
#
# 1 [I] intend to remain.
#
# 24 I am remaining.
#
# 1 I am again remaining.
#
# 25 Only you go on.
#
# 1 Only [you] still go.
#
# 26 I will not go there.
#
# 1 [I] will not [go to that] place [there].
#
# 27 I will still remain.
#
# 1 [I will] still remain.
#
# 28 Linda said she will be staying.
#
# 1 (As has been mentioned,) Linda spoke.
#
# 2 (As has been mentioned,) [she] intends to remain.
#
# 7 07 BIRTH OF PE'S BABY #2.pdf Maigiphoasi
#
# Background information: The mother giving birth is about 14 years old, married to a man about 45-50. Her name is Pe, his is Hoagaixoxai.  The young girl's parents have gone on a fishing trip, and everyone is quite upset because they are not there to help look after her.  The baby is born down at the river, and the young mother is very weak.  She tries to come up to the river bank but nearly falls, so her husband calls me (Steve) to come with a hammock to get the mother.  She doesn't want to but we bring her up in the hammock anyway.
#
# 2 Are you going to delay long aogioso.
#
# 1 Are you delaying, Xaogioso?
#
# 3 Pii is having labor pains.
#
# 1 Pii is hurt [having labor pains].
#
# 4 Pii has not given birth to it yet.
#
# 1 Pii is still not giving birth [yet].
#
# 5 Hoagaixoxai said, are you going to delay long?
#
# 1 (As has been mentioned,) Hoagaixoxai spoke.
#
# 2 "[Are you] delaying?"
#
# 6 Pii is having labor pains.
#
# 1 Pii is hurt [having labor pains].
#
# 7 She is not giving birth yet.
#
# 1 She is not giving birth.
#
# 8 Does it want to remain in her stomach.
#
# 1 Does it want [to remain in her] stomach?
#
# 9 She has not given birth.
#
# 1 She is not giving birth.
#
# 10 Hoagaixoxai said, the child is already born.
#
# 1 (As has been mentioned,) Hoagaixoxai spoke.
#
# 2 "The child [is] already [born.]"
#
# 11 Hoagaixoxai said, Pii just now gave birth.
#
# 1 (As has been mentioned,) Hoagaixoxai spoke.
#
# 2 "Certainly Pii already gave birth."
#
# 12 Hoagaixoxai put his son on the floating dock when his wife gave birth.
#
# 1 Certainly Hoagaixoxai thus put his son on the wood [a floating dock].
#
# 2 [He] floated.
#
# 3 [His] wife she gave birth.
#
# 13 Hoagaixoxai siad, Opisi are you going to delay long?
#
# 1 (As has been mentioned,) Hoagaixoxai spoke.
#
# 2 "Xopisi, are you/he delaying?"
#
# 14 Pii is having labor pains.
#
# 1 Pii is hurt [having labor pains].
#
# 15 Hoagaixoxai said, Pii is having labor pains at night.
#
# 1 (As has been mentioned,) Hoagaixoxai spoke.
#
# 2 "Pii is hurt [having labor pains] at night."
#
# 16 Is he going to delay long?
#
# 1 Is he delaying?
#
# 17 Hoagaixoxai said, she is not giving birth.
#
# 1 (As has been mentioned,) Hoagaixoxai spoke.
#
# 2 (As has been mentioned,) he spoke.
#
# 3 She is not giving birth.
#
# 18 Aogioso will you delay?
#
# 1 Xaogioso, you/he delay.
#
# 19 Is Aogioso going to delay long?
#
# 1 Is Xaogioso delaying?
#
# 20 Aogioso, Pii is not giving birth!
#
# 1 Is Pii not giving birth, Xaogioso?
#
# 21 Hoagaixoxai said, Pii has just now given birth!
#
# 1 Hoagaixoxai thus spoke!
#
# 2 "Pii has certainly already given birth -- just now!"
#
# 22 Hoagaixoxia said, Steve will we not bring her in the hammock.
#
# 1 Hoagaixoxia thus spoke!
#
# 2 "Steve will not bring her in the hammock."
#
# 23 She is weak.
#
# 1 She certainly is weak.
#
# 24 Hoagaixoxai said, we will bring her in the hammock.
#
# 1 (As has been mentioned,) Hoagaixoxai thus spoke.
#
# 2 "[We] will bring her in the hammock."
#
# 25 Hoagaixoxia then is bringing the hammock.
#
# 1 Thus, Hoagaixoxia is bringing the hammock.
#
# 26 Hoagaixoxai said, Pii is almost came up from the float.
#
# 1 (As has been mentioned,) Hoagaixoxai spoke.
#
# 2 Pii almost floats up.
#
# 27 Pii is nearly weak.
#
# 1 Pii almost is weak.
#
# 28 She is not coming up.
#
# 1 [She] is not coming up.
#
# 29 Then Pii bringing her son just now fell.
#
# 1 Thus Pii begins to bring her son down. ###Or: Thus Pii carries her son and begins to fall.
#
# 30 So Hoagaixoxai grabbed his wife's arm there, like this.
#
# -1 None
#
# 1 Thus Hoagaixoxai [on the] arm there grabbed his wife, like this.
#
# 31 Pii lets go, because your legs are very weak.
#
# 1 Pii, c'mon, you!
#
# 2 Because [your] legs [are starting to be] very [weak].
#
# 32 With her son she must not come!
#
# 1 [She does/can/must] not pick up her son!
#
# 33 Hoagaixoxai, intends to bring her up in the hammock.
#
# 1 Thus Hoagaixoxai intends to pick [her] up in the hammock.
#
# 34 Hoagaixoxai will be bringing his wife.
#
# 1 Thus Hoagaixoxai will bring her [his] wife up in a hammock. ###Or possibly: Thus Hoagaixoxai will bring his wife up in a hammock.
#
# 35 Hoagaixoxai said, Lets go.
#
# 1 Hoagaixoxai thus spoke.
#
# 2 "C'mon!/Let’s go!"
#
# 36 Pii is weak.
#
# 1 Pii is weak.
#
# 37 Hoagaixoxai said to his wife that he would bring her.
#
# 1 Hoagaixoxai spoke [to his] wife.
#
# 2 Hoagaixoxai will bring her.
#
# 38 You (Pii) will go up to the house, will arrive at the house, and afterwards sleep, said Hoagaixoxai.
#
# 1 "You [Pii] will go up to the house."
#
# 2 "[You] will arrive."
#
# 3 "[You] will go be sleeping afterwards."
#
# 4 (As has been mentioned,) Hoagaixoxai spoke.
#
# 39 Pii said, I am staying weak.
#
# 1 (As has been mentioned,) Pii spoke.
#
# 2 I am weak/weakening.
#
# 40 I do not intend to go.
#
# 1 [I] do not intend to go.
#
# 41 My legs are weak.
#
# 1 My legs [are] weak.
#
# 42 My legs are useless.
#
# 1 [My] legs are useless.
#
# 43 I won't go on land!
#
# 1 [I] won't [go] on land!
#
# 44 Hoagaixoxai then said, we will bring you in the hammock.
#
# 1 Hoagaixoxai then spoke.
#
# 2 [We] will bring [you] in the hammock.
#
# 45 You will arrive lying down in the hammock.
#
# -1 None
#
# 1 You lie down and arrive in the hammock.
#
# 46 He is bringing his wife just now.
#
# 1 He certainly will bring [his] wife.
#
# 47 He is coming bringing her in the hammock just now.
#
# 1 [He] certainly will bring [her] in the hammock.
#
# 48 He (Steve) said, is she weak?
#
# 1 (As has been mentioned,) the foreigner [Steve] spoke.
#
# 2 "Is she weak/weakening?"
#
# 49 She is not coming.
#
# 1 (As has been mentioned,) she is not coming up.
#
# 50 Hoagaixoxai then said, we will bring her in the hammock.
#
# 1 (As has been mentioned,) Hoagaixoxai thus spoke.
#
# 2 (As has been mentioned,) [we will] bring [her] in the hammock.
#
# 51 Hoagaixoxai is just now bringing his wife in the hammock.
#
# 1 Thus Hoagaixoxai is starting to bring his wife in the hammock.
#
# 52 Hoagaixoxai said, Pii has just now given birth!
#
# 1 (As has been mentioned,) Hoagaixoxai spoke.
#
# 2 Pii has also already given birth!
#
# 53 Hoagaixoxai put his son on the floating dock.
#
# 1 Thus Hoagaixoxai moved him [his son] up onto the wood [a floating dock].
#
# 2 [He] put him, [his] son [onto the dock].
#
# 54 Hoagaixoxai's wife gave birth.
#
# 1 (As has been mentioned,) Hoagaixoxai's wife gave birth.
#
# 8 08 CASIMIRO DREAMS.pdf Kaboibagi
#
# This is a text about a dream that the speaker in the story had.  He is dreaming about a Brazilian woman that used to live near to the village, and is a very, very large woman.
#
# 2 As I dreamed, I and the Brazilian woman were there.
#
# -1 None
#
# 1 Well, [with respect to] me [my dream], the foreign woman was [there].
#
# 2 [I] began dreaming.
#
# 3 She said in the dream, "You will stay with the Brazilian man."
#
# 1 [I] spoke [to the] foreigner. ###Or possibly: The foreinger spoke.
#
# 2 "[I] was dreaming [about] the foreigner."
#
# 3 "Stay with the foreigner."
#
# 4 You will stay with him.
#
# 1 You will stay [with] the foreigner!
#
# 5 Well, then I and the Big Brazilian woman disappeared.
#
# 1 Well, [with respect to] me, the very big foreigner went away again.
#
# 6 Next, I dreamed about Kamao and bananas.
#
# 1 [Next, I] dreamed [about] bananas.
#
# 9 09 DEATH OF AOGIOSO #2.pdf Iaibigai
#
# This text again tells of Aogioso's death, emphasizing the trip downriver to tell her husband Opisi, who was fishing for Piranha, and the group living at the mouth of the Maici. When Aogioso dies, Abagi (Oi is his other name) is the only Piraha available to help carry her up from the riber bank. Of course he cannot do this alone, so he and Steve go down river to get help.  His daughter Iogi, upon learning of the death is afraid that perhaps the Brazilians may have killed Aogioso and also her husband.
#
# 2 I intend to go and tell bai (her father) that Aogioso has died.
#
# 1 He [Xabagi] intends to go talk to Bai [Xaogioso's father].
#
# 2 "Xaogioso has died."
#
# 3 Only one cannot carry her up the river bank.
#
# -1 None
#
# 1 Certainly, they are not one [person].
#
# 2 (As has been mentioned,) [they] carry [Xaogioso up the river bank].
#
# 4 She is very heavy, and I am only one.
#
# -1 None
#
# 1 She is very heavy.
#
# 2 [I] am alone. ###Or: [I] am [just] one [person].
#
# 5 Aogioso is no longer here, and I probably can't bring her up.
#
# 1 Xaogioso is not [alive].
#
# 2 Carry [her up] (as has been mentioned).
#
# 6 I will go with Steve.
#
# 1 [I] do [go] with Steve.
#
# 7 I am only one he said, and she is very heavy.
#
# 1 [I] am alone.
#
# 2 (As has been mentioned,) he [Xabagi] spoke.
#
# 3 "[She] is very heavy."
#
# 8 There are not lots of people around.
#
# -1 None
#
# 1 Many [people] are not [here]. _Meaning: There aren't many people here.
#
# 9 I will go with Steve.
#
# 1 [I] will go with Steve.
#
# 10 The others are not here.
#
# 1 They [many people] are not [here]. _Meaning: There aren't many people here.
#
# 11 Am I to bring her up the river bank?
#
# 1 (As has been mentioned,) the ground [river bank] is [here].
#
# 2 [How will I] carry [her] (as has been mentioned)?
#
# 12 There is only one of him.
#
# 1 He [Xabagi] is alone.
#
# 13 She has died.
#
# 1 (As has been mentioned,) [Xaogioso] has died.
#
# 14 Abagi said, I will go with Steve.
#
# 1 (As has been mentioned,) he [Xabagi] spoke.
#
# 2 "[I] will go with Steve."
#
# 15 When Steve stopped there Abagi said, Aogioso is dead.
#
# ...
#
# -1 None
#
# 1 (I heard that as has been mentioned,) thus the foreigner [Martins] must leave by day.
#
# 10 He will sleep.
#
# 1 The foreigner sleeps.
#
# 11 Yes, by day he will go on.
#
# 1 Thus by day he will leave.
#
# 12 Steve said, "Tomorrow I will look for Bananas."
#
# -1 None
#
# 1 "Bananas."
#
# 2 (I heard that as has been mentioned,) the foreigner [Steve] spoke.
#
# 3 "(I heard that as has been mentioned,) tomorrow [I] the foreigner will search."
#
# 13 He sleeps.
#
# 1 The foreigner [Martins] sleeps.
#
# 14 Yes, he intends to sleep.
#
# 1 Thus the foreigner intends to go to sleep.
#
# 15 He will take out bananas.
#
# 1 (As has been mentioned,) [he] goes to sleep [on?] bananas.
#
# 16 He will sleep.
#
# 1 The foreigner sleeps.
#
# 17 Yes the Brazilian intends to sleep.
#
# 1 Thus the foreigner Martins intends to go to sleep.
#
# 18 Steve says, he sleeps.
#
# 1 (As has been mentioned,) the foreinger [Steve] spoke.
#
# 2 "The foreigner [Martins] sleeps."
#
# 19 You will sleep!
#
# 1 [You] still must go to sleep!
#
# 20 You are drunk.
#
# 1 You [are] drunk.
#
# 21 The boat must not hit wood (logs).
#
# 1 (As has been mentioned,) the boat must not hit them, the wood [logs].
#
# 22 He will sleep.
#
# 1 The foreigner sleeps.
#
# 23 The Brazilian intends to sleep.
#
# 1 Thus the foreigner intends to go to sleep.
#
# 24 By day you go, Steve said to his customer.
#
# 1 "Leave in the day."
#
# 2 (I heard that as has been mentioned,) the foreigner [Steve] went to talk to [his] customer.
#
# 25 By day he will look for bananas.
#
# 1 By day the foreigner will search for those bananas.
#
# 26 He will sleep.
#
# 1 The foreigner sleeps.
#
# 27 Yes, the Brazilian, Martins, intends to sleep.
#
# 1 Thus the foreigner, Martins, intends to go to sleep.
#
# 28 Steve said, "The Brazilian sleeps."
#
# 1 (As has been mentioned,) the foreinger [Steve] thus spoke.
#
# 2 "The foreigner [Martins] sleeps."
#
# 29 Martins, you are drunk!
#
# 1 "Martins, you [are] drunk!"
#
# 30 You go by day!
#
# 1 "Leave by day!"
#
# 31 There are many logs.
#
# 1 [There are] many logs.
#
# 32 It's nearly becoming night.
#
# 1 [It has nearly] become night!
#
# 33 He sleeps.
#
# 1 The foreigner sleeps.
#
# 34 He is nearly asleep?
#
# 1 Is [he] still nearly beginning to sleep?
#
# 35 By day he will look for bananas.
#
# 1 By day the foreigner will search for bananas.
#
# 36 He sleeps.
#
# 1 The foreigner sleeps.
#
# 37 Yes, the Brazilian intends to sleep.
#
# 1 Thus the foreigner intends to go to sleep!
#
# 38 He (Isabi) said, "The Brazilian sleeps."
#
# 1 (As has been mentioned,) he [Xisaabi] spoke.
#
# 2 "The foreigner sleeps."
#
# 39 By day (Steve) will look for them (bananas).
#
# 1 By day the foreigner [Steve] will search.
#
# 40 Well I (the speaker) almost went on board.
#
# 1 Thus I [the speaker] almost went [on board the boat].
#
# 41 (Isabi) said, "He sleeps."
#
# 1 (As has been mentioned,) he [Xisaabi] spoke.
#
# 2 "The foreigner sleeps."
#
# 42 He (Isabi) said, "intends to sleep."
#
# 1 (I heard that as has been mentioned,) he spoke.
#
# 2 "The foreigner sleeps."
#
# 43 Steve said, "Sleep here with me Martins,"
#
# 1 (I heard that as has been mentioned,) Steve spoke.
#
# 2 "[You] Martins [AND?] I certainly [should] still go to sleep."
#
# 44 You are drunk.
#
# 1 You have become drunk.
#
# 45 The boat must not hit logs.
#
# 1 The boat must not hit logs.
#
# 46 He (Steve) said, "Go to sleep, so he went to sleep in the front of the boat."
#
# 1 (I heard that as has been mentioned,) he [Steve] spoke.
#
# 2 "Continue to go to sleep."
#
# 3 Therefore [he] slept in the front of the boat.
#
# 47 Bai nearly went into the front of the boat.
#
# 1 Thus, did Bai nearly enter the front of the boat?
#
# 48 He entered, however, on top of the Brazilian.
#
# 1 Therefore/however, [Bai] entered on top of the foreigner.
#
# 49 He (Isabi) said, "Yes" he said, "He sleeps."
#
# 1 (As has been mentioned,) he thus spoke.
#
# 2 (As has been mentioned,) he thus spoke.
#
# 3 "The foreigner sleeps."
#
# 50 He will sleep.
#
# 1 [He] begins to sleep.
#
# 51 He will still sleep!
#
# 1 [He] must continue to go to sleep!
#
# 52 It is getting dark.
#
# 1 It is getting dark. [Lit: The black sky arrives. Or: The sky becomes black.]
#
# 53 He (Isabi) said, "Martins is angry."
#
# 1 He [Xisaabi] spoke.
#
# 2 He did.
#
# 3 "Martins the foreigner is angry."
#
# 54 He is nearly to leave.
#
# 1 He nearly leaves.
#
# 55 He (Isabi) said, "Steve's customer nearly becomes angry."
#
# 1 He thus spoke.
#
# 2 "(I heard that as has been mentioned,) the foreigner's [Steve's] customer nearly becomes angry."
#
# 56 Isabi said, "He will sleep there."
#
# 1 Xisaabi spoke.
#
# 2 "The foreigner sleeps."
#
# 57 He will sleep after he goes there.
#
# 1 [He will] sleep there.
#
# 2 (I heard that as has been mentioned,) [he] will certainly afterwards go and continue to sleep.
#
# 58 Steve said to his customer, stay and sleep.
#
# 1 (As has been mentioned,) the foreigner [Steve] spoke to Martins, his customer.
#
# 2 "[You] continue to go to sleep."
#
# 59 He (Steve) said, "Go by day."
#
# 1 (I heard that as has been mentioned,) the foreigner [Steve] spoke.
#
# 2 "Leave by day."
#
# 60 There are lost of logs.
#
# 1 Many logs are [by the] boat.
#
# 61 The boat might hit the logs.
#
# 1 (I heard that as has been mentioned,) the boat [might] hit them [the logs].
#
# 62 Yes, sleep.
#
# 1 Thus sleep.
#
# 63 Steve said to his customer, you must sleep.
#
# 1 (I heard that as has been mentioned,) the foreigner Steve spoke to his customer.
#
# 2 "The foreigner [you, Martins] thus [should] intend to begin to sleep."
#
# 64 You go to sleep.
#
# 1 The foreigner goes to sleep.
#
# 65 He (Steve) said, "Sleep."
#
# 1 (As has been mentioned,) he [Steve] spoke.
#
# 2 "The foreigner [you, Martins] sleep."
#
# 66 By day you go.
#
# 1 Leave by day.
#
# 67 The Brazilian is drunk.
#
# 1 The foreigner [is] drunk!
#
# 68 Yes, he is drunk.
#
# 1 (I heard that as has been mentioned,) the foreigner [is] drunk.
#
# 69 The Brazilian sleeps.
#
# 1 The foreigner sleeps.
#
# 70 Yes, he will sleep.
#
# 1 Thus the foreigner goes to sleep.
#
# 71 You are drunk!
#
# 1 You [are] drunk.
#
# 72 The Brazilian is out of his head.
#
# 1 (I heard that as has been mentioned,) the foreigner is crazy.
#
# 73 He (Isabi) says, "He speaks out of his head."
#
# 1 (As has been mentioned,) he [Xisaabi] spoke.
#
# 2 The foreigner talks crazy.
#
# 74 He is out of his head.
#
# 1 The foreigner [is] crazy.
#
# 75 Steve's customer speaks that way.
#
# 1 (I heard that as has been mentioned,) the foreigner's [Steve's] customer talks.
#
# 76 He is drunk.
#
# 1 He is drunk.
#
# 77 Martins drinks lots of whiskey.
#
# 1 Martins drinks liquid [whiskey]!
#
# 78 He (Isabi), said, "He sleeps."
#
# 1 (As has been mentioned,) he [Xisaabi] spoke.
#
# 2 "The foreigner sleeps."
#
# 79 Steve said to his customer, You will stay and sleep there!
#
# 1 (I heard that as has been mentioned,) the foreigner Steve spoke to his customer.
#
# 2 "There"
#
# 3 (I heard that as has been mentioned,) the foreinger [Steve] spoke.
#
# 4 "You must continue to go to sleep!"
#
# 80 By day ... Martins you are drunk.
#
# 1 By day ... Martins you [are] drunk!
#
# 81 He sleeps with us.
#
# 1 The foreigner sleeps.
#
# 2 (As has been mentioned,) the foreigner sleeps.
#
# 82 You will stay and sleep!
#
# 1 [You] must continue to go to sleep!
#
# 83 Well, that same night, Steves customer nearly went away.
#
# 1 Thus, [that] same night, the foreigner [Martins], the foreigner's [Steve's] customer nearly went away.
#
# 14 14 MIGIXISTI DIES.pdf Itaibigai
#
# Migixisitisi was one of the tribe leaders, a very well liked and well respected man in the village.  He was also one of the best of the language helpers.  While we were gone from the tribe once he became very ill and died.  His death was caused by some unknown sickness, and the speaker felt that if Linda had been here perhaps he could have been saved.
#
# 2 What is his sickness.
#
# 1 Is he sick?
#
# 3 Well Apais husband is already nearly dead.
#
# 1 Apai's husband [Bigixisitisi] nearly died.
#
# 4 He had the unknown sickness.
#
# 1 Did he [have] the unknown sickness?
#
# 5 Well then he was dead.
#
# 1 (I heard that) thus he was dead.
#
# 6 Not many days passed before Bigixiaitisi died.
#
# 1 Bigixisitisi died not many days ago.
#
# 7 Linda was not here.
#
# 1 Linda [was] not [here].
#
# 8 She was not here.
#
# 1 She was not [here].
#
# 9 I (the speaker) said Linda is not here.
#
# 1 Thus I [the speaker] spoke.
#
# 2 She [Linda] is not [here].
#
# 10 He is dead now.
#
# 1 He is dead now.
#
# 15 15 OPISI GETS A DOG.pdf Tisahai
#
# This story tells of a dog that Opisi found on the Marmelos. It had been left there by Martins a Brazilian trader.  Opisi and Isabi were traveling in two canoes, and Opisi wants Isabi to take the dog so it will not interupt his hunting at night.  Isabi agrees, and on the way home the dog smells a rat and puts it into a paka hole.  Isabi thought it was a paka but when they dug up the hole he found only a rat.  Itaibigai is Isabi's wife, and Toohio is their 6 year old daughter.
#
# 2 He said, "Toohio get the dog."
#
# 1 (I heard that as has been mentioned,) he [Xopisi] spoke.
#
# 2 "Toohio came again to get the animal [dog]."
#
# 3 Put the dog into the canoe.
#
# 1 (As has been mentioned,) [he] put the animal into [the canoe].
#
# 4 Martins did not remember to take the dog just now.
#
# 1 Because the foreigner Martins thus was certainly still forgetting his animal [dog].
#
# 5 He (Opisi) said, "Toohio put the dog in the canoe."
#
# 1 (I heard that as has been mentioned,) he [Xopisi] spoke.
#
# 2 "Toohio, you put the animal into [the canoe]."
#
# 6 It will also go with you.
#
# 1 (I heard that as has been mentioned,) the animal will also still be going.
#
# 7 He (Opisi) said to Isabi, "I can't hunt."
#
# 1 (I heard that as has been mentioned,) he thus spoke [to] Xisaabi.
#
# 8 Toohio, come and get the dog.
#
# 1 (I heard that as has been mentioned,) Toohio, [you] must put the animal [dog] in [the canoe].
#
# 9 Well the Brazilian forgot the dog, Opisi said.
#
# 1 Well the foreigner forgot the animal [dog].
#
# 2 (I heard that as has been mentioned,) [Xopisi] spoke.
#
# 10 Itaibigai has just put the dog in the canoe.
#
# 1 Did Xitaibigai thus certainly put the animal [dog] in [the canoe] (as has been mentioned)?
#
# 11 Opisi said, put the dog with you in the canoe.
#
# 1 (I heard that as has been mentioned,) he spoke.
#
# 2 "Put the animal away into [the canoe]."
#
# 12 Toohio you take the dog and go.
#
# 1 Toohio, go and continue to carry the animal [dog] (as I have heard and has been mentioned).
#
# 13 Well she put the dog in the canoe.
#
# 1 (I heard that as has been mentioned,) she thus put the animal [in the canoe].
#
# 14 The Brazilian should not have beat the dog.
#
# 1 Well, the foreigner mustn't beat the animal, his animal.
#
# 15 Well when the Brazilian took the dog he fell.
#
# 1 Thus the foreigner took the animal.
#
# 2 He continued to fall.
#
# 16 He wanted to grab at the dog there.
#
# 1 [He] wanted to grab at the animal there.
#
# 17 The Brazilian was going to take the dog.
#
# 1 Thus the foreigner continued tying [up the dog in order to take it] with him.
#
# 18 He left the dog.
#
# 1 [He] forgot the animal.
#
# 19 Well, just as he was taking the dog he fell.
#
# 1 Thus the foreinger took the animal.
#
# 2 [But then he] continued to fall [at that] place, that's all.
#
# 20 Opisi then put the dog in the canoe.
#
# 1 (I heard that as has been mentioned,) thus Xopisi put the animal in [the canoe].
#
# 21 Then he said, "Toohio put the dog in your canoe."
#
# 1 (As has been mentioned,) then he thus spoke.
#
# 2 "Toohio, put the animal [dog] [in your canoe.]"
#
# 22 I intend to hunt.
#
# 1 [I] intend to be hunting animals [with the] animal [dog].
#
# 23 I can't hunt with the dog.
#
# 1 Don't go hunt animals [with the] animal [dog] (as I have heard and has been mentioned).
#
# 24 Put it (dog) in the canoe with you.
#
# 1 (I heard that as has been mentioned,) he/you thus put the animal away into [the canoe with you].
#
# 25 Toohio, she put the dog in.
#
# 1 (As has been mentioned,) Toohio thus put the animal [dog] in.
#
# 26 Isabi paddled slowly.
#
# 1 Xisaabi thus paddled slowly.
#
# 27 He hunted animals.
#
# 1 He went [hunted] animals.
#
# 28 He dug up the ground for a paka.
#
# 1 (I heard that as has been mentioned,) he was digging up [the ground for a] paca [a large rodent].
#
# 29 He found a rat.
#
# 1 (I heard that as has been mentioned,) [he] found a rat.
#
# 30 Yes he returned from hunting.
#
# 1 Thus did he return [from hunting] animals (as I have heard and has been mentioned)?
#
# 31 Don't you know, is it (the dog) not here?
#
# -1 None
#
# 1 [ You] are ignorant.
#
# 2 It [the dog] is certainly not [here].
#
# 32 The dog is now with Opisi.
#
# 1 [The dog] is certainly [now] with him [Xopisi].
#
# 16 16 TRIP TO SEE A PLANE.pdf Tisahai
#
# This story was told by Tisahai to Itabigai.  Tisahai had been to Porto Velho, and had taken a trip to the airport to look at airplanes.  While there she saw soldiers and lots of Brazilians.  She and her child saw inside a jet and the steward gave them candy.
#
# 2 There are lots of big airplanes.
#
# 1 Thus, [there are] many big airplanes.
#
# 3 Toohio (her child) will he all alone with Steve went there.
#
# 1 Thus Toohio [Itaibagai's child] will also come alone with the foreigner Steve.
#
# 4 They gave Toohio lots and lots of candy.
#
# -1 None
#
# 1 Thus the foreigners gave a bunch [of] candy to Toohio.
#
# 5 Itaibigai there are big airplanes there.
#
# 1 Itaibigai, big airplanes are there.
#
# 6 There are lots of planes.
#
# 1 [There are] many airplanes.
#
# 7 Itaibigai the airplanes there are big.
#
# 1 Itaibigai, the airplanes there are big.
#
# 8 There are lots of soldiers.
#
# 1 [There are] many foreigners, soldiers.
#
# 9 Many Brazilians fight.
#
# -1 None
#
# 1 Because many foreigners, customers, fight.
#
# 10 Only Brazilians go there.
#
# 1 Only foreigners come there.
#
# 11 There are lots of soldiers.
#
# 1 [There are] many foreigners, soldiers.
#
# 12 An airplane landed there.
#
# 1 An airplane landed near him.
#
# 13 They gave all the candy to Toohio.
#
# 1 Thus the foreigners gave a bunch [of] candy to Toohio.
#
# 14 There are airplanes.
#
# 1 There [are] airplanes.
#
# 15 Inside the Brazilians gave him candy.
#
# 1 Inside [the airplane], the foreigners did [gave].
#
# 2 The foreigners gave a bunch [of] candy to him.
#
# 16 Itaibigai there are lots and lots of planes.
#
# 1 Itaibigai, many airplanes [are] there.
#
# 17 There are big jets airplanes there.
#
# 1 [There] are airplanes, big airplanes.
#
# 2 The white ones [airplanes] [are] there.
#
# 18 There is an airplane sitting path there.
#
# 1 The airplane, the foreigner's airplane, sits on the path there.
#
# 19 Itaibigai, the airplanes are big.
#
# 1 Itaibigai, the airplanes [are] big.
#
# 17 17 PORTO VELHO IS BIG.pdf Tisahai
#
# Tisahai and her husband Apibai were in Porto Velho attending a workshop when this story was told.  She was sending it as a letter to others back in the village to tell them some of her impressions.
#
# 2 Itaibigai, he (Steve) again bought lots of fish.
#
# 1 Itaibigai, the foreigner [Steve] again wanted to do [buy] much [fish].
#
# 3 Yes he just now bought a great deal of fish.
#
# 1 Thus the foreigner [bought] much animal/fish [meat].
#
# 2 He certainly wanted/bought animal/fish [meat].
#
# 4 Itaibigai, it was not just a little bit.
#
# 1 Itaibigai, [it] was not a little bit [of fish].
#
# 5 You must go see Porto Velho.
#
# 1 You [must] see Porto Velho there!
#
# 6 When Steve buys, he really buys a lot of it.
#
# 1 [When] the foreigner [is there].
#
# 2 Thus the foreigner certainly buys animal [meat], a lot of it.
#
# 7 Steve also buys farinha.
#
# 1 The foreigner [Steve] also certainly wants to ?? [buy] farinha [from him/them].
#
# 8 Steve does not go hungry.
#
# 1 The foreigner [Steve] does.
#
# 2 The foreigner [Steve] does.
#
# 3 [He] does not hunger.
#
# 9 I almost won't go back.
#
# 1 [I] nearly won't return!
#
# 10 Itaibigai, there are lots of Brazilians.
#
# 1 Itaibigai, [there are] many foreigners
#
# 11 Go and see the Brazilians.
#
# 1 You look at the foreigners there.
#
# 12 There are so many Brazilians.
#
# 1 Many foreigners are [there].
#
# 2 (As has been mentioned,) [there are] many foreigners.
#
# 13 You haven't seen the Brazilians.
#
# 1 [You] certainly haven't seen the foreigners.
#
# 14 There are many Brazilians.
#
# 1 [There are] many foreigners.
#
# 15 Go see them.
#
# 1 [You] see the foreigners there.
#
# 16 Itaibigai there are many Brazilians.
#
# 1 Itaibigai, many foreigners [are there], certainly.
#
# 17 There are many Brazilian houses at Porto Velho.
#
# 1 Many foreigner's houses are at Porto Velho.
#
# 18 There are many Brazilians.
#
# 1 (As has been mentioned,) [there are] many foreigners.
#
# 19 You have not seen the Brazilians.
#
# 1 [You] have not seen the foreigners.

# %% [markdown]
# ### TODO
# - Check code so far
# - Put in pandas dataframe

# %% [markdown]
# ## TODO
# - Check overview
# - The word order in Pirahã is predominantly verb-final, with subjects (S) usually preceding objects (O) for a predominantly SOV word order
# - For example, if the subject intervened between the object and the verb (as in an OSV order), the object was labeled as a topic-obj. Similarly, noun phrases appearing after the verb were labeled as topics
# - We used labels similar to the Penn Treebank labels for syntactic categories [40]: NP (noun phrase); IN (adposition); PP (adpositional phrase); VP (verb phrase); S (sentence); NN (a common noun); PRP (pronoun); NNP (proper noun); POS (possessive NP); JJ (adjective); DT (determiner); CD (quantity term); RB (adverb); FW (foreign word); FRAG (fragment). We also introduced the symbol Q dominating the contents of direct speech reports
# - Use [this](https://github.com/wroberts/nltk_tgrep) for parsing trees.
# - Can download files [here](https://osf.io/kt2e8/) too.
# - Note that in this corpus high tones are marked with a capitalized letter.
# - 1149 sentences, with an average of 5.9 words per sentence. But also contains original sentence boundaries, making 749 sentences.
# - Shallow POS was added, and grammatical relations (subject, object, indirect object, locative, temporal, instrumental, vocative, topic)
