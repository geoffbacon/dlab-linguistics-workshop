# %% [markdown]
# # Pirahã syntax
#
# In this notebook we are going to explore Pirahã syntax. As you know, Pirahã is (in)famous in the field of linguistics for many reasons. One of the most prominent claims made about the language is a lack of syntactic recursion. Futrell et al. (2016) analyze a corpus of Pirahã for evidence of syntactic embedding. They report that they do not find any such evidence, and that the corpus is consistent with an analysis of Pirahã as a [regular language](https://en.wikipedia.org/wiki/Regular_language). If you want to know more about Pirahã and the controversy surrounding it, read the following:
#
# - Everett, Daniel L. "Pirahã culture and grammar: a response to some criticisms." Language 85.2 (2009): 405-442.
# - Everett, Daniel, et al. "Cultural constraints on grammar and cognition in Piraha: Another look at the design features of human language." Current anthropology 46.4 (2005): 621-646.
# - Frank, Michael C., et al. "Number as a cognitive technology: Evidence from Pirahã language and cognition." Cognition 108.3 (2008): 819-824.
# - Futrell, Richard, et al. "A corpus investigation of syntactic embedding in Pirahã." PloS one 11.3 (2016): e0145289.
# - Nevins, Andrew, David Pesetsky, and Cilene Rodrigues. "Pirahã exceptionality: A reassessment." Language 85.2 (2009): 355-404.
#
# Throughout all the notebooks of this workshop, we're not going to be concerned with whether the arguments are right or wrong. Rather, we care about practising our Python skills so that we can do similar linguistic analyses. In particular, in this notebook we're going to practice the following topics:
#
# ### Core ideas of this notebook
# - Object types
# - Manipulating text data
# - Regular expressions
# - User-defined functions
# - Writing modular code
# - Documentation
# - Going from messy to structured data
# - Using other people's code
#
#
# ### Our goal
# We want to turn <a href="data/piraha.txt">this</a> into this:
#
#
# |story_num|speaker|                fname                 |utt_num|                               utt_translation                               |sent_num|                                   words                                   |                 sent_translation                  |
# |--------:|-------|--------------------------------------|------:|-----------------------------------------------------------------------------|-------:|---------------------------------------------------------------------------|---------------------------------------------------|
# |        1|Aogioso|01_KATO'S BABY FALLS NEAR THE FIRE.pdf|      1|Early in the day I spoke. BaIgipOhoasi spoke (carried sound). Is Kato sleepy?|       1|['ti', 'xahoa', '-gI', 'ti', 'iga', 'O', '-p', '-I', '-xi']|[Early in the] day I spoke.                        |
# |        1|Aogioso|01_KATO'S BABY FALLS NEAR THE FIRE.pdf|      1|Early in the day I spoke. BaIgipOhoasi spoke (carried sound). Is Kato sleepy?|       2|['hi', 'igA', 'xai', 'baIgipOhoasi']       |BaIgipOhoasi [speaker's sister] spoke.             |
# |        1|Aogioso|01_KATO'S BABY FALLS NEAR THE FIRE.pdf|      1|Early in the day I spoke. BaIgipOhoasi spoke (carried sound). Is Kato sleepy?|       3|['KatO', 'hi', 'o', '*', '-b', '-a', '-p', '-I', '-aag', '-oxoihI', 'KatO']|Is Kato sleepy?"  [Lit: "Kato-- her eyes flutter?"]|
# |        1|Aogioso|01_KATO'S BABY FALLS NEAR THE FIRE.pdf|      2|He (TixohOI) fell by the fire.                                               |       1|['hi', 'hoaI', 'ib', '-a', '-b', '-og', '-aA']|He [TixohOI, KatO's baby] almost fell in the fire. |
# |        1|Aogioso|01_KATO'S BABY FALLS NEAR THE FIRE.pdf|      3|I spoke (carried sound). TixohOI is crying on the ground                     |       1|['ti', 'igA', 'xai', '-ai']                         |I spoke!                                           |

# %% [markdown]
# ## Data
#
# The corpus used in the paper consists of Pirahã stories that were originally collected and translated by Steve Sheldon and Dan Everett over the period of several decades. It also includes aligned translation between Pirahã
# and English, including shallow syntactic parses and approximate English glosses.
#
# Here's how the authors describe the way they created the corpus:
# > We obtained glossed transcriptions of 17 stories in Pirahã, consisting of a total of 1149 sentences
# and 6830 words in our analysis. 13 of the stories were collected by Steve Sheldon in the
# 1970s, and the remaining 4 stories were collected by Dan Everett over the period 1980–2009.
# Each story was told by a single speaker with no recorded interruptions. The stories were transcribed
# by Everett or Sheldon; audio recordings are only available for stories 2 and 3. According
# to Everett, the texts are fairly representative of how the Pirahã tell stories to one another.
#
# If you're interested, you can see all the original texts in pdf format [here](https://github.com/languageMIT/piraha/tree/master/sources).

# %% [markdown]
# ### Downloading the data
#
# Futrell et al. make their data [available](https://github.com/languageMIT/piraha), but I've already downloaded it for you. In the `data` folder there's a file called `piraha.txt`.

# %% [markdown]
# ### Structure of the data
#
# Although it's great that the data is made freely available, it's in a really messy format. It's going to take some preprocessing for us to reformat the data into a more usable form. Here's the description from the [README](https://github.com/languageMIT/piraha/blob/master/README.md) of how the corpus is structured:
#
# > Each text in the corpus is preceded by three lines of hashes and information about the source of the text. The corpus is divided into stories; stories are divided into "utterances"; and utterances are divided into sentences. Utterances correspond to the sentence breaks in Steve Sheldon's original glosses. Each utterance is preceded by two English glosses (free translations). The first is labeled with a hash and a code of two numbers, and reflects the English translation given by Steve Sheldon or Daniel L. Everett in their original translation. The second is labeled with a hash and a code of three numbers, and reflects the current best translation, as judged by Daniel L. Everett, Steve Sheldon, and the other authors. Clarifications are provided in square brackets in these glosses. The glosses allow simple text searching to find rough equivalents of English words and phrases (e.g. what does Pirahã use to convey meanings glossed as "and"?).
#
# > Each Pirahã sentence is labeled with a unique code of three numbers, appearing on the preceding line along with its current best English translation. The first number indicates the text in which the utterance appears. The second number indicates the utterance's sequential placement within the text. This second number reflects the utterance boundaries present in the original transcriptions (e.g. by Dan Everett and Steve Sheldon). In many cases, text which was originally translated into a single utterance actually includes a group of Pirahã sentences according to our current best translations. When this occurs, the third number indicates the order of the Pirahã sentences within this grouping. Otherwise, the third number is simply 1.
#
# Here's my simplification of it:
#
# - The corpus is all in one file, `piraha.txt`.
# - There are 17 stories in the corpus. They are separated from one another by three lines of hashtags.
# - Each story starts with three pieces of metadata: the source, the informant and the comment.
# - The source holds the names of the original pdf files of the story and the story number.
# - The informant is the speaker (for most stories there's only one speaker).
# - The comment holds various other things, like background, summary of the story, etc.
# - After the metadata, each story has a series of utterances. Utterances are the original sentence boundaries given by either Everett or Sheldon. Each utterance has a number within the story (e.g. 4.16 for utterance number 16 in story number 4). Immediately after the numeric identifier comes the original English translation of the utterance.
# - However, Sheldon and Everett have re-analyzed many utterances to in fact consist of more than one sentence. So each utterance actually consists of one or more sentences. Each sentence is identified by the story number, utterance number and sentence number (so 4.16.2 is the 2nd sentence of the 16th utterance of the 4th text). Immediately after each numeric identifier of a sentence is a shallow parse tree.

# %% [markdown]
# ### Reading in data in Python
#
# The main way to read in data in Python is to use the `open` function. The `open` function is always available as soon as you start Python (whether from a Jupyter notebook, an interactive session from the terminal, in IDLE, or in Sypder).

# %% [markdown]
# ###  1. Read in the data
# _Hint: It's sorted in a file called 'piraha.txt' in a folder called 'data'._

# %%
### FILL IN THE BLANKS
fname = 'data/piraha.txt'
with open(fname, 'r') as f:
    raw_text = f.read()

# %% [markdown]
# - What type is `fname`?
# - What type is `open(fname)`?
# - Can you access the opened file after the `with` statement?
# - Old school way of opening files
# - Joining paths together
# - Finding the type of a file
# - Reading in files line by line
# - Read Python docs for [open](https://docs.python.org/3/library/functions.html) and [os.path](https://docs.python.org/3/library/os.path.html)

# %% [markdown]
# ### 2. Split `raw_text` into individual stories
#
# _Hint: Each text is separated by a special string. Use that special string to turn the raw text into a list of stories called `stories`._

# %%
### FILL IN THE BLANKS
text_boundary = '''############################################################################################################################################ 
############################################################################################################################################ 
############################################################################################################################################'''
stories = raw_text.split(text_boundary)[1:]
stories = [story.strip() for story in stories]

# %% [markdown]
# - What type is `stories`?
# - How can you get the first story?
# - What type is each story?
# - How can you get the first 100 characters of the seventh story?
# - What does `strip()` [do](https://docs.python.org/3.6/library/stdtypes.html#text-sequence-type-str)?

# %% [markdown]
# ### 3. Turn what you just did in 2 into a function

# %%
def split_stories(text):
    """Return all the stories in `text`.
    
    Parameters
    ----------
    text : str
        The raw text of the corpus
    
    Returns
    -------
    stories: list(str)
    """
    text_boundary = '''############################################################################################################################################ 
############################################################################################################################################ 
############################################################################################################################################'''
    stories = text.split(text_boundary)[1:]
    return [story.strip() for story in stories]

stories = split_stories(raw_text)
story = stories[3]

# %% [markdown]
# - Does the function `split_stories`'s parameter have the name you gave it?
# - Do user-defined functions have to have parameters?
# - If you forget the `return` statement, what does the function return?
# - Why do we bother ever defining functions?
# - Lambda functions
# - Higher-order functions (e.g. for `sorted`)

# %% [markdown]
# ### 4. Import the library for regular expressions in Python

# %%
### FILL IN THE BLANKS
import re

# %% [markdown]
# - Why do we have to import libraries at all? Wouldn't it be easier if everything was immediately available like the `open` function is?
# - What type is the module?
# - What if we really wanted to have our own variable with the same name as a library we import? Won't their names clash?

# %% [markdown]
# ### 5. Extract the story number from a story
#
# _Hint: Look in `piraha.txt` to see that a story's number is stored on the line that starts with "# SOURCE". What is the regular expression for a single digit?_

# %%
match = re.search(r'# SOURCE: (\d+)', story)
if match:
    number = match.group(1)
    number = int(number)
else:
    number = -1

# %% [markdown]
# - How do we access the function called `search` in the `re` module?
# - What if we had imported everything from the `re` module like this: `from re import *`?
# - What parameters does the `search` function take?
# - What's the difference between `search` and `match`?
# - What type of object does the `re.search` function return if it does find a match? What if it doesn't?
# - How can I turn something of type `int` into a string? How can I turn a string into an integer?
# - Use [pythex](https://pythex.org/) to check your regexes
# - Compiling regexes in Python

# %% [markdown]
# ### 6. Now turn what you did in 5 into a function

# %%
### FILL IN THE BLANKS
def story_number(story):
    """Extract the number of `story`.
    
    Parameters
    ----------
    story : str
    
    Returns
    -------
    number: int
        The position of the story in the corpus
    """
    match = re.search(r'# SOURCE: (\d+)', story)
    if match:
        number = match.group(1)
        number = int(number)
        return number
    else:
        return -1

# %% [markdown]
# - What type is `story_number`?
# - Function documentation

# %% [markdown]
# ### 7. Define functions for extracting the filename, speaker and comment from a story
#
# _Hint: The filename is stored on the same line as the story number. The speaker and comment are stored in a similar fashion. You'll need to look at the file to see exactly what regex to use._

# %%
### FILL IN THE BLANKS
def story_filename(story):
    """Extract the original pdf filename of `story`.
    
    Parameters
    ----------
    story : str
    
    Returns
    -------
    filename: str
    """
    match = re.search(r'# SOURCE: .*, (.*.*\.pdf)', story)
    if match:
        filename = match.group(1)
        return filename
    return None

# %%
### FILL IN THE BLANKS
def story_informant(story):
    """Extract the name of the speaker of `story`.
    
    Parameters
    ----------
    story : str
    
    Returns
    -------
    name: str
    """
    speaker_pattern = re.compile(r'# INFORMANT: (.*)\n')
    match = re.search(speaker_pattern, story)
    if match:
        return match.group(1)
    return None

# %%
### FILL IN THE BLANKS
def story_comment(story):
    """_____"""
    speaker_pattern = re.compile(r'# COMMENT: (.*)\n')
    match = re.search(speaker_pattern, story)
    if match:
        return match.group(1)
    return None

# %% [markdown]
# ### 8. Split a story into a list of its utterances
#
# _Hint: Looking at the file 'piraha.txt' again, note that within each story, there are blocks of data separated by newlines. Each block is an utterance. We want a function that takes in a story (what type will this be?) and returns a list of utterances (i.e. a list of those blocks). A newline is represented as the sequence '\n' in Python._

# %%
def split_utterances(story):
    """Return all the utterances in `story`.
    
    Parameters
    ----------
    story : str
        The raw text of a story
    
    Returns
    -------
    utterances: list(str)
    """
    utterance_boundary = '\n\n'
    utterances = story.split(utterance_boundary)[1:]
    first_utterance = utterances[0]
    if first_utterance.startswith('### NOTE'):
        first_utterance = re.sub('### NOTE.*\n', '', first_utterance)
    utterances = [first_utterance] + utterances[1:]
    return utterances

# %% [markdown]
# - If '\n' is a newline, what is a tab?

# %% [markdown]
# ### 9. Extract the utterance number and the translation
#
# _Hint: In an utterance, the first line always consists of the number and the translation (in English). The number is of the form "x.y", where "x" is the story number, and "y" is the utterance number (we just want the utterance number). The translation is everything after the ":" after the number._

# %%
def utterance_number(utt):
    """Extract the number of `utt`.
    
    Parameters
    ----------
    utt : str
        An utterance

    Returns
    -------
    number: int
        The position of the utterance in the story
    """
    match = re.search(r'(\d+\.\d+):', utt)
    if match:
        whole_number = match.group(1)
        number = whole_number.split('.')[1]
        number = int(number)
        return number
    return -1

# %%
def utterance_translation(utt):
    """Extract the (original) translation of `utt`.
    
    Parameters
    ----------
    utt : str
        An utterance

    Returns
    -------
    translation: str
        The translation of the utterance
    """
    match = re.search(r'(\d+\.\d+): (.*)', utt)
    if match:
        translation = match.group(2)
        return translation
    return None

# %% [markdown]
# ### 10. Split an utterance into its sentences
#
# _Hint: Within an utterance, after the first line containing the number of English translation, there are one or more sentences. We want a function to takes an utterance and returns a list of sentences._

# %%
def split_sentences(utt):
    """Return all the sentences in `utterance`.
    
    Parameters
    ----------
    utt : str
        The raw text of an utterance
    
    Returns
    -------
    sentences: list(str)
    """
    all_sentences = re.sub(r'(# \d+\.\d+): (.*)', '', utt).strip()
    sentences = re.split(r'(?: ^|\n)# ', all_sentences)
    return sentences

# %% [markdown]
# ### 11. Extract the sentence number and translation
#
# _Hint: Every sentence starts with the number in the form of "x.y.z", where "x" is the story number, "y" is the utterance number, and "z" is the sentence number._

# %%
def sentence_number(sent):
    """Extract the number of `sent`.
    
    Parameters
    ----------
    sent : str
        A sentence

    Returns
    -------
    number: int
        The position of the sentence in the utterance
    """
    match = re.search(r'(\d+\.\d+\.\d+):', sent)
    if match:
        whole_number = match.group(1)
        number = whole_number.split('.')[2]
        number = int(number)
        return number
    return -1

# %%
def sentence_translation(sent):
    """Extract the translation of `sent`.
    
    Parameters
    ----------
    sent : str
        An utterance

    Returns
    -------
    translation: str
        The translation of the sent
    """
    match = re.search(r'(\d+\.\d+\.\d+): (.*)', sent)
    if match:
        translation = match.group(2)
        return translation
    return None

# %% [markdown]
# ### Sentence trees
#
# _Hint: This part is nuanced, so don't worry about following every single detail for the time being. The core concepts we should focus on are `try/except` clauses and using other people's code._

# %%
from nltk.tree import ParentedTree
from nltk.tgrep import tgrep_nodes, tgrep_positions

# %%
def sentence_tree(sent):
    """Extract the tree of `sent`.
    
    Parameters
    ----------
    sent : str

    Returns
    -------
    tree: str
    """
    try:
        non_tree_pattern = re.compile(r'(?:# )?\d+\.\d+(\.\d+)?: .*')
        tree = re.sub(non_tree_pattern, '', sent).strip()
        tree = re.sub(r'#.*', '', tree).strip()
        return ParentedTree.fromstring(tree)
    except ValueError:
        return None

# %%
def words_from_tree(t):
    """Return list of words from tree `t`."""
    if t:
        return [leaf.split('/')[0] for leaf in t.leaves()]
    else:
        return None

# %% [markdown]
# ### Putting the pieces together
#
# Now, we have functions that can extract the relevant information from the data. We don't really want to have to extract a particular piece of information out every time we're interested in it (i.e. when we're asking questions like "Do the different speakers in the corpus use this word differently?"). We want to do it once, and then work with the extracted data. We also want a way of linking data from the same sentence together. That is, for every sentence in the corpus, we'd like to be able to know who the speaker is, what the words are, what story it came from, etc. In the olden days, this was how we did that:

# %%
sentences = []
for story in split_stories(raw_text):
    for utterance in split_utterances(story):
        for sentence in split_sentences(utterance):
            dictionary = {}
            dictionary['story_num'] = story_number(story)
            dictionary['fname'] = story_filename(story)
            dictionary['speaker'] = story_informant(story)
            #dictionary['comment'] = story_comment(story)
            dictionary['utt_num'] = utterance_number(utterance)
            dictionary['utt_translation'] = utterance_translation(utterance)
            dictionary['sent_num'] = sentence_number(sentence)
            dictionary['sent_translation'] = sentence_translation(sentence)
            #dictionary['sent_tree'] = sentence_tree(sentence)
            dictionary['words'] = words_from_tree(sentence_tree(sentence))
            sentences.append(dictionary)

# %% [markdown]
# - What type is `sentences`?
# - What type is `sentences[0]`?
# - What type is `sentences[0]['words']`?
# - What type is `sentences[0]['words'][0]`?
# - What type is `sentences[0]['words'][0][0]`?

# %% [markdown]
# ### 12. Get a list of all the sentences
#
# _Hint: Each sentence is a list of strings, so what we want is a list of lists of strings._

# %%
[s['words'] for s in sentences]
# Out:
# [['ti', 'xahoa', '-gI', 'ti', 'iga', 'O', '-p', '-I', '-xi'],
#  ['hi', 'igA', 'xai', 'baIgipOhoasi'],
#  ['KatO', 'hi', 'o', '*', '-b', '-a', '-p', '-I', '-aag', '-oxoihI', 'KatO'],
#  ['hi', 'hoaI', 'ib', '-a', '-b', '-og', '-aA'],
#  ['ti', 'igA', 'xai', '-ai'],
#  ['hi', 'big', 'a', '-I'],
#  ['*', 'is', '-Aaga', '-haI', 'TixohOI'],
#  ['*', 'hoaI', '*', '-b', '-o', '-i', '-hI', 'pixAi', '-xIga'],
#  ['ti', 'xaigIA', 'igA', 'xai', '-ai', 'xaI', 'Xopisi'],
#  ['hi', 'o', '-b', '-a', '-hohI', 'pixAi', '-xIga', 'TixohOI'],
#  ['*', 'hoai', 'Is', '-aagA', '-haI'],
#  ['hi', 'o', '-b', '-a', '-hoi', '-hI', 'pixAi', '-xIga'],
#  ['ti', 'xaigIa', 'igA', 'xai', '-ai'],
#  ['xaI', 'ti', 'aigIa', 'hi', 'xoi', '-si', 'kaop', '-aI'],
#  ['hi', 'Ao', 'big', '*', '-o', '-b', 'Ao', '-p', '-aI', '-xai'],
#  ['ti', 'xaigIa', 'igA', 'xai', '-aI'],
#  ['xopIsi',
#   'hi',
#   'o',
#   '*',
#   '-b',
#   'a',
#   '-p',
#   '-I',
#   '-aag',
#   '-ag',
#   '-i',
#   '-sahaxaI'],
#  ['*', 'hoaI', '*', '-b', '-O', '-i', '-hI', 'pixAi', '-xIga'],
#  ['hI', 'O', '-b', '-a', '-hoihI'],
#  ['xigaOxixaihoai', 'hi', 'aigIa', 'igA', 'xai', '-haxA'],
#  ['katO', 'hi', 'o', '*', '-b', '-a', '-p', '-I', '-ai', '-hI'],
#  ['gIxai', 'piihI', 'hOi', '-kOoI', 'pixAi', '-xIga', 'hoaI', '*'],
#  ['hi', 'aigIa', 'igA', 'xai'],
#  ['xahaig', 'OtI', '-ha', 'xaI'],
#  ['hi', 'igA', 'xai', '-xai'],
#  ['*', 'hoaI', '-b', '-O', '-i', '-hI'],
#  ['*', 'hoaI', '-b', '-O', '-i', '-hI', 'pixAi', '-xIga'],
#  ['hi', 'o', '-b', '-a', '-hoihI', 'tixohOI'],
#  ['*', 'hoaI', 'is', '-Aaga', '-haI'],
#  ['tIi', 'xaigIa', 'igA', 'xai', '-ai'],
#  ['xaI', 'xopIsi', 'hi', 'o', '-b', '-a', '-hoihI', 'pixAi', '-xIga'],
#  ['xaI', 'xoI', 'hi', 'aigIa', 'ahaig', 'Oti', '*', '-haxA'],
#  ['xoI', 'hi', 'igA', 'xai', '-xi'],
#  ['hoagaixoxai', 'hi', 'o', '*', '-b', '-a', '-p', '-I', 'ai', '-hI'],
#  ['gIxai', 'xigihI', '*'],
#  ['hi', 'hoA', 'xo', 'Agi', '-ti', '-ig', '-o', '-p', '-i', '-haiba', '-haI'],
#  ['hi', 'big', '-O', '*'],
#  ['hi', 'biIi', '-gi', '-O', '*'],
#  ['hi', 'go', '-O', '*'],
#  ['ti', 'Oo', '-s', 'aaga'],
#  ['*', 'bAas', 'A', '-p', '-ai', 'go', '-O', '-hA'],
#  ['kos', 'ai', 'gAi', 'big', '-O'],
#  ['kos', 'ai', 'gAi', 'big', '-O'],
#  ['xaI', 'ti', 'aigIa', 'hI', 'Xoi', 'kaob', '-Ibai', 'katO'],
#  ['ti', 'xi', 'osibAop', '-Abag', '-aO'],
#  ['xigIa', '*', 'igA', 'xai'],
#  ['katO', 'hi', 'o', '*', '-b', '-a', '-p', '-I', '-a'],
#  ['katO',
#   'ti',
#   'xaigIa',
#   'ib',
#   '-A',
#   '-b',
#   '-o',
#   '-I',
#   '-ta',
#   '-g',
#   '-ab',
#   '-AbagaI'],
#  ['hi', 'o', '*', '-b', '-a', '-p', '-I', '-o', 'aI', '-hI'],
#  ['ti', 'aigIa', 'hi', 'xoa', '-o', '-p', 'aI', '-xai'],
#  ['xopIsi', 'hi', 'aigIa', 'igA', 'xai', '-hI'],
#  ['katO', 'hi', 'o', '*', '-b', '-a', '-p', '-I', '-bAaI'],
#  ['xi',
#   'hi',
#   'xoA',
#   'gi',
#   '-ti',
#   '-ig',
#   '-A',
#   '-o',
#   '-p',
#   '-I',
#   '-hiaba',
#   '-haI'],
#  ['ti', 'aigIa', 'hi', 'o', 'ah', '-A', '-p', '-i', '-ta', '-I'],
#  ['*', 'hI', 'xoI', '-si', 'kaop', '-aI'],
#  ['hi', 'O', '-b', '-o', '-i'],
#  ['hi', 'ai', '-hI', 'baOsaI'],
#  ['hi', 'O', '-xai'],
#  ['xi', 'xai'],
#  ['hi', 'O', '-xai'],
#  ['hi', 'O', '-xaagA'],
#  ['xigaOxixaihoAi',
#   'hi',
#   'aigIa',
#   'ti',
#   'Ahai',
#   'xoa',
#   '*',
#   '-O',
#   '-p',
#   'a',
#   '-hA',
#   'bAIgipOhoasi'],
#  ['ti', 'igA', 'xai'],
#  ['*', 'xaOpI', '*', '-so'],
#  ['xahaig', 'OtI', '*', '-sai', '-haxA'],
#  ['hi', 'igA', 'xai'],
#  ['xaI',
#   'hoagaIxOxaI',
#   'hi',
#   'o',
#   '*',
#   '-b',
#   '-a',
#   '-p',
#   '-i',
#   '-baA',
#   '-xaO',
#   '-xoi',
#   '-hI'],
#  ['hoagI', 'hi', 'xo', 'Agi', '-ti', '-g', '-o', '-p', '-i', '-hiaba', '-haI'],
#  ['xI', 'sa', '-ha', '-xaI'],
#  ['ti', 'xaigIa', 'xoa', '*', '-O', '-p', '-a', '-i', 'xai'],
#  ['ti', 'igA', 'xai', '-aI'],
#  ['tixohOI', 'big', 'aI', 'is', '-Aaga', '-haI'],
#  ['xIbohoi', 'hi', 'ig', 'ap', '-o', '-p', '-I', '-sai', '-xI'],
#  ['hi', 'go', '-O', '-xio', 'tiaos', 'ai'],
#  ['i', 'go', '-O', '-xio', '*'],
#  None,
#  ['hi', 'aigIa', 'gAi', '*'],
#  ['hi', 'igAi'],
#  ['big', '-O', 'apaO', '*', '-sai', 'i', 'bas', '-Apa', '-O', '-xio'],
#  ['hi', 'gI', 'big', '*', '-o', '-p', '-i', '-hI', '-xigI'],
#  ['hi', 'aigIa', 'hoagaixoOxai', 'hi', '-gI', 'ti', 'aobab', '-aO'],
#  ['kAgi', 'hi', 'o', '-s', 'ib', '-Ao', '-p', '-Abai', '-ha', '-xAi'],
#  ['*', 'kagihi', '-gI', 'ao', 'Ib', '-I', '-sahaxaI'],
#  ['tIi', 'hi', 'gIxa', 'otI', '*', '-saa', '-hA'],
#  ['*', 'xabaxaI', 'hi', 'xo', '-aO', '-p', '-aI'],
#  ['ti', 'xaigIa', 'katO', 'hi', 'xO', '-p', '-I'],
#  ['hi', 'big', 'aI'],
#  ['*', 'xis', '-Aaga', '-haI'],
#  ['xi', 'higIhi', 'aab', '-O', '-p', '-I', '-sai', '-xo', '-Ai'],
#  ['ti', 'xaigIa', 'hi', 'xo', '-aO', '*', '-p', '-ao'],
#  ['*', 'gA', 'xai', '-ai'],
#  ['toIao', 'hi', 'go', '-g', '-i', '-aI', 'sito', '-aO', '-p', '-i', '-hI'],
#  ['toIao', 'hi', 'o', '-b', '-A', '-hoIsOi', '-xAi', '-hI', 'pixAi', '-xIga'],
#  ['xaI', 'xopIsi', 'hi', 'aigIa', 'ko', 'k', 'ah', '-A', '-p', '-i'],
#  ['xaI', 'hi', 'aigIa', 'ti', 'igA', 'xai'],
#  ['*', 'xaopI', '*', '-so'],
#  ['ti', 'gA', 'xai'],
#  ['*', 'xaopI', '*', '-so'],
#  ['*', 'xaopI', '*', '-ha'],
#  ['*', 'xAi', 'xo', '-aab', '-a', '-b', '-aO'],
#  None,
#  ['xoii', 'hi', 'aigIa', 'hi', 'Ahaig', '-O', 'kagi', 'otI', '*', '-haI'],
#  ['xoii', 'hi', 'aigIa', 'gA', '-sai', '-hIai', '-aI'],
#  ['*', 'xI', 'oho', '-ab', '-a', '-haI', 'pixAi', '-xIga'],
#  ['*', 'xIo', '-si', 'ib', '-i', '-haI'],
#  ['his', 'Ai'],
#  ['hi', 'aigIa', 'igA', 'xai', 'xoii'],
#  ['hi', 'aigIa', 'igA', '-sai'],
#  ['*', 'i', 'oho', '-i', '-haI', 'pixai', '-xIga'],
#  ['*', 'goi', 'xIo', '-si', 'ib', '-i', '-haI'],
#  ['*', '*', 'ig', '*', '-I', '-a'],
#  ['*', 'ito', '-ii', 'ib', '-i', '-ab', '-aI', '-haI'],
#  ['Is', 'aI', '-ha', '-xa', '-xaI'],
#  ['hi', 'aigIa', 'tihoa', 'xoA', 'O', '-p', '-i', '-so'],
#  ['*', 'gA', 'xai', '-ha', '-xa'],
#  ['i', 'i', 'o', '-pa', '*', '-b', '-a', '-p', '-i', '-hi', '-xOixi'],
#  ['xIbigaI', '-si', 'is', 'ai', '-hI', '-xoI', '-koI'],
#  ['is', 'Aag', '-i', '-so'],
#  None,
#  ['hi', 't', '-ab', '-i', '-si'],
#  ['*', 'xigiAbi', '-so'],
#  ['hi', '-o', 's', 'ib', '-Ao', '-b', '-AbagaI'],
#  ['*', 'xagao', 'aag', '-i', '-sai'],
#  None,
#  ['hi', 'o', '-s', 'ai', '-si'],
#  ['*', 'xaab', 'A', '-hA'],
#  ['hi',
#   'aigIa',
#   'xoii',
#   'hi',
#   'aigIa',
#   'kagI',
#   'otI',
#   '*',
#   '-sai',
#   '-ha',
#   '-xa',
#   'xaI'],
#  ['*', 'xaotI'],
#  ['*', 'big', '-O', 'hoaga', 'It', '-a', '-o', '-p', '-i', '-sahaxaI'],
#  ['ti', 'gA', 'xai', '-s', '-o', '-p', '-aI'],
#  ['hi', 'o', '-b', '-a', '-hoi', '-hI', 'pixAi', '-xIga'],
#  ['hi',
#   'so',
#   'xOgi',
#   '-O',
#   'bo',
#   '-g',
#   '-A',
#   '-ha',
#   '-taIo',
#   'so',
#   'xOgi',
#   '-O'],
#  ['hi', 'aigIa', 'i', 'AbahIooi', 'a', '-hA', '-xai'],
#  ['baOsa', 'Oxiai', '*', '-hi'],
#  ['ti', 'xaigIa', 'big', '-O', 'i', 'ahoa', '-o', '-p', '-Abag', '-aO'],
#  ['*', 'hi', 'xoA', 'O', '-p', 'ai', '-xai'],
#  ['xitaIoi', 'hi', 'aigIa', 'gA', 'xai', '-ha'],
#  ['katO', 'hi', 'o', '*', '-b', '-a', '-p', '-I', 'ai'],
#  ['xi', 'gIa', 'oa', '-s', 'aga', '-I'],
#  ['*', 'xit', '-ab', '-i', '-koI'],
#  ['hoagaixoOxai',
#   'hi',
#   'aigIa',
#   'I',
#   'kagi',
#   'hi',
#   'o',
#   'siib',
#   '-A',
#   '-o',
#   '-p',
#   '-Abai',
#   '-xi'],
#  ['xI', 'kagihi', 'gIxa', '*', '-o', 'Ib', '-I', '-sahaAi'],
#  ['*', 'taIgA', '-hoI', '-ta', '-hA'],
#  ['a', 'kagi', 'hi', 'o', 'siib', '-i', '-hiab', '-aO'],
#  ['ti', 'xaigIa', 'hI', 'xoA', 'O', '-p', 'ai', '-xai'],
#  ['ti', 'xaigIa', 'gA', 'xai'],
#  ['xopIsi', 'o', '-b', '-a', '-hoi', '-hI', 'pixAi', '-xIga'],
#  ['*', 'hoa', '-O', 'bOi', '-hI', 'pixAi', '-xIga'],
#  ['*', 'gA', 'o', '-p', '-aO'],
#  ['*', 'hi', 'xoA', 'o', '-p', 'aI'],
#  ['*', 'hi', 'gA', '*', '-b', '-ab', 'ai', '-xai'],
#  ['hi', 's', '-Ab', '-aO'],
#  ['*', 'xaitA', '-iIg', '-A', '-a', '-hoI', '-ta', '-haI'],
#  None,
#  ['*', 'bog', '*', '-aO'],
#  ['*', 'hiisI', '-hiab', '-aO'],
#  ['*', 'sa', '-ab', '-A', '-xai', '-xAi'],
#  ['tIi', 'gIxai', 'xoA', 'o', '-p', '-i', '-sai'],
#  ['xopIsi', 'hi', 'aigIa', 'ka', 'Ot', 'Agi', 'tig', '-a', '-o', '-p', '-aO'],
#  ['*', 'xaitA', '-o', '-b', '-I', '-ta', '-hA', '-xai'],
#  ['hi', 'aigIa', 'hoagaIxoxaI', 'ip', '-o', '-p', '-aO'],
#  ['tIi', 'gA', 'xai', '-a', '-o', '-p', '-i', '-so'],
#  ['hoagaIxoxaI', '*', 'hoaI', 'bOi', '-hI'],
#  ['hi', 'o', '*', '-b', '-a', '-p', '-i', 'aag', '-ab', '-i', '-hI'],
#  ['hi', 'o', '*', '-b', '-a', '-p', '-i', 'aag', '-ab', '-i', '-sahaxaI'],
#  ['*', 'hoaI', 'bOi', '-hI'],
#  ['hi', 'O', '-s', 'aa', '-hiab', '-a', '-hAxai'],
#  ['xi', 'O', '-s', 'aa', '-hiab', '-aO'],
#  ['*', 'big', '-O', 'ahoAtI', 'ohoa', '*', '-hAxai'],
#  ['tIi', 'xibigaI', '-si', 'hi', '-gI', 'oA', 'O', '-p', 'ai', '-xai'],
#  ['tIi', 'xaigIa', 'gA', 'xai', '-ai', '-aI'],
#  ['tixohOI', 'big', '-O', 'hi', 'o', '-p', '-i', '-hI', 'pixAi', '-xIga'],
#  ['hi', 'o', '-b', '-a', '-hoi', '-hI'],
#  ['hi', 'o', '-b', '-a', '-hoi', '-sai', '-xAag', '-abagaI'],
#  ['baOsa', 'O', '-xiai', '-hI'],
#  ['xaI', 'hi', 'aigIa', 'ti', 'xo', '-o', '*', '-gIa', '-xi'],
#  ['*', 'XohoA', '-o', '-b', '-Aa', 'bO', '-p', '-a'],
#  ['*', 'Xo', '-p', '-i', '-ta', '-p', '-aI'],
#  ['tIi', 'xaigIa', 'gA'],
#  ['toIao', 'tIi', 'OsibAop', '-iig', '-AbagaI'],
#  ['xaI', 'tIi', 'gA', '-sai', 'gai', 'gOi'],
#  ['hi', 'o', '-b', '-A', '-ab', '-Abai', 'hoaI'],
#  ['hi', 'sA', '-i', '-xI'],
#  ['hoagaixoOxai', 'hi', 'o', '-s', 'aa'],
#  ['hi', 'ab', 'a', '-haI', '-xai'],
#  ['hi',
#   'aigIa',
#   'xopIsi',
#   'hi',
#   'aigIa',
#   'ka',
#   'Ot',
#   'a',
#   '-O',
#   '-p',
#   '-iig',
#   '-aO'],
#  ['*', 'xaitA', '-iIg', '-A', '-o', '-b', '-I', '-ta', '-hA'],
#  ['hi', 'gA', 'xai', '-aI'],
#  ['*', 'k', 'o', '-s', 'a', '-i', '-hiab', '-aO'],
#  ['*', 'xaitA', '-b', '-iI', '-hai', '-xai'],
#  None,
#  ['hi', 'aigIa', 'ko', '*', '-b', '-a', '-p', '-i', 'aagA'],
#  ['hoagaixoxai', 'hi', 'aigIa', 'gA', 'xai'],
#  ['kagihi', 'ot', '*', '-Ab', 'aag', '-aO'],
#  ['kagihi', 'Oti', '*'],
#  ['aigIa', '*', 'ihIhI', '-a', '-p', '-i', '-ta', '-p', '-aI'],
#  ['tIi', 'xaigIa', 'gA', '-sai'],
#  ['*', 'xihi', '-ab', '-Io'],
#  ['*', 'hi', '*', 'ogI', '-O', 'xio', '*', '-sai'],
#  ['*', 'hi', 'a', '-p', '-i', '-ta', '-p', '-aI'],
#  ['hi', 'sA', '-ab', '-AO', '-xai'],
#  ['xai', 'ti', 'iga', '-I', 'apaI'],
#  ['xigAbaI', 'gI', 'basI', 'ig', 'a', '-b', '-o', '-p', '-a', '-p', '-I'],
#  ['*',
#   'xIs',
#   'ib',
#   '-A',
#   '-i',
#   '-ta',
#   '-a',
#   '-b',
#   '-o',
#   '-i',
#   '-haI',
#   'tigaiti'],
#  ['xIs', 'a', '-xAa', '-hA'],
#  ['xaI', 'toItoI', '*', 'hi', 'xigI', 'a', '-xAa', '-i', '-hA'],
#  ['hi', 'agIai', 'tigaiti', '-gIi', 'xibigaA', '*'],
#  ['tigaiti', '-gIi', 'xaI'],
#  ['*', 'xis', 'ib', '-A', '-i', '-ta', '-b', '-og', '-aAti'],
#  ['hi', 'agIa', '*', 'xogi', 'Aaga', '-O'],
#  ['*',
#   'xis',
#   'aihi',
#   'og',
#   '-a',
#   '-A',
#   '-a',
#   '-b',
#   '-O',
#   '-p',
#   '-a',
#   '-p',
#   '-A'],
#  ['ti', 'agIa', 'xis', 'igI', '-o', '*'],
#  ['k', '-A', 'ab', '-O', '-p', '-A', '-p', '-A', '-xaI'],
#  ['ti', 'igAI', '-sai'],
#  ['xi', 'ab', '-Ao', '-p', '-I', '-saxAa', '-g', '-abaga', '-A'],
#  ['xiabAIsi',
#   'k',
#   '-A',
#   'ab',
#   '-o',
#   '-O',
#   '-p',
#   '-a',
#   '-i',
#   '-hiab',
#   '-i',
#   '-sO',
#   '-ai',
#   'xaIhA'],
#  ['xi', 'go', '-O', '-i', 'xa', '-O', '-o', '-p', '-A', '-a', '-ha', '-xaI'],
#  ['xi', 'go', '-O', '-i', 'xa', '-O', '-o', '-p', '-A'],
#  ['xoI', 'hi', 'aI', '-si', '-xIga'],
#  ['*', 'xigAbaI', 'hi', 'aa', '-b', '-Ao', '-b', '-Ii', '-sa', '-xA', '-abaI'],
#  ['*',
#   'xigAbaI',
#   'hi',
#   'Aa',
#   '-b',
#   '-o',
#   '-O',
#   '-p',
#   '-Ai',
#   '-hiab',
#   '-sOi',
#   '-xAihi'],
#  ['tIi', 'baAbi', '*', '-ha', '-saa', '-go', '-Ai'],
#  None,
#  ['bAIhiigI'],
#  ['xai', 'bAIhiigI'],
#  ['xaiO'],
#  ['xitaIbIgaisi', 'kapiiga', 'kagak', '-aA'],
#  None,
#  ['xai', 'xigIa', '-oaxAi', '-xi'],
#  ['gIxai', 'xahoa', '-Ati', 'topagahai'],
#  None,
#  ['xai',
#   'xaoOi',
#   'xaaIbAi',
#   'xoI',
#   'kapiOxiai',
#   'kob',
#   '-ai',
#   '-sog',
#   '-abagaI',
#   'hiaitIihI'],
#  ['xigIa', '-oaxAi'],
#  ['xigIai'],
#  ['xai', 'xigIai', 'kapiiga', 'hi', 'ahoAi'],
#  ['xoogiAi', 'hi', 'go', 'gAi', '-sai'],
#  ['xaoOi', 'xaaIbai', 'xaI', 'hiaitIi', '*'],
#  ['xaIbai', '-si'],
#  None,
#  ['xaoOi', 'xao', 'xaagA', 'xoI', 'kapiOxio'],
#  None,
#  ['hi', 'gAI', '-sai'],
#  ['*', 'kob', '-ai', '-soog', '-abagaI', 'hiaitIihI'],
#  None,
#  ['xai', 'saaIbasi', '*', 'kob', '-ai', '-sai'],
#  None,
#  ['xai', 'gixai', 'xaahoai', '-so'],
#  ['*', '*', 'xigi', 'hai', 'xoi', 'kapioxiai', '*'],
#  None,
#  ['xigio', '-awaxai'],
#  ['xigIai'],
#  ['xai', 'xigIai', '*', 'xAaga'],
#  ['xaI', 'ti', 'gAI', '-sai'],
#  ['xigIai', '*', 'xAaga'],
#  ['xaoOii', 'xo', 'Ai'],
#  ['tIi', 'hi', 'aIbA', '-sigIi', 'kob', '-ai', '-soog', '-abagaI'],
#  ['hi', 'hOihi', 'hi', 'hOihi', 'Ai', 'gAihi'],
#  ['paOxai', 'hi', 'ob', '-ai', '-sog', '-abagaI', 'hi', 'aIbA', '-sigIi'],
#  ['xai', 'hi', 'aIbA', '-sigIi', 'hi', 'kob', '-a', '-soog', '-abagaI'],
#  ['hi', 'aIbA', '-sigIi', 'hi', 'ob', '-ai', '-soog', '-abaI', 'gIi'],
#  ['xooopai', 'hi', 'ob', '-a', '-soog', '-abaI', 'hi', 'aIbA', '-sigIi'],
#  ['xai', 'pii', 'ai', '*', '-kOoi'],
#  ['boitOhoi', 'xi', 'ig', '-O', '*', '-p', '-I', '-hiabi', '-koI'],
#  ['xai', 'boitOhoi', 'k', 'ah', '-A', '-p', '-i', '-hiaba', '-A'],
#  ['xao',
#   'hi',
#   'ob',
#   '-a',
#   '-soog',
#   '-abaI',
#   'hi',
#   'aIbA',
#   '-sigIii',
#   'hi',
#   'aIbA',
#   '-sigIii'],
#  ['hi', 'hOihi', 'ai', 'gAi'],
#  ['xai', 'hi', 'hOihi', 'ai', 'gAi', 'pasabIi'],
#  ['xaoOi', 'hi', 'xaokasabIi', 'pasabIi', 'gAi'],
#  ['xaI', 'hoagahIai', 'hiatIi', 'hi', 'xaaIbA', 'ai'],
#  ['xaI', '*', 'xaaIbA', 'ai'],
#  ['hoagahaIai', '-xIga', '*', 'xai'],
#  ['xaI', 'hoagahIai', '-xIga', '*', 'xaaIbA', 'ai'],
#  ['hoagahIai', 'xai', 'gIxai', '*', 'soxOA'],
#  ['xaI', 'tI', 'xabaxAI', 'hi', 'ahoaI', 'topaaga', 'xaI', 'gAi', 'tIi'],
#  ['*', 'kaba', '*', '-hA'],
#  ['*', 'xaaIba', '-hiaba', '*', '-hA', 'gAi'],
#  ['so', 'tIi', 'xabaA', '-ti'],
#  ['xioitabIi', '*', 'gAi'],
#  ['bahaio', 'pIaii'],
#  ['xaI', 'hoaOwIi'],
#  ['tiiowi', 'pIaii', 'xaI', 'tiiowi', 'saiu_ai_morar', 'goO'],
#  ['xabaxAigio'],
#  ['kaahai', '*', 'kaba', '*', '-hA', 'xaaIba', '-si'],
#  ['hOi', 'hOihi'],
#  ['xaI', '*', 'palhal', 'hOii', '*'],
#  ['pIaii', 'agora', 'gAihi', 'ti', 'pIaii'],
#  ['hOihi', 'hOihi'],
#  ['kaba', '-hA', 'xaaIba', '-hiaba'],
#  ['agora', '*', 'hoagahIai', 'xaaIbA', 'ai', 'hiaitIihI'],
#  ['xai',
#   'hiaitIihI',
#   'hi',
#   'aaIbA',
#   'ai',
#   'hiaitIihI',
#   'hoagahIai',
#   '-xiga',
#   'xai',
#   'gAihi'],
#  ['hoihiigIai', 'hi', 'hoihiigIai', 'hi'],
#  ['xaoOi', 'xaokasabIi', 'flechal'],
#  ['xai', 'hiaitIihI', 'xaaIbA', 'ai', 'pIaii'],
#  ['hoihiigIai', 'hoihiigIai', 'pIaii', 'hi', 'aaIbA', 'ai'],
#  ['xaI', 'hiaitIihI', 'xoI', 'hi', 'aokasAi', 'hoihiigIai'],
#  ['xaI', 'flechal', 'xaI', 'xaoOi', 'xao', 'hi', 'xaokasabIi'],
#  ['xai', 'hiaitIihI', 'hi', 'xaokasabIi', 'hoihiigIai', 'hoihiigIai'],
#  ['gAihi',
#   'hoagaihIai',
#   '-hi',
#   'hiaitIihI',
#   'mais_pra_ca',
#   'hoagaihIai',
#   '-hI'],
#  ['xaI', '*', 'xaaIbA', 'ai', 'hiaitIihI', 'hoagaihIai', 'hoagaihIai'],
#  ['xaI', 'gIxai', 'saabi', 'hoagaihIai'],
#  ['xaI', 'tI', 'igAI', '-sai'],
#  ['hi', 'ahoAi', 'topaaga', '-hai', 'agora'],
#  ['gAi', 'kabagAi', 'xabaxAIgio', '*'],
#  ['xai', '*', 'xabaxAIgio', '*', 'kabagai'],
#  ['*', 'hiaiitii', 'kaba', '*', 'kapiOxiai'],
#  ['xai', 'quase', 'gAi', 'gAi', 'passabem', 'xibigai'],
#  ['xaaIbAai', 'hI', 'ai', 'kOi', '-hi'],
#  ['quase', 'xaI', 'muito', 'hi', 'ai'],
#  ['xai', 'xaaIbAai', 'hi', 'xoi', 'hi', 'ai', 'xai', 'hI', 'baagi'],
#  ['bAagiso', 'xaagA', 'gAi', 'bAagiso'],
#  ['xaI', 'tI', '*', 'pIai', 'hOi', '-ho', '*'],
#  ['xaI', 'gAihi', 'tiapAobii', 'pIaii', '*'],
#  ['hOi', 'xaaIba', '-hiaba'],
#  ['xaI', 'tiapAobii', 'xaaIba', '*', '-hiaba'],
#  ['gAihi', '*', 'kab', 'ai'],
#  ['hoagaihiai', 'xaaIbAi', 'hiaitIihI', 'xai', 'hoagaihIai', 'xaaIbAi', '*'],
#  ['gAi', 'hoihigiai', 'pIaii', '*', 'xaaIbA', 'ai', 'hiaitIi'],
#  ['CoatA',
#   'pIaii',
#   'xaaIbAai',
#   'hiatIi',
#   'xaaIbAai',
#   'tiobAhai',
#   'xaI',
#   'xai',
#   '*',
#   '-xIga',
#   'xaaIbAai',
#   'coatA'],
#  ['xaI', 'paagagIsai', 'nome', 'xaoOi', 'gIxai', 'soxOA', 'conhece', 'xai'],
#  ['xaI', 'CoatA', 'mais_para_cA', 'CoatA'],
#  ['xai', 'coatA', 'xaaIbAai', '*'],
#  None,
#  ['xaI', 'tI', 'xahoaI', 'xaoOi'],
#  ['xigIai'],
#  ['xakI', 'xakI', 'ti', 'kagAIhiaI', 'kagi', 'ab', '-A', '-i', '-p', '-I'],
#  ['*', 'k', 'o', '-A', '-i'],
#  ['ti', 'kagAIhiaI', 'kagi', 'ab', '-A', '-i', '-p', '-I'],
#  ['*', 'k', 'o', '-Ai'],
#  ['xaI', 'ti', '*', 'ai', '-A', 'xai', '-A'],
#  ['gaI',
#   '*',
#   's',
#   'ib',
#   '-a',
#   '-i',
#   '-b',
#   '-i',
#   'ab',
#   '-ab',
#   '-A',
#   '-o',
#   '-p',
#   '-i',
#   '-i',
#   '-A'],
#  ['xi',
#   'kagi',
#   'ab',
#   '-A',
#   '-i',
#   '-p',
#   '-I',
#   '-sigI',
#   '-ai',
#   'gaI',
#   '-si',
#   '-i'],
#  ['xIs', 'a', '-p', '-i', '-k'],
#  ['*', 'ob', '-A', '-o', '-b', '-i', '-I', '-haI'],
#  ['xaI', 'ti', 'xai', '-A', 'xakI'],
#  ['kopaIyai', 'kagi', 'ab', '-A', '-i', '-p', '-A', '-hai'],
#  ['xaI', 'kopaIyai', 'kagi', 'ab', '-A', '-i', '-p', '-A', '-hai', '-i'],
#  ['xaI', 'ti', 'gA', 'xai', '-A'],
#  ['kopaIyai', 'xAaga', '-hA', '-I', '-a'],
#  ['xaI', 'kopaI', 'ti', 'gAi'],
#  ['xakI', '-si', 'xIs', 'a', '-p', '-i'],
#  ['*', 'k', 'ob', '-ab', '-A', '-o', '-p', '-iI', '-haI'],
#  ['mm', 'ti', 'gA', 'xai', '-A'],
#  ['xakI', 'xIs', 'a', '-o', '-b', '-ogA', 'xai', '-A', 'xai'],
#  ['giaibaI', 'kopaIyai', 'kAgi', 'ab', '-A', '-i', '-p', '-A', '-hA', '-ii'],
#  ['kopaIyai', 'xIb', '-ai'],
#  ['k', 'oaI'],
#  ['s', 'aagA', '-hai'],
#  ['xaI', '*', 'k', 'apA', '-g', '-ob', '-aO'],
#  ['s', 'ob', '-A', '-I', '-b', '-A', '-o', '-hoagAi', '-xii', '-gA', 'xaI'],
#  None,
#  ['kaapAsi'],
#  ['xaI', 'ti', 'gAI'],
#  ['kaapAsi', '*', 'kaxAowI', 'k', 'ob', '-A', '-aA', '-ta', '-haI'],
#  ['xI', 'kagi', '-hoi', 'xOb', '-A', '-aA', '-ta', '-haI'],
#  ['*', 'kagi', 'ab', '-A', '-i', '-p', '-I'],
#  ['*', 'sigi', 'Ai', '-hI'],
#  ['xaI', 'bAOhoipaI', 's', 'a', '-o', 'xab', '-a', '-ab', '-o'],
#  ['kopaIai', 's', 'a', '-o', 'xab', '-a', '-ab', '-A', '-hA', 'taIo'],
#  ['xaI', '*', 'xab', 'a', '-ab', '-A', '-A', 'taIo'],
#  None,
#  ['xI', 'kag', 'igI', 'a', 'xiowi'],
#  ['hi', 'A', '-o', '-b', '-IsigI', '-o', 'kag', 'igI', '-a', 'xiowi'],
#  ['*', 'hi', 'a', '-o', '-b'],
#  ['*', 'is', 'ig', '-I', '-o', 'xab', '-a', '-ab', '-A', 'taO'],
#  ['hi', 'agIa', '*', '-sO', '-xo', '-i'],
#  ['xIs', 'agIa', 'xI', 'ig', 'A', '-i', '-p', '-AO'],
#  ['*', 'kagi', '-hoi', 'xo', '-A', '-o', '-b', '-A', '-hA', 'xaI'],
#  ['giaibAi',
#   '-hi',
#   'xaI',
#   'xa',
#   'hoa',
#   '-O',
#   'xita',
#   'Ogi',
#   'xaaga',
#   '-hA',
#   'xai'],
#  ['*', 'kagi', 'Igi', '-I', 'bag', '-Ai', '-hI'],
#  ['*', 'kagi', 'ab', '-A', '-boi', '-ta', '-A'],
#  ['hI', 'ab', '*', '-A'],
#  ['*',
#   'kagi',
#   'ab',
#   'o',
#   '-I',
#   '-boI',
#   '-ta',
#   '-A',
#   '-sog',
#   '-ab',
#   '-ai',
#   '-sai',
#   'xOO',
#   '-agA'],
#  ['xaI', 'ti', 'gA', 'xai', '-A'],
#  ['*', 'kA', 'ap', '-I', '-xoog', '-ab', '-i', '-sahaI'],
#  ['*', 'k', 'apA', '-o', '-b', '-Ii', '-ga', '-At', '-i'],
#  ['xi', 'ti', 'boI', '-t', '-A', '-o', '-b', '-I', '-haI'],
#  ['*', 'xI', 'k', 'o', '-ab', '-A', '-o', '-b', '-A', '-hA'],
#  ['taIo', 'xIs', '*', '-agI', '-a'],
#  ['xI', 'k', 'o', '-ab', '-A', '-o', '-b', '-Ii', '-gA', '-hA'],
#  ['taI',
#   '-o',
#   'xI',
#   'k',
#   'ahA',
#   '-p',
#   '-iI',
#   '-hiab',
#   'a',
#   '-hA',
#   'taI',
#   '-o'],
#  ['xigI',
#   'xai',
#   'xI',
#   'k',
#   'o',
#   '-ab',
#   '-A',
#   '-o',
#   '-b',
#   '-A',
#   '-A',
#   'taI',
#   '-o'],
#  ['xaI', 'k', 'o', '-ab', '-A', '-o', '-b', '-Ii', '-g'],
#  ['xaI', 'kaapAsi', 'xigIa', 'xapA', '-o', '-b', '-I', '-sAi', '-hI'],
#  ['xaI', 's', 'agIa', 'k', 'o', '-Ab', '-A', '-o', '-b', '-A', '-I'],
#  ['s', 'agIa', 'sit', '-o', '-A', '-op', '-AO'],
#  ['k', 'ahA', '-pi', '-tA'],
#  ['k', 'o', '-Ab', '-A', '-o', '-b', '-AI', '-saI'],
#  ['ti', 'xagiA', 'k', 'apa', '-Ig', '-A', '-o', '-b', '-I', '-ta', '-haI'],
#  ['i', 'toI', 'hi', '-O', 'xI', 'Ai', 'hI', 'xaI', '*'],
#  ['ti', 'I', 'k', 'apa', '-Ig', '-A', '-o', '-b', '-I', '-ta', '-haI', 'xaI'],
#  ['ti', 'giA', 'k', 'ap', '-A', '-o', '-b', '-I', '-so'],
#  ['k', 'o', '-ab', '-Ai'],
#  ['k', 'o', '-ab', '-A', '-ig', '-A', '-o', '-b', '-i', '-haA', 'xaI'],
#  ['xis', 'ai', '-ta', 'Ogi', '*'],
#  ['xI', 'k', 'oa', '-iI'],
#  ['hi', 'ab', 'a', '-A', 'taI', '-o', 'gIi', '-sai'],
#  ['xis', 'ai', '-ta', 'Ogi', '*'],
#  ['k', 'o', '-aI', '-hiab', '-i', '-kwI', 'gAi'],
#  ['xaowi', '-I', 'xaowi', 'gIai', 'k', 'ob', '-ai', '-hiab', '-i', '-kwI'],
#  None,
#  ['xaI',
#   'pixAi',
#   '*',
#   'xI',
#   'k',
#   'a',
#   '-ap',
#   '-I',
#   '-kwI',
#   'pixAi',
#   '-xII',
#   '-g',
#   '-a'],
#  ['xaI', 'bAOhoipaI', 'so', 'xisaitaOgi', 'sowA', 'k', 'ob', '-ai'],
#  ['xakI', 'kagAIhiAI', '*', '*'],
#  ['so',
#   'kopaIyai',
#   'xisaitaOgi',
#   'hi',
#   'I',
#   'k',
#   'ob',
#   '-ai',
#   '-hiab',
#   '-ii',
#   '-g',
#   '-A'],
#  ['pixAi', 'soxOA', 'hiaitIihI', 'k', 'ap', '-I', '-kwI', 'pixAi', '-xIIga'],
#  ['xaI', 'hiaitIihI', 'baai', '-owI', '*', 'baOhoipaI', 'kopaIyaihi'],
#  ['xigIai'],
#  ['Xabagi', 'hi', 'aigIa', 'gA', 'xai', '-haI'],
#  ['*', 'aogI', 'igIo', 'ai', '-haI', 'aogI'],
#  ['*', 'aogI', 'igIo', '*'],
#  ['*', 'Xoi', '-kab', '-i', '-haI'],
#  ['ahoOgi', 'hi', 'aOgi', 'aIso', 'ag', '-Abai'],
#  ['kohoibiIsai', 'hi', 'aigIa', 'gA', 'xai', '-sai'],
#  ['*', 'aogI', 'aIso', 'xai', '-kab', '-i', '-haI'],
#  ['gIxa', 'baAbi', 'xi', '-isai'],
#  ['*', 'aogI', 'igIo', '*'],
#  ['hi', 'aigIa', 'aogI', 'a', 'bagIa', '-baI', '-xI'],
#  ['hi', 'aOgi', 'a', 'bAI', '*', '-si', '-sai', '-hIaga'],
#  ['ahoOgi', 'hi', 'gA', 'xai', '-sai', '-hiAi'],
#  ['hi', 'aOgi', 'xai', '-sahaxaI'],
#  ['aogI', 'hi', 'aigIa', 'gA', 'xai', '-sai', '-hIai'],
#  ['isaitaOgi', 'hi', 'Ap', '-i', '-si', '-igi', '-hIai', '-saixoAi'],
#  ['ia', 'bAt', '*', '-Aob', '-aA'],
#  ['iAbi', 'hi', 'aigIa', 'gA', 'xai', '-sai', '-hiAi', 'iAbi'],
#  ['isaitaOgi', 'hi', 'Ap', '-i', '-sahaxaI', 'pixAi', '-xIga'],
#  ['ia', 'bAt', '*', '-Aob', '-aA', '-isai', '-hIai'],
#  ['aogi', 'aI', '-tixi'],
#  ['Xoi', 'hi', 'aigIa', 'gA', 'xai'],
#  ['isaitaOgi', 'ao', 'ai'],
#  ['hi', 'ap', '-i', '-kaAhaa'],
#  ['aogI', 'hi', 'gA', 'xai'],
#  ['itaiAi', 'hi', 'aigIa', 'gA', 'xai', '-sai', '-hIai'],
#  ['aO', 'xi', 'ai'],
#  ['ti', 'xaa', '-sai', '-xaaga'],
#  ['isaitaOgi', 'hi', 'ai'],
#  ['hi', 'ap', '-i', '-kaAh', '-aaga'],
#  ['Xoi', 'hi', 'aigIa', 'gA', 'xai'],
#  ['*', 'aogi', 'aIso', 'xai', '-kab', '-i', '-haI'],
#  ['isaitaOgi', 'ao', 'ai'],
#  ['hi', '*', 'Igi', '*'],
#  ['hi', 'ai', '-xi', '-isai', '-hIai'],
#  ['hi', 'aigIa', 'aogi', 'aIso', 'xai', '-kab', '-i', '-haI'],
#  ['aogI', 'aigIa', 'tiIgo', 'o', '-b', '-ai', '-baa', '-haI'],
#  ['ka', 'bAbi', '*'],
#  ['i', 'ka', 'bAbi', '*', '-sahaxaI'],
#  ['hi', 'aOgi', 'aiso', 'aag', '-Abai'],
#  ['hi', 'gA', 'xai'],
#  ['*', 'aogI', 'aIso', 'xai', '-kab', '-i', '-haI'],
#  ['gIxa', 'bAbi', '-kaAh', 'aaga'],
#  ['iAbi', 'hi', 'aigIa', 'aogI', 'hi', 'aigIa'],
#  ['ahoOgi', 'hoI', 'k', 'oaI', '-koI', 'tiobAhai'],
#  ['iAbi', 'hi', 'aigIa', 'gA', 'xai', '-haxa'],
#  ['ahoOgi', 'hoI', 'koaI', 'pixAi', '-xIga'],
#  ['iAbi', 'aogi', 'aigIa', '*'],
#  ['ahoigI', '-O', 'hi', 'hoI', 'kobagApAba', '-ihI', 'tiobAhai'],
#  ['hi', 'gA', '-sai'],
#  ['hi', 'oaI', '-xi'],
#  ['ahoOgi', 'hi', 'aigIa', 'gA', 'xai', '-haI'],
#  ['hi', 'aOgi', 'Ob', '-ao', '-p', '-i', '-hiaba', '-haI'],
#  ['aogI', 'xiigihi', '*', '-O', 'aisigI', 'hi', 'oaI'],
#  ['Xisaabi', 'hi', 'aigIa', 'gA', 'xai', '-sai', '-haxaa'],
#  ['ahoOgi', 'hi', 'aOgi', 'ob', '-ao', '-p', '-ai', '-hiab', '-aO'],
#  ['hi', 'oa', '-bAa', '-hoi', '-hI'],
#  ['hi', 'oa', '-bAa', '-hoI', '-saoi'],
#  ['hi', 'aOgi', 'hi', '-O', 'xia', '-haxa', '-isai', '-hiAi'],
#  None,
#  ['Xoi',
#   'hi',
#   'aigIa',
#   'ahoa',
#   'ko',
#   'oho',
#   '-ai',
#   'ahai',
#   'hoI',
#   'kob',
#   'Aabop',
#   '-Abai',
#   '-ha'],
#  ['aogi', 'Ahoa', 'hio', 'aip', 'iig', '-ag', '-Ap', '-Abai'],
#  ['iAbi',
#   'aogi',
#   'aigIa',
#   'ahoa',
#   'ko',
#   'oho',
#   '-a',
#   'hI',
#   '-O',
#   'hi',
#   'ob',
#   '-ag',
#   '-ai',
#   '-hI'],
#  ['hi', 'oaI', '-xi', 'tiobAhai'],
#  ['isaitaOgi', 'aOpI', '*', '-sahaxaI'],
#  ['hi', 'oaI', '-xi', '-isai', '-hIaha'],
#  ['hi',
#   'ahoa',
#   'ko',
#   'oho',
#   '-a',
#   'hI',
#   '-O',
#   'aogI',
#   'ob',
#   'aOp',
#   '-a',
#   '-hA',
#   'taIo'],
#  ['*', 'aogi', 'Aagisa'],
#  ['iAbi', 'aogi', 'aigIa', 'gA', 'xai', '-sai', '-hiAi'],
#  ['hi', 'tI', 'ob', 'aop', '-ai', '-hiaba', '-haI'],
#  ['hi', '-gI', 'aiO', '*', 'hi', 'xaipi', 'hoai', '-sai', '-xAaga', '-hA'],
#  ['kaogiaI', 'koab', '-Abai', '-koI', 'a', '-ihI'],
#  ['iAbi',
#   'aogi',
#   'hi',
#   'oaI',
#   '-si',
#   'kaoi',
#   'xi',
#   'aipi',
#   'ob',
#   '-Aop',
#   '-A',
#   '-hA'],
#  ['aogi', 'aIpi', '-aAbi', '-so', 'hI', 'ai', 'hi', 'aOi'],
#  ['xi', 'xaipi', 'ob', '-Aop', '-A', '-hA'],
#  ['hi', 'xa', 'xaiO', 'koig', '-A', '-hA', 'kaogiaI'],
#  ['kaxaI', 'hi', 'aOgi', 'ot', '*', '-Ab', '-abai'],
#  ['pix', 'Aagi', 'hi', '-O', 'iai'],
#  ['Xoi',
#   'hi',
#   'pix',
#   'Aagi',
#   'tohoIxi',
#   '-a',
#   'xahaig',
#   'aOi',
#   'xi',
#   'xaipi',
#   'ob',
#   '-i',
#   '-so',
#   '-xai',
#   'aa',
#   '-hAxa'],
#  ['Xapibai', 'ti', 'xaogi', 'aI', 'aixi'],
#  ['hi', 'gA', '-sai', 'ioitAbi'],
#  ['hi', 'ab', '-iI', '-haI'],
#  ['hi', 'oa', '-og', '-ab', '-i', '-sahaI'],
#  ['ti', 'ab', '-iI', '-haI'],
#  ['*', 'abaxaI', 'hoag', '-aI'],
#  ['hi', 'oa', '-og', '-ab', '-i', '-saI'],
#  ['*', 'aibogiaI', '*', '-g', '-Ab', '-O', '-p', '-ai', '-ta', '-haA'],
#  ['ti', 'ab', '-iI', '-sai', '-Aaga'],
#  ['*', 'ab', '-iI', '-haI'],
#  ['*', 'xoi', 'kaba', '*', '-O'],
#  ['*', 'ab', '-iI', '-haI'],
#  ['hi', 'tai', '-kaA', 'xaaga', 'tiobAha'],
#  ['gIxa', 'hi', 'Ig', 'i', '-hiab', '-i', '-koI'],
#  ['*', 'xaI', 'ab', '-iI', '-haI'],
#  ['hi', 'gA', '-sai'],
#  ['*', 'soxoA', 'hOi', '-koI'],
#  ['hi', 'oa', '-og', '-ab', '-i', '-saI'],
#  ['*', 'oA', 'kaba', '-O'],
#  ['*', 'ab', '-iIg', '-A'],
#  ['ba', 'hOxoi', 'piai', 'pio', 'hoag', '-aAti'],
#  ['*', 'Xoi', 'kaba', '*', '-O'],
#  ['*', 'ab', '-iI'],
#  ['xaI', 'isaitaOgi', 'hi', 'ah', '-A', '-p', '-i', '-so'],
#  ['*', 'io', 'abOp', '-I'],
#  ['xaI', '*', 'Xoi', 'kaba', '*', '-O'],
#  ['*', 'ab', '-iI', '-haI'],
#  ['i', 'ab', '-aI', '-ta', '-I'],
#  ['*', 'abaxaI', 'hoi', '-iIg', '-A'],
#  ['*', 'Xoi', 'kaba', '*', '-O'],
#  ['*', 'ab', '-xiig', '-A'],
#  ['hi', 'gA', '-sai', 'ioitAbi'],
#  ['*', 'ab', '-iI', '-sai', '-xAaga'],
#  ['hoagaIxOxaI', 'hi', 'gA', '-sai', 'hoagaIxOxaI'],
#  ['hi', 'ab', '*', '-iig', '-A', 'Xaogioso'],
#  ['gIxi', 'oa', '-og', '-ab', '-oxoi', '-hI', 'XaogiosohoagI'],
#  ['*', 'itA', 'hoAgaI', '-I', 'pIi'],
#  ['pIi', 'i', 'op', '-i', '-hiab', '-iig', '-A', 'pIi'],
#  ['hoagaIxOxaI', 'hi', 'gA', '-sai', 'hi'],
#  ['*', 'oa', '-og', '-ab', '-oxoi', '-hI'],
#  ['pIi', 'itA', 'hoAgaI', '-I', 'pIi'],
#  ['i', 'op', '-i', '-hiaba', '-xaI'],
#  ['i', 'aIgI', 'sog', '-i', '-sOiAihI'],
#  ['i', 'op', '-i', '-hiaba'],
#  ['hoagaIxOxaI', 'hi', 'gA', '-sai', 'hoagaIxOxaI'],
#  ['tiobAha', '*', 'soxoA'],
#  ['hoagaIxOxaI', 'hi', 'gA', '-sai'],
#  ['hi', 'soxoA', 'kA', 'op', '-A', '-hA', 'pIi'],
#  ['hoagaIxOxaI',
#   'hi',
#   'aigIa',
#   'xabOi',
#   '-apai',
#   'i',
#   'hoagI',
#   'hi',
#   'Ao',
#   '-p',
#   '-A',
#   '-hA'],
#  ['*', 'iA'],
#  ['kagi', 'hi', 'A', 'Op', '-I', '-so'],
#  ['hoagaIxOxaI', 'hoagaIxOxaI', 'hi', 'gA', '-sai'],
#  ['Xopisi', 'hi', 'oa', '-og', '-ab', '-oxoi', '-hI'],
#  ['*', 'itA', 'hoAgaI', '-i', 'pIi'],
#  ['hoagaIxOxaI', 'hi', 'gA', '-sai', 'hoagaIxOxaI'],
#  ['pIi', 'itA', 'hoAgaI', '-i', 'ahoaIi'],
#  ['hi', 'oa', '-og', '-ab', '-oxoi', '-hI'],
#  ['hi', 'gA', '-sai', 'hoagaIxOxaI'],
#  ['hi', 'gA', '-sai'],
#  ['i', 'op', '-i', '-hiaba', '-xaI'],
#  ['XaogiosohoagI', 'hi', 'oao'],
#  ['XaogiosohoagI', 'hi', 'oa', '-og', '-ab', '-oxoi', '-hI'],
#  ['i', 'op', '-i', '-hiaba', '-xaI', 'Xaogioso', 'pIi'],
#  ['hoagaIxOxaI', 'hi', 'aigIa', 'gA', 'xai', '-ai', 'hoagaIxOxaI'],
#  ['hi', 'soxoA', 'kA', 'op', '-A', '-hA', 'pIi', 'pixAi', '-xIga'],
#  ['hoagaIxOxaI', 'hi', 'aigIa', 'gA', 'xai', '-ai'],
#  ['isaitaOgi',
#   'baOsai',
#   'pis',
#   '-o',
#   'iig',
#   '-o',
#   '-p',
#   '-i',
#   '-kaba',
#   '-haI'],
#  ['hi', 'bio', 'aI', '-xi'],
#  ['hoagaIxOxaI', 'hi', 'aigIa', 'hoagaIxOxaI', 'hi', 'gA', '-sai'],
#  ['*', 'baOsai', '-pis', '-o', 'iig', '-o', '-p', '-i', '-haI'],
#  ['hoagaIxOxaI',
#   'hi',
#   'aigIa',
#   'baOsai',
#   '-pisi',
#   'iig',
#   '-ai',
#   '-p',
#   '-I',
#   '-haI'],
#  ['hoagaIxOxaI', 'hi', 'gA', '-sai'],
#  ['pIi', 'ia', '-o', '-p', '-a', '-pahAi', '-xi'],
#  ['pIi', 'I', 'bio', '*', '-ab', '-Aa'],
#  ['*', 'o', '-p', '-ai', '-hiab', '-i', '-haI'],
#  ['hi', 'aigIa', 'hoagI', 'xiig', '-A', '-o', '-b', '-AhA', 'pIi'],
#  None,
#  ['hoagaIxOxaI',
#   'hi',
#   'aigIa',
#   'apipA',
#   'giaIi',
#   'kagi',
#   'hi',
#   'abAa',
#   '-hoi',
#   '-haI',
#   'agIiso'],
#  ['pIi', 'gIxa', 'kaxaO'],
#  ['aho', 'IbIg', '*', '-AhA', '-taIo'],
#  ['*', 'a', 'hoagI', 'a', '-p', '-i', '-xai', '-hiabi', '-koI'],
#  ['hoagaIxOxaI',
#   'hi',
#   'aigIa',
#   'baOsai',
#   'pis',
#   '-o',
#   'a',
#   '-o',
#   '-p',
#   '-ai',
#   '-xiI',
#   '-haI'],
#  ['hoagaIxOxaI',
#   'hi',
#   'aigIa',
#   'baOsai',
#   'pis',
#   '-o',
#   'kagi',
#   'hi',
#   'iIg',
#   '-A',
#   '-o',
#   '-p',
#   '-ai',
#   '-haI'],
#  ['hoagaIxOxaI', 'hi', 'aigIa', 'gA', 'xai'],
#  ['*', 'kaxaO'],
#  ['pIi', 'hi', 'bio', 'aI', 'pIi'],
#  ['hoagaIxOxaI', 'hi', 'gA', 'xai', '-aO', 'kagi'],
#  ['hi', 'iig', '-A', '-o', '-p', '-a', '-pabAi', 'hoagaIxOxaI'],
#  ['gIx', 'o', '-p', '-i', '-haI', 'kaI', '-o'],
#  ['*', 'a', '-b', '-o', '-p', '-i', '-haI'],
#  ['*', 'ait', '-ab', '-o', '-p', '-i', '-haI', 'gabai'],
#  ['hoagaIxOxaI', 'hi', 'gA', '-sai'],
#  ['pIi', 'hi', 'gA', '-sai'],
#  ['ti', 'bio', '-ab', 'Ai'],
#  ['*', 'o', '-p', '-i', '-hiab', '-aA'],
#  ['ti', 'xahoa', 'bIo', '*'],
#  ['aho', 'AbahIo', '-xi', 'ai'],
#  ['*', 'oO', 'xaI', '-hiaba'],
#  ['hoagaIxOxaI', 'hi', 'aigIa', 'gA', 'xai', '-a', 'hoagaIxOxaI'],
#  ['*', 'baOsai', 'pis', '-O', 'iig', '-o', '-p', '-i', '-haI'],
#  None,
#  ['gIxi', 'ait', 'a', '-b', '-o', '-p', '-i', '-haI', 'baOsai', 'pis', '-O'],
#  ['kagi', 'hi', 'iIg', '-a', '-o', '-p', '-A', '-pa', '-hA', '-xai'],
#  ['*',
#   'baOsai',
#   'pis',
#   '-O',
#   'iIg',
#   '-a',
#   '-o',
#   '-p',
#   '-A',
#   '-pa',
#   '-hA',
#   '-xai'],
#  ['aO', 'gA', '-sai'],
#  ['i', 'biO', '-ab', '*', '-OxoI', '-hI'],
#  ['i', 'O', '-p', '-i', '-hiaba', '-xaI', '-isai'],
#  ['hoagaIxOxaI', 'hi', 'aigIa', 'hoagaIxOxaI', 'hi', 'gA', '-sai'],
#  ['*', 'baOsai', 'pis', '-O', 'iig', '-o', '-p', '-i', '-haI', '-isai'],
#  ['hoagaIxOxaI',
#   'hi',
#   'aigIa',
#   'baOsai',
#   'pis',
#   '-O',
#   'i',
#   'kagi',
#   'iig',
#   '-a',
#   '-o',
#   '-p',
#   '-A',
#   '-pahA',
#   '-xai'],
#  ['hoagaIxOxaI', 'hi', 'aigIa', 'hoagaIxOxaI', 'hi', 'gA', '-sai'],
#  ['pIi', 'hi', 'soxoA', 'kA', 'o', '-p', '-AhA', 'pio'],
#  ['hoagaIxOxaI', 'hi', 'aigIa', 'Aboi', '-apai', 'i', 'A', '-p', '-ai'],
#  ['*', 'hoagI', 'hi', 'aO', '-p', '-i', '-haxaI'],
#  ['hoagaIxOxaI', 'kagi', 'hi', 'A', 'Op', '-i', '-sai'],
#  ['ti', 'aogI', 'aipipaO', '-ba', '-hoagaI'],
#  ['gI', 'ai', '-hai'],
#  None,
#  ['ti', 'xaI', 'aogI', 'ai', '-xaagA'],
#  ['*', 'apipaO', '-ba', '-hoagaI'],
#  ['*', 'ao', 'gA', 'xai', '-si'],
#  ['*', 'ao', 'apipoA', '-ba'],
#  ['*', 'ao', 'higIo', 'ab', '-aAti'],
#  ['gIxa', 'hi', 'ao', 'ab', '-i', '-koI'],
#  ['ti',
#   'xaigIa',
#   'ao',
#   'ogI',
#   '-giO',
#   'ai',
#   'hi',
#   'ah',
#   '-A',
#   '-p',
#   '-i',
#   '-ta'],
#  ['*', 'apipaA', 'kagahaoogI', 'poogIhiai'],
#  ['Xabagi', 'hi', 'gA', '-sai'],
#  ['isaitaOgi', '*', 'hi', 'ioi', 'xa', '-haI'],
#  ['hi', 'aho', 'ahAp', '-i', '-xiI', '-haI', 'baI'],
#  ['*', 'ioAi', '-xi', 'XaogiosohoagI'],
#  None,
#  ['hi', 'hoi', '-hiab', 'Aa', '-hA'],
#  ['*', 'iig', '-op', '-ai', '-saI'],
#  None,
#  ['*', 'itai', '-kaAh', 'aaga', 'i'],
#  ['*', 'hOi', '-hi', 'Ai'],
#  ['XaogiosohoagI', 'hi', '*', '-abA', 'xai'],
#  ['*', 'iig', '-op', '-ai', '-sai'],
#  ['*', '*', 'ioo', 'a', '-haI', 'isaitaogi'],
#  ['*', 'hOi', '-hI', 'ai'],
#  ['hi', 'ga', '-sai'],
#  ['*', 'itai', '-kaAh', 'aaga'],
#  None,
#  ['hi', '*', '-hiab', '-i', '-kaAh', '-aaga', 'baagi', '-sai'],
#  ['*', 'isaitaOgi', 'ioo', 'xa', '-haI'],
#  ['hi', 'ai', '-hiab', '-i', '-kaAh', 'aaga'],
#  ['*', 'big', 'aI', '-sai'],
#  ['*', 'iig', '-op', '-i', '-sai', '-hi'],
#  ['hi', 'hOi', '-hI', 'ai'],
#  ['*', 'aoaI', '-kaAh', 'aaga', '-i', '-sai'],
#  ['hi', 'ga', '-sai'],
#  ['*', 'hi', 'xioo', 'xa', '-haI', 'isaitaOgi'],
#  ['hi', 'aigIa', 'hi', 'ga', '-sai'],
#  ['isaitaOgi', 'ao', 'ao', 'xai'],
#  ['hi', 'aba', '-ahAp', '-iig', '-A'],
#  ['Xopisi', 'Xaogiosohoagi', 'ioaI', '-xi'],
#  ['isaitaOgi', 'ao', 'I', 'ga', 'xai', '-sai', '-hIai'],
#  ['XaogiosohoagI', 'i', 'o', '-ab', '-A'],
#  ['Xopisi',
#   'hi',
#   'oa',
#   '-og',
#   '-ab',
#   '-a',
#   '-hA',
#   'taIo',
#   '-i',
#   '-sai',
#   '-hIai'],
#  ['hi', 'aigIa', 'ga', 'xai'],
#  ['hi', 'oa', '-og', '-ai', '-ihI'],
#  ['XaogiosohoagI', 'i', 'axabaxaIgio', 'hoiso', '-ai', '-i', '-sai', '-hIai'],
#  ['Xoi', 'hi', 'aigIa', 'ga', 'xai'],
#  ['ao', 'ao', 'hi', 'ob', '-ab', '-ahAp', '-i', '-xiI', '-so', '-xai'],
#  ['isaitaOgi', 'ao', 'aigIa', 'ga', 'xai', '-sai', '-hIai'],
#  ['XaogiosohoagI', 'i', 'hoisO', '-xai'],
#  ['Xopisi', 'hi', 'oa', '-og', '-ab', '-oxoi', '-hI', '-i', '-sai', '-hIai'],
#  ['ao', 'ao', 'hi', 'Aba', '-b', '-ahA', '-p', '-i', '-xiI', '-sai', '-hIai'],
#  ['hi', 'aigIa', 'ga', 'xai', '-sai', '-hIai'],
#  ['XaogiosohoagI', 'ioai', '-xi', '-i', '-sai', '-hIai'],
#  ['hi', 'aigIa', 'ga', 'xai', '-sai', '-hIai'],
#  ['aoOi', 'hi', 'ap', '-i', '-hI'],
#  ['isaitaOgi', 'ao', 'api', '-hiab', '-abaI'],
#  None,
#  ['ao',
#   'aigIa',
#   'ao',
#   'ahoa',
#   'kooho',
#   'ahIo',
#   'ao',
#   'boitOhi',
#   'ohoap',
#   '-i',
#   '-tai',
#   '-xiI',
#   '-sai',
#   '-hIaha'],
#  ['*', 'Xoi', 'kab', 'isoO', 'xia', '-i'],
#  ['hi', 'aigIa', 'ahai', 'ga', 'ai'],
#  ['*', 'opi', '-so'],
#  ['i', 'oaI', '-so', '-xai', 'XaogiosohoagI'],
#  ['hi', 'aI', '-ta', '-o', '-p', '-i', '-hiab', '-iI', '-sai', '-hIai'],
#  ['i', 'so', 'ga', 'xai', '-sai', '-hIai', '-koI', 'agiiso'],
#  ['ao', 'i', 'oaI', '-sai'],
#  ['*', 'boitOhi', 'ohoap', '-I', '-ta', '-pa', '-hAi'],
#  ['ao', 'ga', '-sai'],
#  ['Xaogioso', 'i', 'oaI', '-sai'],
#  ['*', 'gIxa', 'ob', 'Aap', '-i', '-haxa', '-i', '-sai', '-hIaha'],
#  ['XiOgi', 'hi', 'aigIa', 'ga', 'xai', '-sai', '-hIai'],
#  ['XaogiosohoagI', 'i', 'bAa', '-si', 'koaI', '-hi'],
#  ['hi', 'baA', 'xaA', '-baI', '-i', '-sai', '-hIai'],
#  ['hi', 'aigIa', 'ga', 'xai', '-sai', '-hIai'],
#  ['AbahIoxio', 'hi', 'aigIa', 'koaI', '-si'],
#  ['i', 'op', '-aO', '-ai'],
#  ['hi', 'oaI', '-xi', '-i', '-sai', '-hIaha'],
#  ['axaI', 'hi', 'aigIa', 'Ahaig', 'oaI', '-sai', '-hIai'],
#  ['hi', 'aigIa', 'ga', 'xai', '-sai', '-hIai'],
#  ['ko', 'i', 'baAxA', '-bai', '*'],
#  ['hi', 'bAa', '-si', '*'],
#  ['*', 'koa', '-bAii', '-i', '-sai', '-hIaha'],
#  ['Xoi', 'hi', 'aigIa', 'ga', 'xai', '-sai', '-hIai'],
#  ['isaitaOgi', 'hi', 'oaI', '-sai'],
#  ['*', 'gIxa', 'ob', 'ahAp', '-i', '-ta', '-hA'],
#  ['hi', 'oaI', '-kaAh', '-aoga'],
#  ['i', 'hoisO', '-xai', '-xi'],
#  None,
#  ['Xaogioso', 'i', 'op', '-aO'],
#  ['*', 'koaI', '-soxai', '-i', '-sai', '-hIaha'],
#  ['hi', 'aigIa', 'ga', 'xai'],
#  ['hi', 'ogiAgaO', 'hi', 'bagA', '-og', '-ai', '-haI', '-i', '-sai', '-hIaha'],
#  ['*', 'i', 'ob', 'aA', '-haI'],
#  ['*', 'ao', 'ioo', 'a', '-haI', '-i', '-sai', '-hIaha'],
#  None,
#  ['hi', 'aigIa', 'ga', 'xai', '-sai', '-hIai', 'iOgi'],
#  ['aOi', 'ibai', 'kapA', '-boI', '-hI'],
#  ['hi', 'aigIa', '*'],
#  ['gI', '*', '-hiab', '-aO'],
#  ['*', 'bog', '-aI', '-haI', 'baisIhio', '-iai'],
#  ['hi', 'ahoa'],
#  ['*', 'igA', '-boI', '-xiig', '-oxoi', '-hI', '-i', '-sai', '-hIaha'],
#  ['aI', 'hi', 'aigIa', 'ga', 'xai', '-sai', '-hIai'],
#  ['isaitaOgi',
#   'ao',
#   'ahoa',
#   'koo',
#   'hoai',
#   'hi',
#   '-o',
#   'boitOhi',
#   'ohoap',
#   '-i',
#   '-tai'],
#  ['hi', 'goO', 'aoI', 'ai', '-sai', '-xOai'],
#  ['hi',
#   'aigIa',
#   'boitOhoi',
#   'ahoa',
#   'koo',
#   'hoai',
#   'ohoap',
#   '-i',
#   '-ta',
#   '-hai',
#   '-i',
#   '-sai',
#   '-hIaho'],
#  ['Xoi', 'hi', 'aigIa', 'ga', 'xai', '-sai', '-hIai'],
#  ['boitOhi', 'abaa', '-hoI', '-sai'],
#  ['XaogiosohoagI', 'i', 'oaI', '-xi'],
#  ['i', 'oaI', '-so', '-ai', '-sai', '-hIaha'],
#  ['boitOhi', 'abaa', '-hoI', '-so'],
#  ['i', 'aIt', 'aop', '-i', '-sai', '-hIai'],
#  ['i', 'oaI', '-so', '-xai', 'XaogiosohoagI'],
#  ['*',
#   'iAohoabi',
#   'hi',
#   '-gI',
#   'is',
#   'Ik',
#   'ab',
#   '-Abai',
#   '-sai',
#   '-hIai',
#   'tigaiti',
#   'iaOhoabi'],
#  ['I', 'hi', 'hi', 'aopi', '-sai', '-hIai', 'Xopisi'],
#  ['hi', 'gA', '-sai', 'iaOhoabi'],
#  ['Is', 'ai', 'hoag', '-Ixi'],
#  ['I', 'hi', 'akab', '-Abai', '-sai', '-hIahi', 'tigaiti'],
#  ['iaOhoabi', 'hi', 'gA', '-sai'],
#  ['tigaiti', 'Is', 'ai', 'hoag', '-Ixi'],
#  ['*', 'ao', '-xai'],
#  ['*', 'iO', 'xik', 'ohoai', '-sahaxaI'],
#  ['Xopisi'],
#  ['hi', 'gA', '-sai', 'iaOhoabi'],
#  ['*', 'Ik', 'oabAipi', '-hiaba', '-hA', 'tigaiti'],
#  ['Is', 'ai', 'hoagI'],
#  ['hi', 'gA', '-sai', 'iaOhoabi'],
#  ['*', 'Ik', 'oabAipi', '-hiab', '-a', 'Xopisi'],
#  ['Is', 'ai', '*'],
#  ['Is', 'ai', 'hoagI', '-sahaxaI'],
#  ['*', 'kai', '-hiab', '-i', '-haI'],
#  ['hi', 'gA', '-sai', 'iaOhoabi'],
#  ['tigaiti', 'Is', 'ai', 'hoagI'],
#  ['Xopisi', 'i', 'hi', 'ab', '-abaI', '-aO', '-xai', 'tigaiti'],
#  ['hi', 'gA', '-sai', 'iaOhoabi'],
#  ['Is', 'ai', 'hoag', '-Ixi'],
#  ['Ik', 'oabAipi', '-hiaba', '-hA'],
#  ['*', 'iO', 'xik', 'ohoai', '-sahaxaI'],
#  ['hi', 'gA', '-sai', 'iaOhoabi'],
#  ['Is', 'ik', 'ab', '-Abai', '-sO', '-xai'],
#  ['Is', 'ai', 'iaOhoAbi', '*'],
#  ['is', 'ai', 'hoagI'],
#  ['*', 'ao', '-xai', '-hIai'],
#  ['*', 'iO', 'xik', 'ohoai', '-sahaxaI'],
#  ['hi', 'gA'],
#  ['Is', 'ai', 'hoagi'],
#  ['*', 'iO', 'xik', 'ohoai', '-sahaxaI'],
#  ['is', 'ai', 'tigaiti'],
#  ['*', 'hi', 'ab', '-Abai', '-sai', '-hIai'],
#  ['*', 'iO', 'xai', '-sahaxaI'],
#  ['iaOhoabi', 'Is', 'ai', 'hoagI'],
#  ['i', 'ab', '-Abai', '-sai', '-hIai'],
#  ['*', 'iO', 'xik', 'ohoai', '-sahaxaI', '-isai'],
#  ['tigaiti', 'Is', 'ai', 'hoagI'],
#  ['Is', 'ao', '-xai', '-hIai'],
#  ['*', 'iO', 'xai', '-sahaxaI'],
#  ['iAohoabi', 'hi', 'gA', '-sai'],
#  ['tigaiti', 'is', 'ao', '-xai'],
#  ['*', 'ai', 'hoAgi', '-xi'],
#  ['*', 'iO', 'xai', '-sahaxaI'],
#  ['*', 'ai', '-hIxi', '-isai', 'tigaiti'],
#  ['hi', 'gA', '-sai', 'iaOhoabi'],
#  ['i', 'gIx', 'akaa', '-si'],
#  ['*', 'ao', '-xai', 'tigaiti', '-isai'],
#  ['iaOhoabi', 'iO', 'xik', 'ohoai', '-sahaxaI', '-isai'],
#  ['iaOhoabi', 'hi', 'aigIa', 'gA', 'xai'],
#  ['hi', 'gA', '-sai'],
#  ['*', 'iO', 'xai', '-sahaxaI'],
#  ['hi', 'a', 'xaiO', 's', '-igI', 'ohoai', '-hiab', '-i', '-haI'],
#  ['Isi', 'xi', 'ab', '-Ao', '-p', '-i', '-sa', '-xAg', '-abai', '-haxaI'],
#  None,
#  ['*', 'Ik', 'ohoa', '-o', '-p', '-i', '-sai', '-hI', '-isai'],
#  ['Is', 'ai', 'hoagI'],
#  ['I', 'hi', 'hiaop', '-abaI', '-sai', '-hiAi'],
#  ['Xiohoabi', 'hi', 'gA', '-sai'],
#  ['Is', 'ai', 'hoagI', '-xi'],
#  ['*', 'ao', '-xai'],
#  ['*', 'iO', 'xai', '-sahaxaI', '-isai'],
#  ['hi', 'aigIa', 'aho'],
#  ['*', 'aopi', '-haxA', 'gIbagai'],
#  ['hi', 'gA', '-sai'],
#  ['*', 'Is', 'igIo', 'xIk', 'ohoA', '-op', '-aA', '-sahaxaI'],
#  ['*', 'iO', 'xai', '-sahaxaI'],
#  ['hi', 'aIgia', 'Ahaig', 'Ahoa', 'o', '-p', '-i', '-haxA', 'ioIxaihoI'],
#  ['*', 'iO', 'xik', 'ohoai', '-sahaxaI'],
#  ['hi', 'gA', '-sai'],
#  ['I', 'ti', 'hi', 'aI', '-xi'],
#  ['tigaiti', 'ai', 'xOai', '-isai'],
#  ['hi', 'aigIa', 'gA', 'xai', '-sai', '-hIai'],
#  ['*', 'iO', 'xik', 'ohoai', '-sahaxaI'],
#  ['I', 'ti', 'hI', 'ai', 'tigaiti'],
#  ['Is', 'ai', 'hoagI', '-xi'],
#  ['*', 'ao', '-xai', '-isai'],
#  ['*', 'iO', 'xik', 'ohoai', '-sahaxaI', '-aIsai'],
#  ['hi', 'aigIa', 'Ahaig', 'Ahoa', '-opi', '-haxA'],
#  ['hi', 'gA', '-sai'],
#  ['iO', 'is', 'igIo', '*'],
#  ['*', 'iO', 'xik', 'ohoai', '-sahaxaI'],
#  ['hi', 'gA', '-sai'],
#  ['hi', 'aigIa', 'Ahaig', 'Ahoa', '-opi', '-haxA'],
#  ['hi', 'gA', '-sai'],
#  ['*', 'iO', 'xik', 'ohoai', '-sahaxaI'],
#  ['Is', 'ai', 'hoagi', '-xi'],
#  ['*', 'ao', '-xai', 'tigaiti'],
#  ['Ik', 'oabAipi', '-hiaba', '-xai', '-isai'],
#  ['iaOhoabi', 'hi', 'aigIa', 'Ahaig', 'Ahoa', '-abOp', '-aI', '-haxA'],
#  ['*', 'Ahaig', 'Ahoa', 'hoagaI', '-ihI'],
#  ['hi', 'gA', '-sai'],
#  ['*', 'baisIhio', 'Ik', 'ohoai', '-sahaxaI'],
#  ['Is', 'ai', 'hoagI', '-xi'],
#  ['*', 'ao', '-xai', '-xI'],
#  ['Is', 'ai', 'hoagI', 'tigaiti'],
#  ['Ik', 'oabAipi', '-hiab', '-i', '-sai', '-hIai'],
#  ['Ik', 'oabAipi', '-hiab'],
#  ['aI', '*', 'iO', 'xai', '-sahaxaI'],
#  ['*', 'ai', '-hI', '-isai'],
#  ['Is', 'ao', '-xai', 'tigaiti'],
#  ['hi', 'aigIa', 'Ahaig', 'Ahoa', 'hoagaI', '-haxA'],
#  ['hi', 'gA', '-sai'],
#  ['*', 'iO', 'ik', 'ohoai', '-sahaxaI'],
#  ['aI', 'Ik', 'oabAbaipi', '-hiaba', '-xaI', '-isai'],
#  ['hi', 'aigIa', 'Ahaig', 'Ahoa', 'hoagaI', '-ihI', 'ai', '-hI'],
#  ['kabogI',
#   'hi',
#   'baishIhi',
#   '-O',
#   'Ik',
#   'ohoa',
#   '-boi',
#   '-sog',
#   '-ab',
#   '-ai',
#   '-xi'],
#  ['aI', 'kAgi', 'hi', 'gA', 'xai'],
#  ['hi', 'gA', 'xai', '-a', '-hA'],
#  ['paOhoaxai', 'Is', '*', 'igIo', '*'],
#  ['*', 'Ik', 'ohoa', '-bogA', '-sahaxaI', '-isai'],
#  ['hi', 'aigIa', 'baisIhi', '-O', 'Ik', 'ohoai', '-iI', '-haxA'],
#  ['hi',
#   'aigIa',
#   'Ik',
#   'ohoai',
#   '-ta',
#   '-hiab',
#   '-i',
#   '-haxA',
#   '-gAa',
#   '-hAxa',
#   '-isaI'],
#  ['paOhoahai', 'kagi', 'igIo', 'ab', '-Aa'],
#  ['*', 'Ik', 'ohoa', '-ab', '-aA', '-sahaxaI'],
#  ['tigaiti', 'ti', 'baia', 'kai', '-so'],
#  ['ti',
#   'xaigIa',
#   'igihI',
#   'oO',
#   'hoi',
#   '-hI',
#   '-ai',
#   'kasO',
#   '-ab',
#   '-ai',
#   '-sai'],
#  ['*', 'kasOi', '-ta', '-hiab', '-aI', '-gAa', '-hAa'],
#  ['ti', 'gA', 'xai', '-aop', '-A'],
#  ['paohoahai', 'gIxa', 'Is', 'igIo', 'Ik', 'ohoa', '-ab', '-aA', '-sahaxaI'],
#  ['*', 'gAaha', 'oO', 'xai', '-hiaba', '-hA'],
#  ['hi', 'gIx', 'ab', '-iig', '-Aop', '-Abai', '-saI', 'pixAa', '-hAa'],
#  ['ti', 'gA', 'xai', '-saa'],
#  ['hi', 'gA', 'xai', '-abai', '-sai'],
#  ['*', 'Ik', 'ohoa', '-ab', '-iig', '-Abai', '-saI'],
#  ['ti', 'gA', 'ai', '-a'],
#  ['paOhoahai', 'kagI', 'Igio', '*', 'aisigIo', '*'],
#  ['*', 'Ik', 'oho', '-ab', '-aA', '-sahaxaI'],
#  ['tigaiti', 'ti', 'baia', 'kai'],
#  ['*', 'oO', 'xai', '-hiabi', '-koI'],
#  ['Xipogi', 'ahaig', 'AobabI', '-i', '-sai', '-hIai'],
#  ['hi', 'gA', 'xai', '-sai', 'itahA', 'ibigaI', '-so', 'oOxiai'],
#  ['xIs', 'oi', 'aItIgai'],
#  ['XipOgi', '*', 'gai', '-goi', 'hi', 'Aob', '-aop', '-A', '-bA'],
#  ['hi', 'gA', '-sai', '-hiai'],
#  ['Xipogi', 'i', 'baOhoipaIi', 'aItiaai'],
#  ['hi', 'gA', '-sai'],
#  ['Xipogi', '*', 'gI', 'hOi', 'iig', '-op', '-A', '-pI'],
#  ['I', 'soxoA', 'hI', 'abaI', '-I', 'baOhoipAii', 'itihoixoI'],
#  ['hi', 'gA', '-sai', '-hIai'],
#  ['boaI', 'gI', 'ti', 'p', '-A', '-pi'],
#  ['*', 'hi', 'ob', '-aa', 'op', '-iI', '-haI'],
#  ['hi', 'baOhoipaI', '*', 'Xoi'],
#  ['*', 'aItIsai'],
#  ['hi', 'gA', '-sai'],
#  ['i', 'kA', 'op', '-A', '-pi', 'baOhoipaIi'],
#  ['i', 'soxoA', 'hi', 'abAip', '-I'],
#  ['I', 'isagi', 'ohoa', '-bA'],
#  ['hi', 'xai', '-i'],
#  ['Isi', '*', 'ioi', 'baaIg', '-ahAp', '-i', '-sai', '-hIai'],
#  ['hi', 'aigIa', 'gA', 'xai', '-sahai', 'ipoIhi', '-O'],
#  ['*', 'kaxaO'],
#  ['i', 'baOhoipaIi', 'kagi', 'aI', 'giO', 'iig', '-ohAp', '-i'],
#  ['hi', 'aigIa', 'kagi', 'Aob', '-A', '-ha'],
#  ['kagi', 'ahAp', '-i'],
#  ['hi', 'giopaI', 'oO', 'xiai'],
#  ['Is', 'aigIa', 'hi', 'aigIa', 'hi', 'gA', 'xai', '-sai', '-hIai'],
#  ['gI', 'xiig', '-a', '-pI', 'tagaaAga'],
#  ['iI', 'soka', '-op', '-A', '-paA'],
#  ['hi', 'baiai', 'hi', 'aaga', '-hA', 'ipoIhi', '-O'],
#  ['hi', 'aOgaa', 'hoi', 'aaab', 'ai'],
#  ['i', '-higI', 'aOi', 'bAog', '-i', '-so'],
#  ['*', 'hi', 'oab', '-a', '-hoI', '-sai', '-hIai'],
#  ['hi', 'aigIa', 'hi', 'apisA', 'gaitA', '-O'],
#  ['*', 'hi', 'boAsoa', 'gaitA', '-op', '-A', '-hA', '-taI'],
#  ['hi', 'gA', '-sai', '-hIai'],
#  ['kahi', '*', '-ab', '-Ao', '-bII'],
#  ['kabogI', 'hi', 'gA', '-sai', '-hIai'],
#  ['toIao', '*', 'iti', 'ohoa', '-ab', '-aAti', 'taoIhiai'],
#  ['Xoi', 'hi', 'Isi', 'hoai', '-p', 'aI', '-sai', '-hIai'],
#  ['hi', 'aigIa', 'ahai', 'pIo', 'Isi', 'hoa', '-ab', '-i', '-sai', '-hIai'],
#  ['*', 'baixOsi', 'ai', '-sai', '-hIai'],
#  ['kabOgi', 'hi', 'aigIa', 'gA', 'xai', '-sai', '-hIai'],
#  ['ti', 'boa', 'xahoaIi', '*'],
#  ['*', 'Is', 'aOab', '-i', '-hiab', 'aO'],
#  ['*', 'iig', '-abOp', '-A', '-p', '-ai', 'kabatiI', 'is', 'aIbao'],
#  ['ii', 'bIg', 'ohoi', '-sai', '-hIai', 'giotigaxai'],
#  ['hi', 'aigIa', 'gA', 'xai', '-sai', '-hIai', 'Xoi'],
#  ['aibIgaI', '*', 'Ik', 'aabog', '-aAti', 'kabatiI'],
#  ['is', 'aIbaO', '*'],
#  ['*', 'iibIg', 'ohoi', '-xiig', '-A', '-hA'],
#  ['itaIsoi', 'hi', 'aigIa', 'gA', 'xai', '-sai', '-hIai'],
#  ['*', 'hihIo', 'Ik', 'aob', '-iI', '-haI', '-isai'],
#  ['itaIsoi', 'hi', 'aigIa', 'agaoa', 'paI', 'abaxA', '-O', 'boi', '-haI'],
#  None,
#  ['*', 'ik', 'oho', '-ab', 'abOp', '-aI', '-haI', '-isaaga'],
#  ['itaIsoi', 'hi', 'aigIa', 'agaoa', 'abaxA', '-O', 'boi'],
#  ['*', 'Is', 'apai', 'gAob', '-A'],
#  ['*', 'apa', 'Ohoi', '-haI', 'kabatiI', '-IsaI'],
#  ['itaIsoi', 'hi', 'aigIa', 'agaoa', 'abaxA', '-O', 'xiai'],
#  None,
#  ['*', 'abax', '-Oa', 'Ik', 'Aob', '-A'],
#  ['hi', 'gA', '-sai'],
#  ['*', 'abaxaIgio', 'Ik', 'oho', '-ab', 'abOp', '-aI', '-haI', 'I', 'kabatiI'],
#  ['hi', 'aigIa', 'kabOgI', 'hi', 'Isao', 'aIt', 'aop', '-Isai'],
#  ['hi', 'gA', '-sai'],
#  ['*', 'sapa', 'gAob', '-ab'],
#  ['*', 'abOp', '-aI', '-xiI', '-haI', 'itaIsoi'],
#  ['kabOgi', 'hi', 'aigIa', 'hi', 'ab', '-iI'],
#  ['*', 'hiab', 'Aob', 'Xoi', '-koI'],
#  ['Xoi', 'hi', 'aigIa', 'gA', 'xai', '-sai'],
#  ['Xoi', 'hi', 'gA', 'xai', '-sai', '-hIai'],
#  ['hi', 'abAs', 'Xoi', 'xaI', '-i', '-hI'],
#  ['*', 'aI', '-hiaba'],
#  ['*', 'abOp', '-iI', '-haI'],
#  ['itaIsoi', 'hi', 'gA', '-sai'],
#  ['Xoi', 'hi', 'bai', 'aag', '-oI'],
#  ['hi', 'aigIa', 'Is', 'aOabi', '-hiab', '-i', '-haI'],
#  ['is', 'ai', '-hIaga'],
#  ['hi', 'aigIa', 'abaxa', '-O', 'abOp', '-aI'],
#  ['hi', 'gA', '-sai'],
#  ['hi', 'baI', 'ai'],
#  ['hi', 'I', 'hoai', '-hiab', '-i', '-haI', '-isaagA'],
#  ['hi', 'aigIa', 'AbaxaI', 'boi', '-koI'],
#  ['hi', 'gA', '-sai', 'kabOgI'],
#  ['*', 'hi', 'bigAb', '-i', '-haI', 'itaIsoi'],
#  ['hi', 'gA', '-sai', 'kabOgI'],
#  ['*', 'hi', 'bigAb', '-i', '-haI', 'itaIsoi'],
#  ['itaIsoi', 'hi', 'abaxa', '-O', 'kohoi', '-sog', '-iI'],
#  ['hi', 'gA', 'xai', '-sai', '-hiAi', 'itaIsoi'],
#  ['hi', 'gA', '-sai'],
#  ['Xoi', 'hi', 'bai', 'xaag', '-oI'],
#  ['hi', 'gA', '-sai'],
#  ['*', 'saOabi', '-hiaba'],
#  ['*', 'abaxaI', 'boi', '-haI', 'gaI', '-xIga'],
#  None,
#  ['*', 'aixiI', 'oag', '-i', 'op', '-aO'],
#  ['hi', 'IsaO', 'apoI', 'aihIop', '-aI'],
#  ['hi', 'gA', '-sai', '-hIai'],
#  ['kabatiI', 'is', 'aIbao', '*'],
#  None,
#  ['*', 'ibIg', 'ohoi', '-hI', 'kabatiI'],
#  ['*', 'bigA', '-xai'],
#  ['*', 'iI', 'oag', '-i', '-op', '-aI'],
#  ['hi', 'aigIa', 'hi', 'aAob', '-aO', '-xaI'],
#  ['hi', 'gA', '-sai', '-hiAi', 'Xoi'],
#  ['hi', 'abAs', 'Xoi', 'xaI', '-ihI'],
#  ['*', 'Is', 'aOab', '-i', '-hiab', '-aO'],
#  ['*', 'a', '-haI', '-isai', '-hIaga'],
#  ['Xoi', 'hi', 'bai', 'ai', '-hIaga'],
#  ['hi', 'aigIa', 'kabOgI', 'pixAagihI', 'hi', 'gA', '-sai'],
#  ['ti', 'boa', 'xahoAi', '-koI', '*'],
#  ['*', 'Is', 'aOab', '-i', '-kab', '-i', '-haI'],
#  ['gIxa', 's', 'ai', '-xi'],
#  ['*', 'Is', 'aOab', '-i', '-hiab', 'aO'],
#  ['*', 'abOp', '-xaI', '-isaihIaga'],
#  ['hi', 'aigIa', 'Is', 'aOab', '-i', '-sO'],
#  ['*', 'abOp', '-aI'],
#  None,
#  ['toIao',
#   'hi',
#   'aigI',
#   'Ahai',
#   'pio',
#   'Ik',
#   'oho',
#   '-ab',
#   '-i',
#   '-sai',
#   '-hIai',
#   'baixOsi'],
#  ['Xoi', 'hi', 'aigIa', 'gA', 'xai', '-sai', '-hIai', 'Xoi'],
#  ['ti', 'xipOihi', 'a', 'sO', '-xi', 'ipoIhi', '-xIga'],
#  ['hi',
#   'aigIa',
#   'a',
#   'ogiO',
#   'Is',
#   'aihiaIp',
#   '-i',
#   '-sai',
#   '-hIai',
#   'baixOsi',
#   '-gI'],
#  ['hi', 'gA', 'xai', '-sai', 'itaIsoi'],
#  ['hi', 'aigIa', 'itaIsoi', 'hi'],
#  ['*', 'Is', 'aOai', '-ta', 'abOp', '-aI', '-saha'],
#  ['*', 'abaxaI', 'boi', '-haI'],
#  ['isaitaOgi', 'ao', 'gA', 'xai', '-sai', '-hIai'],
#  ['batIo', 'hi', 'ahoa', '-O', 'ai', '-sahaI'],
#  ['hi', 'pia', 'hoI'],
#  ['*', 'iApai', 'boitOhoi', 'bAob', '-i', '-sahaxaI'],
#  None,
#  ['hi', 'aigIa', 'gA', '-sai', 'pagaoakOxoi'],
#  ['ao', 'aitA', '-hoI'],
#  ['ao', 'bagi', 'aIta', '-hoi', '-xiI', '-sog', '-i', '-sai', '-hIai'],
#  ['ao',
#   'ahoahi',
#   '-O',
#   'ao',
#   'hoAop',
#   '-i',
#   '-sog',
#   '-i',
#   '-sai',
#   '-hIai',
#   'poogaIhiai'],
#  ['isaitaOgi', 'hi', 'bIib', '-i', '-hiab', '-iI', '-haI'],
#  ['isaitaOgi', 'ao', 'aigIa', 'bagi', 'aitA', '-hoi', '-xiI', '-haI'],
#  None,
#  ['ao', 'aigIa', 'his', '-O', 'iig', 'Aop', '-aAti', '-isai', '-hIai'],
#  ['ao', 'Atii'],
#  ['hi', 'aigIa', 'his', '-O', 'iig', '-Op', '-i', '-aibiga'],
#  None,
#  ['poogaIhiai'],
#  ['ao', 'gA', '-sai', '-hIai'],
#  ['ahoahi', '-O', 'ao', 'hoaxA', '-isai', '-hIai'],
#  ['ao', 'aItii'],
#  ['hi', 'aigIa', 'ao', 'aitA', '-hoI', '-xiI', '-aibiga'],
#  ['*', 'poogaIhiai', 'aIt', '-op', '-axA', '-isai'],
#  ['ao', 'aItii'],
#  ['hi',
#   'aigIa',
#   'aoI',
#   'batIo',
#   'ao',
#   'aigIa',
#   'ait',
#   '-aI',
#   '-gA',
#   '-hoI',
#   '-xiI',
#   '-haxA'],
#  ['ao', 'gA', '-sai'],
#  ['ao', 'xaItii'],
#  ...]

# %% [markdown]
# ### Homework: Verify the following
# > The phonological segments of Pirahã are /i/, /a/, /u/, /p/, /t/, /k/, /h/, /s/, /b/, /g/, and /ʔ/. In the orthography we adopt for this paper, < x > represents the glottal stop and < o > represents /u/.
#
# _Hint: You'll need to join together all the words in all the sentences into one big string. Then you can use the [set](https://docs.python.org/3/tutorial/datastructures.html#sets) constructor._

# %% [markdown]
# > The language has two tones, high and low. Note that in this corpus high tones are marked with a capitalized letter.
#
# Once you've verified this, change all high tones to the IPA vowel with an accute accent, and low vowels to the IPA vowel with grave accent. Change the < o > to a /u/ as well.

# %% [markdown]
# > The sound /s/ is usually absent from women’s speech; women use /h/ where men use /s/. Can you infer which speakers are female and which are male?

# %% [markdown]
# > 1149 sentences, with an average of 5.9 words per sentence.

# %% [markdown]
# ### Pandas
#
# [Pandas](http://pandas.pydata.org/pandas-docs/stable/) is a new-ish Python library that makes data analysis easy and flexible. The main object it defines for us is a `DataFrame`. This will be familiar for people that use R. When I think of a `DataFrame`, I think of an Excel spreadsheet. Each column has a variable, and each row is an observation.

# %%
import pandas as pd
corpus = pd.DataFrame(sentences)

# %% [markdown]
# - What does the `as pd` bit do?
# - Why did we choose `pd` as the name to import `pandas` as?
# - Constructing DataFrames

# %%
corpus
# Out:
#                                        fname  sent_num  \
# 0     01_KATO'S BABY FALLS NEAR THE FIRE.pdf         1
# 1     01_KATO'S BABY FALLS NEAR THE FIRE.pdf         2
# 2     01_KATO'S BABY FALLS NEAR THE FIRE.pdf         3
# 3     01_KATO'S BABY FALLS NEAR THE FIRE.pdf         1
# 4     01_KATO'S BABY FALLS NEAR THE FIRE.pdf         1
# 5     01_KATO'S BABY FALLS NEAR THE FIRE.pdf         2
# 6     01_KATO'S BABY FALLS NEAR THE FIRE.pdf         3
# 7     01_KATO'S BABY FALLS NEAR THE FIRE.pdf         1
# 8     01_KATO'S BABY FALLS NEAR THE FIRE.pdf         1
# 9     01_KATO'S BABY FALLS NEAR THE FIRE.pdf         2
# 10    01_KATO'S BABY FALLS NEAR THE FIRE.pdf         1
# 11    01_KATO'S BABY FALLS NEAR THE FIRE.pdf         1
# 12    01_KATO'S BABY FALLS NEAR THE FIRE.pdf         1
# 13    01_KATO'S BABY FALLS NEAR THE FIRE.pdf         2
# 14    01_KATO'S BABY FALLS NEAR THE FIRE.pdf         1
# 15    01_KATO'S BABY FALLS NEAR THE FIRE.pdf         1
# 16    01_KATO'S BABY FALLS NEAR THE FIRE.pdf         2
# 17    01_KATO'S BABY FALLS NEAR THE FIRE.pdf         1
# 18    01_KATO'S BABY FALLS NEAR THE FIRE.pdf         1
# 19    01_KATO'S BABY FALLS NEAR THE FIRE.pdf         1
# 20    01_KATO'S BABY FALLS NEAR THE FIRE.pdf         2
# 21    01_KATO'S BABY FALLS NEAR THE FIRE.pdf         1
# 22    01_KATO'S BABY FALLS NEAR THE FIRE.pdf         1
# 23    01_KATO'S BABY FALLS NEAR THE FIRE.pdf         2
# 24    01_KATO'S BABY FALLS NEAR THE FIRE.pdf         3
# 25    01_KATO'S BABY FALLS NEAR THE FIRE.pdf         4
# 26    01_KATO'S BABY FALLS NEAR THE FIRE.pdf         5
# 27    01_KATO'S BABY FALLS NEAR THE FIRE.pdf         1
# 28    01_KATO'S BABY FALLS NEAR THE FIRE.pdf         1
# 29    01_KATO'S BABY FALLS NEAR THE FIRE.pdf         1
# ...                                      ...       ...
# 1159              16 TRIP TO SEE A PLANE.pdf         2
# 1160              16 TRIP TO SEE A PLANE.pdf         1
# 1161              16 TRIP TO SEE A PLANE.pdf         1
# 1162              16 TRIP TO SEE A PLANE.pdf         2
# 1163              16 TRIP TO SEE A PLANE.pdf         1
# 1164              16 TRIP TO SEE A PLANE.pdf         1
# 1165               17 PORTO VELHO IS BIG.pdf         1
# 1166               17 PORTO VELHO IS BIG.pdf         1
# 1167               17 PORTO VELHO IS BIG.pdf         1
# 1168               17 PORTO VELHO IS BIG.pdf         2
# 1169               17 PORTO VELHO IS BIG.pdf         1
# 1170               17 PORTO VELHO IS BIG.pdf         1
# 1171               17 PORTO VELHO IS BIG.pdf         1
# 1172               17 PORTO VELHO IS BIG.pdf         2
# 1173               17 PORTO VELHO IS BIG.pdf         1
# 1174               17 PORTO VELHO IS BIG.pdf         1
# 1175               17 PORTO VELHO IS BIG.pdf         2
# 1176               17 PORTO VELHO IS BIG.pdf         3
# 1177               17 PORTO VELHO IS BIG.pdf         1
# 1178               17 PORTO VELHO IS BIG.pdf         1
# 1179               17 PORTO VELHO IS BIG.pdf         1
# 1180               17 PORTO VELHO IS BIG.pdf         1
# 1181               17 PORTO VELHO IS BIG.pdf         2
# 1182               17 PORTO VELHO IS BIG.pdf         1
# 1183               17 PORTO VELHO IS BIG.pdf         1
# 1184               17 PORTO VELHO IS BIG.pdf         1
# 1185               17 PORTO VELHO IS BIG.pdf         1
# 1186               17 PORTO VELHO IS BIG.pdf         1
# 1187               17 PORTO VELHO IS BIG.pdf         1
# 1188               17 PORTO VELHO IS BIG.pdf         1
#
#                                        sent_translation  speaker  story_num  \
# 0                           [Early in the] day I spoke.  Aogioso          1
# 1                BaIgipOhoasi [speaker's sister] spoke.  Aogioso          1
# 2     "Is Kato sleepy?"  [Lit: "Kato-- her eyes flut...  Aogioso          1
# 3     He [TixohOI, KatO's baby] almost fell in the f...  Aogioso          1
# 4                                              I spoke!  Aogioso          1
# 5                      "He [TixohOI] is on the ground."  Aogioso          1
# 6                                  "TixohOI is crying."  Aogioso          1
# 7             [He] certainly fell by the fire just now.  Aogioso          1
# 8         I thus spoke [to] Xopisi [speaker's husband]!  Aogioso          1
# 9     "Did TixohOI fall down [and burn himself] just...  Aogioso          1
# 10                   "[TixohOI] is by the fire crying."  Aogioso          1
# 11      "Did he fall down [and burn himself] just now?"  Aogioso          1
# 12                                        I thus spoke!  Aogioso          1
# 13       "Well thus I will seek him out in that place."  Aogioso          1
# 14               He was putting dirt up in [his] mouth!  Aogioso          1
# 15                                        I thus spoke!  Aogioso          1
# 16    "Xopisi, don't be so sleepy!"  ###Or possibly:...  Aogioso          1
# 17       [TixohOI] certainly fell by the fire just now.  Aogioso          1
# 18             Did he fall directly down [on the fire]?  Aogioso          1
# 19                 XigaOxixaihoai thus certainly spoke.  Aogioso          1
# 20    "Kato, you certainly are sleepy.  ###Or possib...  Aogioso          1
# 21    " Your young first born child is by the fire r...  Aogioso          1
# 22                   She [speaker's sister] thus spoke.  Aogioso          1
# 23                      [My] sister is certainly angry.  Aogioso          1
# 24                                           She spoke!  Aogioso          1
# 25                        "[TixohOI] fell in the fire?"  Aogioso          1
# 26                    "[He] fell in the fire just now?"  Aogioso          1
# 27               "Did Tixohoi fall down [in the fire]?"  Aogioso          1
# 28                        "[He] is crying by the fire."  Aogioso          1
# 29                                        I thus spoke!  Aogioso          1
# ...                                                 ...      ...        ...
# 1159     The foreigners gave a bunch [of] candy to him.  Tisahai         16
# 1160             Itaibigai, many airplanes [are] there.  Tisahai         16
# 1161              [There] are airplanes, big airplanes.  Tisahai         16
# 1162            The white ones [airplanes] [are] there.  Tisahai         16
# 1163  The airplane, the foreigner's airplane, sits o...  Tisahai         16
# 1164                Itaibigai, the airplanes [are] big.  Tisahai         16
# 1165  Itaibigai, he [Steve] certainly wanted to do [...  Tisahai         17
# 1166  Itaibigai, the foreigner [Steve] again wanted ...  Tisahai         17
# 1167  Thus the foreigner [bought] much animal/fish [...  Tisahai         17
# 1168     He certainly wanted/bought animal/fish [meat].  Tisahai         17
# 1169    Itaibigai, [it] was not a little bit [of fish].  Tisahai         17
# 1170                  You [must] see Porto Velho there!  Tisahai         17
# 1171                   [When] the foreigner [is there].  Tisahai         17
# 1172  Thus the foreigner certainly buys animal [meat...  Tisahai         17
# 1173  The foreigner [Steve] also certainly wants to ...  Tisahai         17
# 1174                        The foreigner [Steve] does.  Tisahai         17
# 1175                        The foreigner [Steve] does.  Tisahai         17
# 1176                              [He] does not hunger.  Tisahai         17
# 1177                           [I] nearly won't return!  Tisahai         17
# 1178             Itaibigai, [there are] many foreigners  Tisahai         17
# 1179                  You look at the foreigners there.  Tisahai         17
# 1180                       Many foreigners are [there].  Tisahai         17
# 1181  (As has been mentioned,) [there are] many fore...  Tisahai         17
# 1182       [You] certainly haven't seen the foreigners.  Tisahai         17
# 1183                       [There are] many foreigners.  Tisahai         17
# 1184                    [You] see the foreigners there.  Tisahai         17
# 1185  Itaibigai, many foreigners [are there], certai...  Tisahai         17
# 1186        Many foreigner's houses are at Porto Velho.  Tisahai         17
# 1187  (As has been mentioned,) [there are] many fore...  Tisahai         17
# 1188                [You] have not seen the foreigners.  Tisahai         17
#
#       utt_num                                    utt_translation  \
# 0           1  Early in the day I spoke. BaIgipOhoasi spoke (...
# 1           1  Early in the day I spoke. BaIgipOhoasi spoke (...
# 2           1  Early in the day I spoke. BaIgipOhoasi spoke (...
# 3           2                     He (TixohOI) fell by the fire.
# 4           3  I spoke (carried sound). TixohOI is crying on ...
# 5           3  I spoke (carried sound). TixohOI is crying on ...
# 6           3  I spoke (carried sound). TixohOI is crying on ...
# 7           4                     He fell by the fire right now.
# 8           5  I spoke to Opisi. 'Did TixohOI burn himself ju...
# 9           5  I spoke to Opisi. 'Did TixohOI burn himself ju...
# 10          6                          He is by the fire crying.
# 11          7                     Did he burn himself right now?
# 12          8               I spoke. Well I will go pick him up.
# 13          8               I spoke. Well I will go pick him up.
# 14          9  He is really putting dirt up in his mouth on t...
# 15         10  Thus I spoke.  Xopisi, don't be so sleepy (lazy)!
# 16         10  Thus I spoke.  Xopisi, don't be so sleepy (lazy)!
# 17         11                          He just fell by the fire.
# 18         12  Did he burn himself?  (lit: Did he fall direct...
# 19         13  XigaOxixaihoai then spoke.  Kato are you sleep...
# 20         13  XigaOxixaihoai then spoke.  Kato are you sleep...
# 21         14      Your young first born son is by the fire now.
# 22         15  She said (my sister is angry) she said, "Did h...
# 23         15  She said (my sister is angry) she said, "Did h...
# 24         15  She said (my sister is angry) she said, "Did h...
# 25         15  She said (my sister is angry) she said, "Did h...
# 26         15  She said (my sister is angry) she said, "Did h...
# 27         16  Did TixohOi burn himself? (lit: fall directly ...
# 28         17                          He is crying by the fire.
# 29         18  I then spoke.  Well Opisi, did he burn himself...
# ...       ...                                                ...
# 1159       15              Inside the Brazilians gave him candy.
# 1160       16       Itaibigai there are lots and lots of planes.
# 1161       17                There are big jets airplanes there.
# 1162       17                There are big jets airplanes there.
# 1163       18           There is an airplane sitting path there.
# 1164       19                  Itaibigai, the airplanes are big.
# 1165        1         Itaibigai he (Steve) bought a lot of fish.
# 1166        2   Itaibigai, he (Steve) again bought lots of fish.
# 1167        3       Yes he just now bought a great deal of fish.
# 1168        3       Yes he just now bought a great deal of fish.
# 1169        4           Itaibigai, it was not just a little bit.
# 1170        5                       You must go see Porto Velho.
# 1171        6       When Steve buys, he really buys a lot of it.
# 1172        6       When Steve buys, he really buys a lot of it.
# 1173        7                           Steve also buys farinha.
# 1174        8                          Steve does not go hungry.
# 1175        8                          Steve does not go hungry.
# 1176        8                          Steve does not go hungry.
# 1177        9                            I almost won't go back.
# 1178       10           Itaibigai, there are lots of Brazilians.
# 1179       11                         Go and see the Brazilians.
# 1180       12                      There are so many Brazilians.
# 1181       12                      There are so many Brazilians.
# 1182       13                   You haven't seen the Brazilians.
# 1183       14                         There are many Brazilians.
# 1184       15                                       Go see them.
# 1185       16               Itaibigai there are many Brazilians.
# 1186       17    There are many Brazilian houses at Porto Velho.
# 1187       18                         There are many Brazilians.
# 1188       19                  You have not seen the Brazilians.
#
#                                                   words
# 0             [ti, xahoa, -gI, ti, iga, O, -p, -I, -xi]
# 1                          [hi, igA, xai, baIgipOhoasi]
# 2     [KatO, hi, o, *, -b, -a, -p, -I, -aag, -oxoihI...
# 3                      [hi, hoaI, ib, -a, -b, -og, -aA]
# 4                                   [ti, igA, xai, -ai]
# 5                                      [hi, big, a, -I]
# 6                         [*, is, -Aaga, -haI, TixohOI]
# 7           [*, hoaI, *, -b, -o, -i, -hI, pixAi, -xIga]
# 8              [ti, xaigIA, igA, xai, -ai, xaI, Xopisi]
# 9         [hi, o, -b, -a, -hohI, pixAi, -xIga, TixohOI]
# 10                           [*, hoai, Is, -aagA, -haI]
# 11             [hi, o, -b, -a, -hoi, -hI, pixAi, -xIga]
# 12                          [ti, xaigIa, igA, xai, -ai]
# 13            [xaI, ti, aigIa, hi, xoi, -si, kaop, -aI]
# 14          [hi, Ao, big, *, -o, -b, Ao, -p, -aI, -xai]
# 15                          [ti, xaigIa, igA, xai, -aI]
# 16    [xopIsi, hi, o, *, -b, a, -p, -I, -aag, -ag, -...
# 17          [*, hoaI, *, -b, -O, -i, -hI, pixAi, -xIga]
# 18                              [hI, O, -b, -a, -hoihI]
# 19         [xigaOxixaihoai, hi, aigIa, igA, xai, -haxA]
# 20           [katO, hi, o, *, -b, -a, -p, -I, -ai, -hI]
# 21    [gIxai, piihI, hOi, -kOoI, pixAi, -xIga, hoaI, *]
# 22                                [hi, aigIa, igA, xai]
# 23                              [xahaig, OtI, -ha, xaI]
# 24                                 [hi, igA, xai, -xai]
# 25                           [*, hoaI, -b, -O, -i, -hI]
# 26             [*, hoaI, -b, -O, -i, -hI, pixAi, -xIga]
# 27                     [hi, o, -b, -a, -hoihI, tixohOI]
# 28                           [*, hoaI, is, -Aaga, -haI]
# 29                         [tIi, xaigIa, igA, xai, -ai]
# ...                                                 ...
# 1159               [ao, giO, hi, a, hoAob, -A, bobOxoi]
# 1160                  [itaibIgai, gahiaO, aIbA, *, gai]
# 1161                  [gahiaO, gahiaO, ogiaI, -i, aagA]
# 1162                                  [koobiai, *, gai]
# 1163      [gahiaO, ao, gahiaO, ak, ab, -ai, -AagA, gAi]
# 1164                 [itaIbigai, gahiaO, oogiaI, *, -i]
# 1165             [itaibIgai, i, kaAb, a, -b, -og, -ahA]
# 1166     [itaibIgai, ao, I, kaAb, a, -b, -og, -A, -taI]
# 1167                          [ao, aigIa, Is, oogiO, *]
# 1168                              [hi, Is, og, -A, -hA]
# 1169                     [itaibIgai, hOi, hIoi, -hiaba]
# 1170    [potohIo, gai, goI, k, ob, -A, -ba, -bai, -koI]
# 1171                                   [aoI, I, *, -so]
# 1172     [ao, aigIa, k, aAbi, -so, hi, Is, og, -A, -hA]
# 1173            [ao, xAgaisi, pio, hi, ??, og, -A, -hA]
# 1174                                           [ao, aI]
# 1175                                       [ao, hi, aI]
# 1176                             [*, iaIso, ai, -hiaba]
# 1177                       [*, api, -hiAb, -AbaI, -koI]
# 1178                           [itaibIgai, ao, aibA, *]
# 1179                   [gai, gOi, ao, ob, -I, -bA, -bA]
# 1180                                 [ao, aIbA, hi, aI]
# 1181                               [ao, aIbA, *, -isai]
# 1182                      [*, ao, ob, -ai, -hiaba, -hA]
# 1183                                      [ao, aIbA, *]
# 1184               [*, gai, -gOi, ao, ob, -A, -bA, -bA]
# 1185                      [itaibigAi, ao, aIbA, *, -hA]
# 1186              [ao, kaI, aIbIbaaxA, potohIo, hi, ai]
# 1187                                [ao, aIbA, *, -sai]
# 1188                           [*, ao, ob, -ai, -hiaba]
#
# [1189 rows x 8 columns]

# %% [markdown]
# We can view the `DataFrame` we created simply by typing its name. The Jupyter notebook knows about pandas dataframes and do prints them in a nice way (with alternating colours for rows). We can use the `head` method of a dataframe to see just the first couple of rows.

# %%
corpus.head()
# Out:
#                                     fname  sent_num  \
# 0  01_KATO'S BABY FALLS NEAR THE FIRE.pdf         1
# 1  01_KATO'S BABY FALLS NEAR THE FIRE.pdf         2
# 2  01_KATO'S BABY FALLS NEAR THE FIRE.pdf         3
# 3  01_KATO'S BABY FALLS NEAR THE FIRE.pdf         1
# 4  01_KATO'S BABY FALLS NEAR THE FIRE.pdf         1
#
#                                     sent_translation  speaker  story_num  \
# 0                        [Early in the] day I spoke.  Aogioso          1
# 1             BaIgipOhoasi [speaker's sister] spoke.  Aogioso          1
# 2  "Is Kato sleepy?"  [Lit: "Kato-- her eyes flut...  Aogioso          1
# 3  He [TixohOI, KatO's baby] almost fell in the f...  Aogioso          1
# 4                                           I spoke!  Aogioso          1
#
#    utt_num                                    utt_translation  \
# 0        1  Early in the day I spoke. BaIgipOhoasi spoke (...
# 1        1  Early in the day I spoke. BaIgipOhoasi spoke (...
# 2        1  Early in the day I spoke. BaIgipOhoasi spoke (...
# 3        2                     He (TixohOI) fell by the fire.
# 4        3  I spoke (carried sound). TixohOI is crying on ...
#
#                                                words
# 0          [ti, xahoa, -gI, ti, iga, O, -p, -I, -xi]
# 1                       [hi, igA, xai, baIgipOhoasi]
# 2  [KatO, hi, o, *, -b, -a, -p, -I, -aag, -oxoihI...
# 3                   [hi, hoaI, ib, -a, -b, -og, -aA]
# 4                                [ti, igA, xai, -ai]

# %%
columns = ['story_num', 'speaker', 'fname', 'utt_num', 'utt_translation', 'sent_num', 'words', 'sent_translation']
corpus = corpus[columns]
corpus.head()
# Out:
#    story_num  speaker                                   fname  utt_num  \
# 0          1  Aogioso  01_KATO'S BABY FALLS NEAR THE FIRE.pdf        1
# 1          1  Aogioso  01_KATO'S BABY FALLS NEAR THE FIRE.pdf        1
# 2          1  Aogioso  01_KATO'S BABY FALLS NEAR THE FIRE.pdf        1
# 3          1  Aogioso  01_KATO'S BABY FALLS NEAR THE FIRE.pdf        2
# 4          1  Aogioso  01_KATO'S BABY FALLS NEAR THE FIRE.pdf        3
#
#                                      utt_translation  sent_num  \
# 0  Early in the day I spoke. BaIgipOhoasi spoke (...         1
# 1  Early in the day I spoke. BaIgipOhoasi spoke (...         2
# 2  Early in the day I spoke. BaIgipOhoasi spoke (...         3
# 3                     He (TixohOI) fell by the fire.         1
# 4  I spoke (carried sound). TixohOI is crying on ...         1
#
#                                                words  \
# 0          [ti, xahoa, -gI, ti, iga, O, -p, -I, -xi]
# 1                       [hi, igA, xai, baIgipOhoasi]
# 2  [KatO, hi, o, *, -b, -a, -p, -I, -aag, -oxoihI...
# 3                   [hi, hoaI, ib, -a, -b, -og, -aA]
# 4                                [ti, igA, xai, -ai]
#
#                                     sent_translation
# 0                        [Early in the] day I spoke.
# 1             BaIgipOhoasi [speaker's sister] spoke.
# 2  "Is Kato sleepy?"  [Lit: "Kato-- her eyes flut...
# 3  He [TixohOI, KatO's baby] almost fell in the f...
# 4                                           I spoke!
